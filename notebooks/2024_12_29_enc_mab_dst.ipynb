# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# %load_ext autoreload
# %autoreload 2

# %%
from src.models.modules import *
from src.models.loss import L1_epsilon_lambda
from dataclasses import dataclass
import torch

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

@dataclass
class SDFTransformerConfig:
    dim_context: int
    dim_input: int
    num_outputs: int
    dim_output: int
    delta: float = 0.1
    dim_hidden: int = 128
    num_inds: int = 64
    num_heads: int = 4
    ln: bool = False

class SDFTransformer(nn.Module):
    def __init__(self, config: SDFTransformerConfig):
        super(SDFTransformer, self).__init__()
        self.config = config
        self.epsilon = None
        self.lambdaa = None
        self.proj1 = nn.Linear(config.dim_input, config.dim_hidden)
        self.proj2 = nn.Linear(config.dim_context + 1, config.dim_hidden)
        self.cross = MAB(config.dim_hidden, config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln)
        self.enc = nn.Sequential(
            SAB(config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln),
            nn.SiLU(),
            SAB(config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln),
            nn.SiLU(),
            SAB(config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln),
            nn.SiLU(),
            PMA(config.dim_hidden, config.num_heads, config.num_outputs, ln=config.ln),
            nn.SiLU(),
            nn.Linear(config.dim_hidden, config.dim_output),
            nn.Tanh()
        )

    def forward(self, context: torch.Tensor, x: torch.Tensor, labels: torch.Tensor = None):
        point = x.expand(-1, context.shape[1], -1)  # [batch_size, context_size, dim_input]
        distances = torch.norm(context[..., :3] - point, dim=-1, keepdim=True) # [batch_size, context_size, 1]

        context = torch.cat([context, distances], dim=-1)  # [batch_size, context_size, dim_context + 1]

        point = self.proj1(point)                   # [batch_size, context_size, dim_hidden]
        context = self.proj2(context)               # [batch_size, context_size, dim_hidden]
        y = self.cross(point, context)              # [batch_size, context_size, dim_hidden]
        y = self.enc(y)                             # [batch_size, num_outputs, dim_output]

        loss = None
        if labels is not None:
            loss = L1_epsilon_lambda(y, labels, self.epsilon, self.lambdaa, self.config.delta)
        return {'loss': loss, 'logits': y}

config = SDFTransformerConfig(dim_context=4, dim_input=3, num_outputs=1, dim_output=1)
model = SDFTransformer(config).to(device)
print(device)
# Out:
# cuda

# %%
from src.models.dataset import LazySampleDataset
from pathlib import Path

project_dir = Path(os.path.abspath('')).resolve().parent
procesed_dir = project_dir / 'data' / 'processed'

train_files = list(procesed_dir.rglob('*_train.hdf5'))
val_files = list(procesed_dir.rglob('*_val.hdf5'))

train_dataset = LazySampleDataset(train_files)
val_dataset = LazySampleDataset(val_files)

# %%
from src.data.load_data import get_results_dir
from datetime import datetime

notebook_name = '2024_12_29_enc_mab_dst'
current_date = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
folder_name = f"{notebook_name}-{current_date}"
result_dir = get_results_dir() / folder_name
result_dir.mkdir(parents=True, exist_ok=True)
print(result_dir)
# Out:
# C:\_prog\vm_shared\attention-sdf\results\2024_12_29_enc_mab_dst-2024-12-29-13-48-57

# %%
from transformers import Trainer, TrainingArguments

batch_size = 40
training_args = TrainingArguments(
    output_dir=result_dir / "results",
    eval_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=1,
    logging_dir=result_dir / "logs",
    logging_steps=10,
    weight_decay=0.01,
    save_total_limit=3,
    seed=42
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

curriculum_schedule = [
    {"epochs": 2, "epsilon": 0.02,   "lambda": 0.0,  'learning_rate': 5e-5},
    {"epochs": 2, "epsilon": 0.0075, "lambda": 0.15, 'learning_rate': 4e-5},
    {"epochs": 2, "epsilon": 0.004,  "lambda": 0.3,  'learning_rate': 3e-5},
    {"epochs": 2, "epsilon": 0.002,  "lambda": 0.4,  'learning_rate': 2e-5},
    {"epochs": 2, "epsilon": 0.0,    "lambda": 0.5,  'learning_rate': 1e-5}
]

# %%
from src.visualization.generate_mesh import generate_meshes
from src.data.load_data import get_data_dir

obj_dir = get_data_dir() / 'intermediate'
format_string_base = "{name}-" + current_date + "-curriculum-"

for i, stage in enumerate(curriculum_schedule):
    model.epsilon = stage['epsilon']
    model.lambdaa = stage['lambda']
    trainer.args.num_train_epochs = stage['epochs']
    trainer.args.learning_rate = stage['learning_rate']
    trainer.train()
    format_string = format_string_base + str(i) + ".obj"
    generate_meshes(model, obj_dir, result_dir, format_string, device,
        batch_size, resolution=100, context_size=200)
train_dataset.close()
val_dataset.close()
# Out:
#   0%|          | 0/18000 [00:00<?, ?it/s]
# {'loss': 0.0113, 'grad_norm': 0.0, 'learning_rate': 4.997222222222223e-05, 'epoch': 0.0}
# {'loss': 0.0055, 'grad_norm': 0.03617922589182854, 'learning_rate': 4.994444444444445e-05, 'epoch': 0.0}
# {'loss': 0.0056, 'grad_norm': 0.035623274743556976, 'learning_rate': 4.991666666666667e-05, 'epoch': 0.0}
# {'loss': 0.0017, 'grad_norm': 0.03526078164577484, 'learning_rate': 4.9888888888888894e-05, 'epoch': 0.0}
# {'loss': 0.0028, 'grad_norm': 0.13995517790317535, 'learning_rate': 4.986111111111111e-05, 'epoch': 0.01}
# {'loss': 0.0022, 'grad_norm': 0.034919921308755875, 'learning_rate': 4.9833333333333336e-05, 'epoch': 0.01}
# {'loss': 0.0024, 'grad_norm': 0.035035233944654465, 'learning_rate': 4.9805555555555554e-05, 'epoch': 0.01}
# {'loss': 0.0049, 'grad_norm': 0.008686736226081848, 'learning_rate': 4.977777777777778e-05, 'epoch': 0.01}
# {'loss': 0.0022, 'grad_norm': 0.03537365794181824, 'learning_rate': 4.975e-05, 'epoch': 0.01}
# {'loss': 0.0033, 'grad_norm': 0.1052757129073143, 'learning_rate': 4.972222222222223e-05, 'epoch': 0.01}
# {'loss': 0.003, 'grad_norm': 0.13986074924468994, 'learning_rate': 4.969444444444445e-05, 'epoch': 0.01}
# {'loss': 0.0031, 'grad_norm': 0.0698968768119812, 'learning_rate': 4.966666666666667e-05, 'epoch': 0.01}
# {'loss': 0.003, 'grad_norm': 0.0, 'learning_rate': 4.963888888888889e-05, 'epoch': 0.01}
# {'loss': 0.0028, 'grad_norm': 0.069874607026577, 'learning_rate': 4.961111111111111e-05, 'epoch': 0.02}
# {'loss': 0.0033, 'grad_norm': 0.03508002683520317, 'learning_rate': 4.958333333333334e-05, 'epoch': 0.02}
# {'loss': 0.0035, 'grad_norm': 0.07153661549091339, 'learning_rate': 4.955555555555556e-05, 'epoch': 0.02}
# {'loss': 0.003, 'grad_norm': 0.03504826873540878, 'learning_rate': 4.952777777777778e-05, 'epoch': 0.02}
# {'loss': 0.0038, 'grad_norm': 0.06969845294952393, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.02}
# {'loss': 0.003, 'grad_norm': 0.03552082180976868, 'learning_rate': 4.947222222222223e-05, 'epoch': 0.02}
# {'loss': 0.0029, 'grad_norm': 0.03563302755355835, 'learning_rate': 4.9444444444444446e-05, 'epoch': 0.02}
# {'loss': 0.0038, 'grad_norm': 0.005698909517377615, 'learning_rate': 4.9416666666666664e-05, 'epoch': 0.02}
# {'loss': 0.0023, 'grad_norm': 0.035158947110176086, 'learning_rate': 4.938888888888889e-05, 'epoch': 0.02}
# {'loss': 0.0034, 'grad_norm': 0.06987307965755463, 'learning_rate': 4.936111111111111e-05, 'epoch': 0.03}
# {'loss': 0.0034, 'grad_norm': 0.03493720293045044, 'learning_rate': 4.933333333333334e-05, 'epoch': 0.03}
# {'loss': 0.0037, 'grad_norm': 0.07053502649068832, 'learning_rate': 4.930555555555556e-05, 'epoch': 0.03}
# {'loss': 0.0045, 'grad_norm': 0.035502009093761444, 'learning_rate': 4.927777777777778e-05, 'epoch': 0.03}
# {'loss': 0.0039, 'grad_norm': 0.07055462896823883, 'learning_rate': 4.9250000000000004e-05, 'epoch': 0.03}
# {'loss': 0.0029, 'grad_norm': 0.006163985468447208, 'learning_rate': 4.922222222222222e-05, 'epoch': 0.03}
# {'loss': 0.0034, 'grad_norm': 0.03585571423172951, 'learning_rate': 4.919444444444445e-05, 'epoch': 0.03}
# {'loss': 0.0038, 'grad_norm': 0.0360352024435997, 'learning_rate': 4.9166666666666665e-05, 'epoch': 0.03}
# {'loss': 0.0033, 'grad_norm': 0.013756255619227886, 'learning_rate': 4.913888888888889e-05, 'epoch': 0.03}
# {'loss': 0.0024, 'grad_norm': 0.10740173608064651, 'learning_rate': 4.9111111111111114e-05, 'epoch': 0.04}
# {'loss': 0.0033, 'grad_norm': 0.07123687863349915, 'learning_rate': 4.908333333333334e-05, 'epoch': 0.04}
# {'loss': 0.0031, 'grad_norm': 0.10721170902252197, 'learning_rate': 4.905555555555556e-05, 'epoch': 0.04}
# {'loss': 0.0028, 'grad_norm': 0.14248409867286682, 'learning_rate': 4.902777777777778e-05, 'epoch': 0.04}
# {'loss': 0.0026, 'grad_norm': 0.0, 'learning_rate': 4.9e-05, 'epoch': 0.04}
# {'loss': 0.0034, 'grad_norm': 0.036635808646678925, 'learning_rate': 4.897222222222222e-05, 'epoch': 0.04}
# {'loss': 0.0035, 'grad_norm': 0.012018408626317978, 'learning_rate': 4.894444444444445e-05, 'epoch': 0.04}
# {'loss': 0.0031, 'grad_norm': 0.03813047707080841, 'learning_rate': 4.891666666666667e-05, 'epoch': 0.04}
# {'loss': 0.0034, 'grad_norm': 0.07526347786188126, 'learning_rate': 4.888888888888889e-05, 'epoch': 0.04}
# {'loss': 0.0026, 'grad_norm': 0.04077194258570671, 'learning_rate': 4.8861111111111114e-05, 'epoch': 0.05}
# {'loss': 0.0033, 'grad_norm': 0.11506973952054977, 'learning_rate': 4.883333333333334e-05, 'epoch': 0.05}
# {'loss': 0.0031, 'grad_norm': 0.03744189441204071, 'learning_rate': 4.880555555555556e-05, 'epoch': 0.05}
# {'loss': 0.0025, 'grad_norm': 0.07792346179485321, 'learning_rate': 4.8777777777777775e-05, 'epoch': 0.05}
# {'loss': 0.002, 'grad_norm': 0.051359873265028, 'learning_rate': 4.875e-05, 'epoch': 0.05}
# {'loss': 0.0019, 'grad_norm': 0.08990869671106339, 'learning_rate': 4.8722222222222224e-05, 'epoch': 0.05}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.869444444444445e-05, 'epoch': 0.05}
# {'loss': 0.0023, 'grad_norm': 0.04431198537349701, 'learning_rate': 4.866666666666667e-05, 'epoch': 0.05}
# {'loss': 0.0014, 'grad_norm': 0.15285445749759674, 'learning_rate': 4.863888888888889e-05, 'epoch': 0.05}
# {'loss': 0.0027, 'grad_norm': 0.03862382099032402, 'learning_rate': 4.8611111111111115e-05, 'epoch': 0.06}
# {'loss': 0.0021, 'grad_norm': 0.11349073797464371, 'learning_rate': 4.858333333333333e-05, 'epoch': 0.06}
# {'loss': 0.0019, 'grad_norm': 0.11960440874099731, 'learning_rate': 4.855555555555556e-05, 'epoch': 0.06}
# {'loss': 0.0025, 'grad_norm': 0.07584945857524872, 'learning_rate': 4.8527777777777775e-05, 'epoch': 0.06}
# {'loss': 0.0033, 'grad_norm': 0.01274857483804226, 'learning_rate': 4.85e-05, 'epoch': 0.06}
# {'loss': 0.0033, 'grad_norm': 0.022184137254953384, 'learning_rate': 4.8472222222222224e-05, 'epoch': 0.06}
# {'loss': 0.0021, 'grad_norm': 0.07517918199300766, 'learning_rate': 4.844444444444445e-05, 'epoch': 0.06}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.8416666666666673e-05, 'epoch': 0.06}
# {'loss': 0.0021, 'grad_norm': 0.05830853804945946, 'learning_rate': 4.838888888888889e-05, 'epoch': 0.06}
# {'loss': 0.0022, 'grad_norm': 0.160523921251297, 'learning_rate': 4.8361111111111116e-05, 'epoch': 0.07}
# {'loss': 0.0013, 'grad_norm': 0.03958553075790405, 'learning_rate': 4.8333333333333334e-05, 'epoch': 0.07}
# {'loss': 0.0021, 'grad_norm': 0.11398056894540787, 'learning_rate': 4.830555555555556e-05, 'epoch': 0.07}
# {'loss': 0.0026, 'grad_norm': 0.04961805418133736, 'learning_rate': 4.8277777777777776e-05, 'epoch': 0.07}
# {'loss': 0.0029, 'grad_norm': 0.08936068415641785, 'learning_rate': 4.825e-05, 'epoch': 0.07}
# {'loss': 0.0025, 'grad_norm': 0.045310571789741516, 'learning_rate': 4.8222222222222225e-05, 'epoch': 0.07}
# {'loss': 0.0019, 'grad_norm': 0.018425289541482925, 'learning_rate': 4.819444444444445e-05, 'epoch': 0.07}
# {'loss': 0.0025, 'grad_norm': 0.0, 'learning_rate': 4.8166666666666674e-05, 'epoch': 0.07}
# {'loss': 0.0012, 'grad_norm': 0.041308049112558365, 'learning_rate': 4.813888888888889e-05, 'epoch': 0.07}
# {'loss': 0.0029, 'grad_norm': 0.06502992659807205, 'learning_rate': 4.811111111111111e-05, 'epoch': 0.08}
# {'loss': 0.002, 'grad_norm': 0.12075584381818771, 'learning_rate': 4.8083333333333334e-05, 'epoch': 0.08}
# {'loss': 0.0027, 'grad_norm': 0.24240687489509583, 'learning_rate': 4.805555555555556e-05, 'epoch': 0.08}
# {'loss': 0.0018, 'grad_norm': 0.2803429961204529, 'learning_rate': 4.8027777777777783e-05, 'epoch': 0.08}
# {'loss': 0.0017, 'grad_norm': 0.07495469599962234, 'learning_rate': 4.8e-05, 'epoch': 0.08}
# {'loss': 0.0019, 'grad_norm': 0.07310502231121063, 'learning_rate': 4.7972222222222226e-05, 'epoch': 0.08}
# {'loss': 0.0013, 'grad_norm': 0.018417909741401672, 'learning_rate': 4.794444444444445e-05, 'epoch': 0.08}
# {'loss': 0.0024, 'grad_norm': 0.04029494896531105, 'learning_rate': 4.791666666666667e-05, 'epoch': 0.08}
# {'loss': 0.0016, 'grad_norm': 0.028399452567100525, 'learning_rate': 4.7888888888888886e-05, 'epoch': 0.08}
# {'loss': 0.003, 'grad_norm': 0.02298668399453163, 'learning_rate': 4.786111111111111e-05, 'epoch': 0.09}
# {'loss': 0.002, 'grad_norm': 0.014048065058887005, 'learning_rate': 4.7833333333333335e-05, 'epoch': 0.09}
# {'loss': 0.0018, 'grad_norm': 0.2678765654563904, 'learning_rate': 4.780555555555556e-05, 'epoch': 0.09}
# {'loss': 0.0026, 'grad_norm': 0.0317496657371521, 'learning_rate': 4.7777777777777784e-05, 'epoch': 0.09}
# {'loss': 0.0018, 'grad_norm': 0.08781398832798004, 'learning_rate': 4.775e-05, 'epoch': 0.09}
# {'loss': 0.0024, 'grad_norm': 0.08779315650463104, 'learning_rate': 4.7722222222222226e-05, 'epoch': 0.09}
# {'loss': 0.0017, 'grad_norm': 0.044371578842401505, 'learning_rate': 4.7694444444444444e-05, 'epoch': 0.09}
# {'loss': 0.0016, 'grad_norm': 0.01167644839733839, 'learning_rate': 4.766666666666667e-05, 'epoch': 0.09}
# {'loss': 0.0019, 'grad_norm': 0.03143427520990372, 'learning_rate': 4.7638888888888887e-05, 'epoch': 0.09}
# {'loss': 0.0024, 'grad_norm': 0.11518821120262146, 'learning_rate': 4.761111111111111e-05, 'epoch': 0.1}
# {'loss': 0.0023, 'grad_norm': 0.015031023882329464, 'learning_rate': 4.7583333333333336e-05, 'epoch': 0.1}
# {'loss': 0.0025, 'grad_norm': 0.10842408984899521, 'learning_rate': 4.755555555555556e-05, 'epoch': 0.1}
# {'loss': 0.0013, 'grad_norm': 0.03749889135360718, 'learning_rate': 4.7527777777777785e-05, 'epoch': 0.1}
# {'loss': 0.0017, 'grad_norm': 0.20543552935123444, 'learning_rate': 4.75e-05, 'epoch': 0.1}
# {'loss': 0.0011, 'grad_norm': 0.045557454228401184, 'learning_rate': 4.747222222222222e-05, 'epoch': 0.1}
# {'loss': 0.0017, 'grad_norm': 0.006135909352451563, 'learning_rate': 4.7444444444444445e-05, 'epoch': 0.1}
# {'loss': 0.0014, 'grad_norm': 0.19242732226848602, 'learning_rate': 4.741666666666667e-05, 'epoch': 0.1}
# {'loss': 0.0016, 'grad_norm': 0.19274894893169403, 'learning_rate': 4.7388888888888894e-05, 'epoch': 0.1}
# {'loss': 0.0019, 'grad_norm': 0.23260624706745148, 'learning_rate': 4.736111111111111e-05, 'epoch': 0.11}
# {'loss': 0.0026, 'grad_norm': 0.09282027930021286, 'learning_rate': 4.7333333333333336e-05, 'epoch': 0.11}
# {'loss': 0.0015, 'grad_norm': 0.05595779791474342, 'learning_rate': 4.730555555555556e-05, 'epoch': 0.11}
# {'loss': 0.0018, 'grad_norm': 0.07953821122646332, 'learning_rate': 4.727777777777778e-05, 'epoch': 0.11}
# {'loss': 0.0023, 'grad_norm': 0.10636591911315918, 'learning_rate': 4.7249999999999997e-05, 'epoch': 0.11}
# {'loss': 0.0016, 'grad_norm': 0.119224414229393, 'learning_rate': 4.722222222222222e-05, 'epoch': 0.11}
# {'loss': 0.0021, 'grad_norm': 0.053273849189281464, 'learning_rate': 4.7194444444444446e-05, 'epoch': 0.11}
# {'loss': 0.002, 'grad_norm': 0.04504095017910004, 'learning_rate': 4.716666666666667e-05, 'epoch': 0.11}
# {'loss': 0.0029, 'grad_norm': 0.03977507725358009, 'learning_rate': 4.7138888888888895e-05, 'epoch': 0.11}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.711111111111111e-05, 'epoch': 0.12}
# {'loss': 0.0008, 'grad_norm': 0.20067442953586578, 'learning_rate': 4.708333333333334e-05, 'epoch': 0.12}
# {'loss': 0.0019, 'grad_norm': 0.08242610841989517, 'learning_rate': 4.7055555555555555e-05, 'epoch': 0.12}
# {'loss': 0.0019, 'grad_norm': 0.0377098023891449, 'learning_rate': 4.702777777777778e-05, 'epoch': 0.12}
# {'loss': 0.0024, 'grad_norm': 0.1787511259317398, 'learning_rate': 4.7e-05, 'epoch': 0.12}
# {'loss': 0.0015, 'grad_norm': 0.03946271911263466, 'learning_rate': 4.697222222222222e-05, 'epoch': 0.12}
# {'loss': 0.0027, 'grad_norm': 0.1236879974603653, 'learning_rate': 4.6944444444444446e-05, 'epoch': 0.12}
# {'loss': 0.0014, 'grad_norm': 0.049914054572582245, 'learning_rate': 4.691666666666667e-05, 'epoch': 0.12}
# {'loss': 0.0024, 'grad_norm': 0.04122375696897507, 'learning_rate': 4.6888888888888895e-05, 'epoch': 0.12}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 4.686111111111111e-05, 'epoch': 0.13}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.683333333333334e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.08549778163433075, 'learning_rate': 4.6805555555555556e-05, 'epoch': 0.13}
# {'loss': 0.0024, 'grad_norm': 0.045598261058330536, 'learning_rate': 4.677777777777778e-05, 'epoch': 0.13}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.6750000000000005e-05, 'epoch': 0.13}
# {'loss': 0.0013, 'grad_norm': 0.05612780898809433, 'learning_rate': 4.672222222222222e-05, 'epoch': 0.13}
# {'loss': 0.001, 'grad_norm': 0.12344049662351608, 'learning_rate': 4.669444444444445e-05, 'epoch': 0.13}
# {'loss': 0.0017, 'grad_norm': 0.08154967427253723, 'learning_rate': 4.666666666666667e-05, 'epoch': 0.13}
# {'loss': 0.0016, 'grad_norm': 0.04845903441309929, 'learning_rate': 4.6638888888888896e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.027858320623636246, 'learning_rate': 4.6611111111111114e-05, 'epoch': 0.14}
# {'loss': 0.0025, 'grad_norm': 0.08153871446847916, 'learning_rate': 4.658333333333333e-05, 'epoch': 0.14}
# {'loss': 0.0025, 'grad_norm': 0.05707080289721489, 'learning_rate': 4.6555555555555556e-05, 'epoch': 0.14}
# {'loss': 0.0016, 'grad_norm': 0.05143395811319351, 'learning_rate': 4.652777777777778e-05, 'epoch': 0.14}
# {'loss': 0.0033, 'grad_norm': 0.04124064743518829, 'learning_rate': 4.6500000000000005e-05, 'epoch': 0.14}
# {'loss': 0.0011, 'grad_norm': 0.049610577523708344, 'learning_rate': 4.647222222222222e-05, 'epoch': 0.14}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.644444444444445e-05, 'epoch': 0.14}
# {'loss': 0.0018, 'grad_norm': 0.06081601232290268, 'learning_rate': 4.641666666666667e-05, 'epoch': 0.14}
# {'loss': 0.0019, 'grad_norm': 0.10673508048057556, 'learning_rate': 4.638888888888889e-05, 'epoch': 0.14}
# {'loss': 0.0018, 'grad_norm': 0.02841643989086151, 'learning_rate': 4.636111111111111e-05, 'epoch': 0.15}
# {'loss': 0.0017, 'grad_norm': 0.07982641458511353, 'learning_rate': 4.633333333333333e-05, 'epoch': 0.15}
# {'loss': 0.002, 'grad_norm': 0.07956355810165405, 'learning_rate': 4.630555555555556e-05, 'epoch': 0.15}
# {'loss': 0.002, 'grad_norm': 0.02358810417354107, 'learning_rate': 4.627777777777778e-05, 'epoch': 0.15}
# {'loss': 0.0024, 'grad_norm': 0.08490538597106934, 'learning_rate': 4.6250000000000006e-05, 'epoch': 0.15}
# {'loss': 0.0008, 'grad_norm': 0.01918850466609001, 'learning_rate': 4.6222222222222224e-05, 'epoch': 0.15}
# {'loss': 0.0034, 'grad_norm': 0.042649440467357635, 'learning_rate': 4.619444444444445e-05, 'epoch': 0.15}
# {'loss': 0.002, 'grad_norm': 0.13488076627254486, 'learning_rate': 4.6166666666666666e-05, 'epoch': 0.15}
# {'loss': 0.0013, 'grad_norm': 0.04820465296506882, 'learning_rate': 4.613888888888889e-05, 'epoch': 0.15}
# {'loss': 0.0022, 'grad_norm': 0.03148927167057991, 'learning_rate': 4.6111111111111115e-05, 'epoch': 0.16}
# {'loss': 0.0014, 'grad_norm': 0.08813200145959854, 'learning_rate': 4.608333333333333e-05, 'epoch': 0.16}
# {'loss': 0.0024, 'grad_norm': 0.12538011372089386, 'learning_rate': 4.605555555555556e-05, 'epoch': 0.16}
# {'loss': 0.001, 'grad_norm': 0.07786140590906143, 'learning_rate': 4.602777777777778e-05, 'epoch': 0.16}
# {'loss': 0.0022, 'grad_norm': 0.12936505675315857, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.16}
# {'loss': 0.0017, 'grad_norm': 0.1767159104347229, 'learning_rate': 4.5972222222222225e-05, 'epoch': 0.16}
# {'loss': 0.0021, 'grad_norm': 0.08988529443740845, 'learning_rate': 4.594444444444444e-05, 'epoch': 0.16}
# {'loss': 0.0015, 'grad_norm': 0.042127713561058044, 'learning_rate': 4.591666666666667e-05, 'epoch': 0.16}
# {'loss': 0.0011, 'grad_norm': 0.04165259003639221, 'learning_rate': 4.588888888888889e-05, 'epoch': 0.16}
# {'loss': 0.0028, 'grad_norm': 0.399881511926651, 'learning_rate': 4.5861111111111116e-05, 'epoch': 0.17}
# {'loss': 0.0022, 'grad_norm': 0.16511791944503784, 'learning_rate': 4.5833333333333334e-05, 'epoch': 0.17}
# {'loss': 0.0015, 'grad_norm': 0.05183391273021698, 'learning_rate': 4.580555555555556e-05, 'epoch': 0.17}
# {'loss': 0.0023, 'grad_norm': 0.022736286744475365, 'learning_rate': 4.577777777777778e-05, 'epoch': 0.17}
# {'loss': 0.0013, 'grad_norm': 0.13429532945156097, 'learning_rate': 4.575e-05, 'epoch': 0.17}
# {'loss': 0.0018, 'grad_norm': 0.08480244129896164, 'learning_rate': 4.572222222222222e-05, 'epoch': 0.17}
# {'loss': 0.0018, 'grad_norm': 0.15082038938999176, 'learning_rate': 4.569444444444444e-05, 'epoch': 0.17}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.566666666666667e-05, 'epoch': 0.17}
# {'loss': 0.0018, 'grad_norm': 0.08865181356668472, 'learning_rate': 4.563888888888889e-05, 'epoch': 0.17}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.561111111111112e-05, 'epoch': 0.18}
# {'loss': 0.0014, 'grad_norm': 0.05401123687624931, 'learning_rate': 4.5583333333333335e-05, 'epoch': 0.18}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 4.555555555555556e-05, 'epoch': 0.18}
# {'loss': 0.0015, 'grad_norm': 0.04201831668615341, 'learning_rate': 4.5527777777777784e-05, 'epoch': 0.18}
# {'loss': 0.0013, 'grad_norm': 0.031637370586395264, 'learning_rate': 4.55e-05, 'epoch': 0.18}
# {'loss': 0.0022, 'grad_norm': 0.09775228053331375, 'learning_rate': 4.5472222222222226e-05, 'epoch': 0.18}
# {'loss': 0.0013, 'grad_norm': 0.09096100181341171, 'learning_rate': 4.5444444444444444e-05, 'epoch': 0.18}
# {'loss': 0.0011, 'grad_norm': 0.07853205502033234, 'learning_rate': 4.541666666666667e-05, 'epoch': 0.18}
# {'loss': 0.0008, 'grad_norm': 0.03793098032474518, 'learning_rate': 4.538888888888889e-05, 'epoch': 0.18}
# {'loss': 0.0025, 'grad_norm': 0.0346372127532959, 'learning_rate': 4.536111111111112e-05, 'epoch': 0.19}
# {'loss': 0.0025, 'grad_norm': 0.15550899505615234, 'learning_rate': 4.5333333333333335e-05, 'epoch': 0.19}
# {'loss': 0.0009, 'grad_norm': 0.0914052277803421, 'learning_rate': 4.530555555555556e-05, 'epoch': 0.19}
# {'loss': 0.0029, 'grad_norm': 0.05737542733550072, 'learning_rate': 4.527777777777778e-05, 'epoch': 0.19}
# {'loss': 0.0019, 'grad_norm': 0.04117978736758232, 'learning_rate': 4.525e-05, 'epoch': 0.19}
# {'loss': 0.0012, 'grad_norm': 0.050601329654455185, 'learning_rate': 4.522222222222223e-05, 'epoch': 0.19}
# {'loss': 0.0012, 'grad_norm': 0.038419682532548904, 'learning_rate': 4.5194444444444444e-05, 'epoch': 0.19}
# {'loss': 0.0008, 'grad_norm': 0.04081621393561363, 'learning_rate': 4.516666666666667e-05, 'epoch': 0.19}
# {'loss': 0.0016, 'grad_norm': 0.11523421853780746, 'learning_rate': 4.5138888888888894e-05, 'epoch': 0.19}
# {'loss': 0.0019, 'grad_norm': 0.03914841637015343, 'learning_rate': 4.511111111111112e-05, 'epoch': 0.2}
# {'loss': 0.0032, 'grad_norm': 0.024955276399850845, 'learning_rate': 4.5083333333333336e-05, 'epoch': 0.2}
# {'loss': 0.0025, 'grad_norm': 0.03991936147212982, 'learning_rate': 4.5055555555555554e-05, 'epoch': 0.2}
# {'loss': 0.0023, 'grad_norm': 0.05604976788163185, 'learning_rate': 4.502777777777778e-05, 'epoch': 0.2}
# {'loss': 0.0021, 'grad_norm': 0.06048506498336792, 'learning_rate': 4.5e-05, 'epoch': 0.2}
# {'loss': 0.0025, 'grad_norm': 0.3588932752609253, 'learning_rate': 4.497222222222223e-05, 'epoch': 0.2}
# {'loss': 0.002, 'grad_norm': 0.07948266714811325, 'learning_rate': 4.4944444444444445e-05, 'epoch': 0.2}
# {'loss': 0.0013, 'grad_norm': 0.1224433183670044, 'learning_rate': 4.491666666666667e-05, 'epoch': 0.2}
# {'loss': 0.0007, 'grad_norm': 0.039597004652023315, 'learning_rate': 4.4888888888888894e-05, 'epoch': 0.2}
# {'loss': 0.0013, 'grad_norm': 0.1304447203874588, 'learning_rate': 4.486111111111111e-05, 'epoch': 0.21}
# {'loss': 0.002, 'grad_norm': 0.08260434120893478, 'learning_rate': 4.483333333333333e-05, 'epoch': 0.21}
# {'loss': 0.0006, 'grad_norm': 0.2311587631702423, 'learning_rate': 4.4805555555555554e-05, 'epoch': 0.21}
# {'loss': 0.0019, 'grad_norm': 0.08870765566825867, 'learning_rate': 4.477777777777778e-05, 'epoch': 0.21}
# {'loss': 0.0016, 'grad_norm': 0.2453109622001648, 'learning_rate': 4.4750000000000004e-05, 'epoch': 0.21}
# {'loss': 0.0022, 'grad_norm': 0.08248226344585419, 'learning_rate': 4.472222222222223e-05, 'epoch': 0.21}
# {'loss': 0.0019, 'grad_norm': 0.04694286361336708, 'learning_rate': 4.4694444444444446e-05, 'epoch': 0.21}
# {'loss': 0.0017, 'grad_norm': 0.05720427259802818, 'learning_rate': 4.466666666666667e-05, 'epoch': 0.21}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.463888888888889e-05, 'epoch': 0.21}
# {'loss': 0.0015, 'grad_norm': 0.02947547473013401, 'learning_rate': 4.461111111111111e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.053483426570892334, 'learning_rate': 4.458333333333334e-05, 'epoch': 0.22}
# {'loss': 0.0012, 'grad_norm': 0.038856927305459976, 'learning_rate': 4.4555555555555555e-05, 'epoch': 0.22}
# {'loss': 0.0008, 'grad_norm': 0.038683053106069565, 'learning_rate': 4.452777777777778e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.2705705165863037, 'learning_rate': 4.4500000000000004e-05, 'epoch': 0.22}
# {'loss': 0.0025, 'grad_norm': 0.2082950919866562, 'learning_rate': 4.447222222222223e-05, 'epoch': 0.22}
# {'loss': 0.0017, 'grad_norm': 0.08973371237516403, 'learning_rate': 4.4444444444444447e-05, 'epoch': 0.22}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.4416666666666664e-05, 'epoch': 0.22}
# {'loss': 0.0015, 'grad_norm': 0.08737672865390778, 'learning_rate': 4.438888888888889e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.07563706487417221, 'learning_rate': 4.4361111111111113e-05, 'epoch': 0.23}
# {'loss': 0.0014, 'grad_norm': 0.05739659070968628, 'learning_rate': 4.433333333333334e-05, 'epoch': 0.23}
# {'loss': 0.0007, 'grad_norm': 0.10009612888097763, 'learning_rate': 4.4305555555555556e-05, 'epoch': 0.23}
# {'loss': 0.0015, 'grad_norm': 0.010687836445868015, 'learning_rate': 4.427777777777778e-05, 'epoch': 0.23}
# {'loss': 0.0011, 'grad_norm': 0.010426061227917671, 'learning_rate': 4.4250000000000005e-05, 'epoch': 0.23}
# {'loss': 0.0022, 'grad_norm': 0.12186918407678604, 'learning_rate': 4.422222222222222e-05, 'epoch': 0.23}
# {'loss': 0.0015, 'grad_norm': 0.11869584023952484, 'learning_rate': 4.419444444444444e-05, 'epoch': 0.23}
# {'loss': 0.0021, 'grad_norm': 0.0996030867099762, 'learning_rate': 4.4166666666666665e-05, 'epoch': 0.23}
# {'loss': 0.0019, 'grad_norm': 0.07551822811365128, 'learning_rate': 4.413888888888889e-05, 'epoch': 0.23}
# {'loss': 0.002, 'grad_norm': 0.04878212511539459, 'learning_rate': 4.4111111111111114e-05, 'epoch': 0.24}
# {'loss': 0.0012, 'grad_norm': 0.027752745896577835, 'learning_rate': 4.408333333333334e-05, 'epoch': 0.24}
# {'loss': 0.0018, 'grad_norm': 0.04551218822598457, 'learning_rate': 4.4055555555555557e-05, 'epoch': 0.24}
# {'loss': 0.0018, 'grad_norm': 0.11938007175922394, 'learning_rate': 4.402777777777778e-05, 'epoch': 0.24}
# {'loss': 0.0019, 'grad_norm': 0.09865880012512207, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.24}
# {'loss': 0.0007, 'grad_norm': 0.0869266539812088, 'learning_rate': 4.3972222222222223e-05, 'epoch': 0.24}
# {'loss': 0.0015, 'grad_norm': 0.07734566926956177, 'learning_rate': 4.394444444444445e-05, 'epoch': 0.24}
# {'loss': 0.0013, 'grad_norm': 0.04201127216219902, 'learning_rate': 4.3916666666666666e-05, 'epoch': 0.24}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.388888888888889e-05, 'epoch': 0.24}
# {'loss': 0.0018, 'grad_norm': 0.12673911452293396, 'learning_rate': 4.3861111111111115e-05, 'epoch': 0.25}
# {'loss': 0.0013, 'grad_norm': 0.13562647998332977, 'learning_rate': 4.383333333333334e-05, 'epoch': 0.25}
# {'loss': 0.0016, 'grad_norm': 0.04011303558945656, 'learning_rate': 4.380555555555556e-05, 'epoch': 0.25}
# {'loss': 0.0008, 'grad_norm': 0.10250917077064514, 'learning_rate': 4.377777777777778e-05, 'epoch': 0.25}
# {'loss': 0.0011, 'grad_norm': 0.041064243763685226, 'learning_rate': 4.375e-05, 'epoch': 0.25}
# {'loss': 0.0013, 'grad_norm': 0.1841908097267151, 'learning_rate': 4.3722222222222224e-05, 'epoch': 0.25}
# {'loss': 0.0011, 'grad_norm': 0.038547053933143616, 'learning_rate': 4.369444444444445e-05, 'epoch': 0.25}
# {'loss': 0.0017, 'grad_norm': 0.13721932470798492, 'learning_rate': 4.3666666666666666e-05, 'epoch': 0.25}
# {'loss': 0.0014, 'grad_norm': 0.042207974940538406, 'learning_rate': 4.363888888888889e-05, 'epoch': 0.25}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.3611111111111116e-05, 'epoch': 0.26}
# {'loss': 0.0023, 'grad_norm': 0.12348728626966476, 'learning_rate': 4.358333333333334e-05, 'epoch': 0.26}
# {'loss': 0.0012, 'grad_norm': 0.13131628930568695, 'learning_rate': 4.355555555555556e-05, 'epoch': 0.26}
# {'loss': 0.0023, 'grad_norm': 0.0, 'learning_rate': 4.3527777777777776e-05, 'epoch': 0.26}
# {'loss': 0.0015, 'grad_norm': 0.11486398428678513, 'learning_rate': 4.35e-05, 'epoch': 0.26}
# {'loss': 0.0017, 'grad_norm': 0.1186358705163002, 'learning_rate': 4.3472222222222225e-05, 'epoch': 0.26}
# {'loss': 0.0012, 'grad_norm': 0.03787323087453842, 'learning_rate': 4.344444444444445e-05, 'epoch': 0.26}
# {'loss': 0.0024, 'grad_norm': 0.042336542159318924, 'learning_rate': 4.341666666666667e-05, 'epoch': 0.26}
# {'loss': 0.0018, 'grad_norm': 0.04759760946035385, 'learning_rate': 4.338888888888889e-05, 'epoch': 0.26}
# {'loss': 0.0014, 'grad_norm': 0.03865566849708557, 'learning_rate': 4.3361111111111116e-05, 'epoch': 0.27}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.27}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.330555555555556e-05, 'epoch': 0.27}
# {'loss': 0.0007, 'grad_norm': 0.050221122801303864, 'learning_rate': 4.3277777777777776e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.10285180062055588, 'learning_rate': 4.325e-05, 'epoch': 0.27}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.3222222222222226e-05, 'epoch': 0.27}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.319444444444445e-05, 'epoch': 0.27}
# {'loss': 0.0014, 'grad_norm': 0.18236851692199707, 'learning_rate': 4.316666666666667e-05, 'epoch': 0.27}
# {'loss': 0.0011, 'grad_norm': 0.07521704584360123, 'learning_rate': 4.313888888888889e-05, 'epoch': 0.27}
# {'loss': 0.0017, 'grad_norm': 0.04421159625053406, 'learning_rate': 4.311111111111111e-05, 'epoch': 0.28}
# {'loss': 0.0014, 'grad_norm': 0.014514612033963203, 'learning_rate': 4.3083333333333335e-05, 'epoch': 0.28}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.305555555555556e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.14008066058158875, 'learning_rate': 4.302777777777778e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.07812408357858658, 'learning_rate': 4.3e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.2972222222222226e-05, 'epoch': 0.28}
# {'loss': 0.0008, 'grad_norm': 0.08479055017232895, 'learning_rate': 4.294444444444445e-05, 'epoch': 0.28}
# {'loss': 0.0008, 'grad_norm': 0.09254716336727142, 'learning_rate': 4.291666666666667e-05, 'epoch': 0.28}
# {'loss': 0.0011, 'grad_norm': 0.05823220685124397, 'learning_rate': 4.2888888888888886e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.055266838520765305, 'learning_rate': 4.286111111111111e-05, 'epoch': 0.29}
# {'loss': 0.0008, 'grad_norm': 0.15068425238132477, 'learning_rate': 4.2833333333333335e-05, 'epoch': 0.29}
# {'loss': 0.0015, 'grad_norm': 0.061468981206417084, 'learning_rate': 4.280555555555556e-05, 'epoch': 0.29}
# {'loss': 0.0012, 'grad_norm': 0.016827024519443512, 'learning_rate': 4.277777777777778e-05, 'epoch': 0.29}
# {'loss': 0.0018, 'grad_norm': 0.06554027646780014, 'learning_rate': 4.275e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.272222222222223e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.03649765998125076, 'learning_rate': 4.2694444444444445e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.0413297675549984, 'learning_rate': 4.266666666666667e-05, 'epoch': 0.29}
# {'loss': 0.0015, 'grad_norm': 0.04341409355401993, 'learning_rate': 4.263888888888889e-05, 'epoch': 0.29}
# {'loss': 0.0019, 'grad_norm': 0.07357226312160492, 'learning_rate': 4.261111111111111e-05, 'epoch': 0.3}
# {'loss': 0.0015, 'grad_norm': 0.05113610997796059, 'learning_rate': 4.2583333333333336e-05, 'epoch': 0.3}
# {'loss': 0.0018, 'grad_norm': 0.04925324022769928, 'learning_rate': 4.255555555555556e-05, 'epoch': 0.3}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.252777777777778e-05, 'epoch': 0.3}
# {'loss': 0.0021, 'grad_norm': 0.06540342420339584, 'learning_rate': 4.25e-05, 'epoch': 0.3}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 4.247222222222223e-05, 'epoch': 0.3}
# {'loss': 0.001, 'grad_norm': 0.04281586781144142, 'learning_rate': 4.2444444444444445e-05, 'epoch': 0.3}
# {'loss': 0.0014, 'grad_norm': 0.06244000419974327, 'learning_rate': 4.241666666666667e-05, 'epoch': 0.3}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.238888888888889e-05, 'epoch': 0.3}
# {'loss': 0.0018, 'grad_norm': 0.03944934159517288, 'learning_rate': 4.236111111111111e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.03833961486816406, 'learning_rate': 4.233333333333334e-05, 'epoch': 0.31}
# {'loss': 0.0007, 'grad_norm': 0.08535216003656387, 'learning_rate': 4.230555555555556e-05, 'epoch': 0.31}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 4.227777777777778e-05, 'epoch': 0.31}
# {'loss': 0.0013, 'grad_norm': 0.08032482117414474, 'learning_rate': 4.2250000000000004e-05, 'epoch': 0.31}
# {'loss': 0.0013, 'grad_norm': 0.050450026988983154, 'learning_rate': 4.222222222222222e-05, 'epoch': 0.31}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.2194444444444446e-05, 'epoch': 0.31}
# {'loss': 0.002, 'grad_norm': 0.0, 'learning_rate': 4.216666666666667e-05, 'epoch': 0.31}
# {'loss': 0.0013, 'grad_norm': 0.06987124681472778, 'learning_rate': 4.213888888888889e-05, 'epoch': 0.31}
# {'loss': 0.0008, 'grad_norm': 0.12393682450056076, 'learning_rate': 4.211111111111111e-05, 'epoch': 0.32}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.208333333333334e-05, 'epoch': 0.32}
# {'loss': 0.0006, 'grad_norm': 0.045835696160793304, 'learning_rate': 4.205555555555556e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.057559527456760406, 'learning_rate': 4.202777777777778e-05, 'epoch': 0.32}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 4.2e-05, 'epoch': 0.32}
# {'loss': 0.0011, 'grad_norm': 0.06771921366453171, 'learning_rate': 4.197222222222222e-05, 'epoch': 0.32}
# {'loss': 0.0013, 'grad_norm': 0.0773039385676384, 'learning_rate': 4.194444444444445e-05, 'epoch': 0.32}
# {'loss': 0.002, 'grad_norm': 0.0, 'learning_rate': 4.191666666666667e-05, 'epoch': 0.32}
# {'loss': 0.0015, 'grad_norm': 0.04042453691363335, 'learning_rate': 4.188888888888889e-05, 'epoch': 0.32}
# {'loss': 0.0018, 'grad_norm': 0.08349774032831192, 'learning_rate': 4.1861111111111114e-05, 'epoch': 0.33}
# {'loss': 0.0025, 'grad_norm': 0.0893060714006424, 'learning_rate': 4.183333333333334e-05, 'epoch': 0.33}
# {'loss': 0.0009, 'grad_norm': 0.07850281149148941, 'learning_rate': 4.1805555555555556e-05, 'epoch': 0.33}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.177777777777778e-05, 'epoch': 0.33}
# {'loss': 0.0019, 'grad_norm': 0.10468044131994247, 'learning_rate': 4.175e-05, 'epoch': 0.33}
# {'loss': 0.0006, 'grad_norm': 0.04128021001815796, 'learning_rate': 4.172222222222222e-05, 'epoch': 0.33}
# {'loss': 0.0013, 'grad_norm': 0.06694160401821136, 'learning_rate': 4.169444444444445e-05, 'epoch': 0.33}
# {'loss': 0.0012, 'grad_norm': 0.03956001251935959, 'learning_rate': 4.166666666666667e-05, 'epoch': 0.33}
# {'loss': 0.0015, 'grad_norm': 0.045021191239356995, 'learning_rate': 4.163888888888889e-05, 'epoch': 0.33}
# {'loss': 0.0009, 'grad_norm': 0.08831626921892166, 'learning_rate': 4.1611111111111114e-05, 'epoch': 0.34}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 4.158333333333333e-05, 'epoch': 0.34}
# {'loss': 0.001, 'grad_norm': 0.09190255403518677, 'learning_rate': 4.155555555555556e-05, 'epoch': 0.34}
# {'loss': 0.0013, 'grad_norm': 0.0793309360742569, 'learning_rate': 4.152777777777778e-05, 'epoch': 0.34}
# {'loss': 0.0012, 'grad_norm': 0.037790074944496155, 'learning_rate': 4.15e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.1472222222222224e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.144444444444445e-05, 'epoch': 0.34}
# {'loss': 0.0015, 'grad_norm': 0.15086966753005981, 'learning_rate': 4.141666666666667e-05, 'epoch': 0.34}
# {'loss': 0.0019, 'grad_norm': 0.07575689256191254, 'learning_rate': 4.138888888888889e-05, 'epoch': 0.34}
# {'loss': 0.002, 'grad_norm': 0.15443818271160126, 'learning_rate': 4.136111111111111e-05, 'epoch': 0.35}
# {'loss': 0.0007, 'grad_norm': 0.04162447154521942, 'learning_rate': 4.133333333333333e-05, 'epoch': 0.35}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 4.130555555555556e-05, 'epoch': 0.35}
# {'loss': 0.0021, 'grad_norm': 0.033647455275058746, 'learning_rate': 4.127777777777778e-05, 'epoch': 0.35}
# {'loss': 0.0008, 'grad_norm': 0.04182549938559532, 'learning_rate': 4.125e-05, 'epoch': 0.35}
# {'loss': 0.0008, 'grad_norm': 0.03824280947446823, 'learning_rate': 4.1222222222222224e-05, 'epoch': 0.35}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.119444444444445e-05, 'epoch': 0.35}
# {'loss': 0.0008, 'grad_norm': 0.06502489000558853, 'learning_rate': 4.116666666666667e-05, 'epoch': 0.35}
# {'loss': 0.001, 'grad_norm': 0.06707759201526642, 'learning_rate': 4.113888888888889e-05, 'epoch': 0.35}
# {'loss': 0.0015, 'grad_norm': 0.0511656180024147, 'learning_rate': 4.111111111111111e-05, 'epoch': 0.36}
# {'loss': 0.0013, 'grad_norm': 0.1068323627114296, 'learning_rate': 4.1083333333333334e-05, 'epoch': 0.36}
# {'loss': 0.0011, 'grad_norm': 0.04052092880010605, 'learning_rate': 4.105555555555556e-05, 'epoch': 0.36}
# {'loss': 0.0011, 'grad_norm': 0.07169615477323532, 'learning_rate': 4.102777777777778e-05, 'epoch': 0.36}
# {'loss': 0.001, 'grad_norm': 0.041355956345796585, 'learning_rate': 4.1e-05, 'epoch': 0.36}
# {'loss': 0.0007, 'grad_norm': 0.08740091323852539, 'learning_rate': 4.0972222222222225e-05, 'epoch': 0.36}
# {'loss': 0.0025, 'grad_norm': 0.04742320999503136, 'learning_rate': 4.094444444444445e-05, 'epoch': 0.36}
# {'loss': 0.0012, 'grad_norm': 0.06825666129589081, 'learning_rate': 4.091666666666667e-05, 'epoch': 0.36}
# {'loss': 0.0015, 'grad_norm': 0.09411068260669708, 'learning_rate': 4.088888888888889e-05, 'epoch': 0.36}
# {'loss': 0.0009, 'grad_norm': 0.04169480875134468, 'learning_rate': 4.086111111111111e-05, 'epoch': 0.37}
# {'loss': 0.0018, 'grad_norm': 0.14309115707874298, 'learning_rate': 4.0833333333333334e-05, 'epoch': 0.37}
# {'loss': 0.0017, 'grad_norm': 0.05159386619925499, 'learning_rate': 4.080555555555556e-05, 'epoch': 0.37}
# {'loss': 0.0015, 'grad_norm': 0.0702211931347847, 'learning_rate': 4.0777777777777783e-05, 'epoch': 0.37}
# {'loss': 0.0019, 'grad_norm': 0.047378815710544586, 'learning_rate': 4.075e-05, 'epoch': 0.37}
# {'loss': 0.0019, 'grad_norm': 0.08084233105182648, 'learning_rate': 4.0722222222222226e-05, 'epoch': 0.37}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 4.0694444444444444e-05, 'epoch': 0.37}
# {'loss': 0.0008, 'grad_norm': 0.04895539954304695, 'learning_rate': 4.066666666666667e-05, 'epoch': 0.37}
# {'loss': 0.0009, 'grad_norm': 0.07007797062397003, 'learning_rate': 4.063888888888889e-05, 'epoch': 0.37}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.061111111111111e-05, 'epoch': 0.38}
# {'loss': 0.0008, 'grad_norm': 0.07123572379350662, 'learning_rate': 4.0583333333333335e-05, 'epoch': 0.38}
# {'loss': 0.0009, 'grad_norm': 0.05504141002893448, 'learning_rate': 4.055555555555556e-05, 'epoch': 0.38}
# {'loss': 0.0013, 'grad_norm': 0.06095675379037857, 'learning_rate': 4.0527777777777784e-05, 'epoch': 0.38}
# {'loss': 0.001, 'grad_norm': 0.12672121822834015, 'learning_rate': 4.05e-05, 'epoch': 0.38}
# {'loss': 0.001, 'grad_norm': 0.17992176115512848, 'learning_rate': 4.047222222222222e-05, 'epoch': 0.38}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.0444444444444444e-05, 'epoch': 0.38}
# {'loss': 0.0017, 'grad_norm': 0.0926896184682846, 'learning_rate': 4.041666666666667e-05, 'epoch': 0.38}
# {'loss': 0.0012, 'grad_norm': 0.09700362384319305, 'learning_rate': 4.038888888888889e-05, 'epoch': 0.38}
# {'loss': 0.002, 'grad_norm': 0.04535103216767311, 'learning_rate': 4.036111111111111e-05, 'epoch': 0.39}
# {'loss': 0.0016, 'grad_norm': 0.0682266503572464, 'learning_rate': 4.0333333333333336e-05, 'epoch': 0.39}
# {'loss': 0.0008, 'grad_norm': 0.038797084242105484, 'learning_rate': 4.030555555555556e-05, 'epoch': 0.39}
# {'loss': 0.0017, 'grad_norm': 0.026278488337993622, 'learning_rate': 4.027777777777778e-05, 'epoch': 0.39}
# {'loss': 0.001, 'grad_norm': 0.04291273653507233, 'learning_rate': 4.025e-05, 'epoch': 0.39}
# {'loss': 0.0009, 'grad_norm': 0.05253920331597328, 'learning_rate': 4.022222222222222e-05, 'epoch': 0.39}
# {'loss': 0.0016, 'grad_norm': 0.07138396799564362, 'learning_rate': 4.0194444444444445e-05, 'epoch': 0.39}
# {'loss': 0.0007, 'grad_norm': 0.11677299439907074, 'learning_rate': 4.016666666666667e-05, 'epoch': 0.39}
# {'loss': 0.0007, 'grad_norm': 0.039412807673215866, 'learning_rate': 4.0138888888888894e-05, 'epoch': 0.39}
# {'loss': 0.0011, 'grad_norm': 0.17456912994384766, 'learning_rate': 4.011111111111111e-05, 'epoch': 0.4}
# {'loss': 0.0017, 'grad_norm': 0.06885737180709839, 'learning_rate': 4.0083333333333336e-05, 'epoch': 0.4}
# {'loss': 0.0023, 'grad_norm': 0.0896591767668724, 'learning_rate': 4.0055555555555554e-05, 'epoch': 0.4}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.002777777777778e-05, 'epoch': 0.4}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4e-05, 'epoch': 0.4}
# {'loss': 0.0008, 'grad_norm': 0.039943259209394455, 'learning_rate': 3.997222222222222e-05, 'epoch': 0.4}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.9944444444444446e-05, 'epoch': 0.4}
# {'loss': 0.0024, 'grad_norm': 0.22659587860107422, 'learning_rate': 3.991666666666667e-05, 'epoch': 0.4}
# {'loss': 0.0018, 'grad_norm': 0.02146833948791027, 'learning_rate': 3.9888888888888895e-05, 'epoch': 0.4}
# {'loss': 0.0016, 'grad_norm': 0.0390586256980896, 'learning_rate': 3.986111111111111e-05, 'epoch': 0.41}
# {'loss': 0.0018, 'grad_norm': 0.16315065324306488, 'learning_rate': 3.983333333333333e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.004394854418933392, 'learning_rate': 3.9805555555555555e-05, 'epoch': 0.41}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 3.977777777777778e-05, 'epoch': 0.41}
# {'loss': 0.0009, 'grad_norm': 0.08316035568714142, 'learning_rate': 3.9750000000000004e-05, 'epoch': 0.41}
# {'loss': 0.0013, 'grad_norm': 0.0875384584069252, 'learning_rate': 3.972222222222222e-05, 'epoch': 0.41}
# {'loss': 0.0008, 'grad_norm': 0.04494088143110275, 'learning_rate': 3.9694444444444446e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.043805934488773346, 'learning_rate': 3.966666666666667e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.03883315622806549, 'learning_rate': 3.9638888888888895e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.10061915218830109, 'learning_rate': 3.961111111111111e-05, 'epoch': 0.42}
# {'loss': 0.0011, 'grad_norm': 0.0396154560148716, 'learning_rate': 3.958333333333333e-05, 'epoch': 0.42}
# {'loss': 0.0015, 'grad_norm': 0.037973567843437195, 'learning_rate': 3.9555555555555556e-05, 'epoch': 0.42}
# {'loss': 0.0009, 'grad_norm': 0.04869091510772705, 'learning_rate': 3.952777777777778e-05, 'epoch': 0.42}
# {'loss': 0.0008, 'grad_norm': 0.07653745263814926, 'learning_rate': 3.9500000000000005e-05, 'epoch': 0.42}
# {'loss': 0.0008, 'grad_norm': 0.060963768512010574, 'learning_rate': 3.947222222222222e-05, 'epoch': 0.42}
# {'loss': 0.001, 'grad_norm': 0.11051633954048157, 'learning_rate': 3.944444444444445e-05, 'epoch': 0.42}
# {'loss': 0.0018, 'grad_norm': 0.09648024290800095, 'learning_rate': 3.941666666666667e-05, 'epoch': 0.42}
# {'loss': 0.0009, 'grad_norm': 0.050885189324617386, 'learning_rate': 3.938888888888889e-05, 'epoch': 0.42}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 3.9361111111111114e-05, 'epoch': 0.43}
# {'loss': 0.0016, 'grad_norm': 0.08474814891815186, 'learning_rate': 3.933333333333333e-05, 'epoch': 0.43}
# {'loss': 0.0014, 'grad_norm': 0.04028906300663948, 'learning_rate': 3.9305555555555556e-05, 'epoch': 0.43}
# {'loss': 0.0015, 'grad_norm': 0.04284052550792694, 'learning_rate': 3.927777777777778e-05, 'epoch': 0.43}
# {'loss': 0.0031, 'grad_norm': 0.19113048911094666, 'learning_rate': 3.9250000000000005e-05, 'epoch': 0.43}
# {'loss': 0.0015, 'grad_norm': 0.0843200609087944, 'learning_rate': 3.922222222222223e-05, 'epoch': 0.43}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 3.919444444444445e-05, 'epoch': 0.43}
# {'loss': 0.001, 'grad_norm': 0.04856843873858452, 'learning_rate': 3.9166666666666665e-05, 'epoch': 0.43}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.913888888888889e-05, 'epoch': 0.43}
# {'loss': 0.0018, 'grad_norm': 0.04426782950758934, 'learning_rate': 3.9111111111111115e-05, 'epoch': 0.44}
# {'loss': 0.0009, 'grad_norm': 0.14721494913101196, 'learning_rate': 3.908333333333333e-05, 'epoch': 0.44}
# {'loss': 0.0017, 'grad_norm': 0.08220881223678589, 'learning_rate': 3.905555555555556e-05, 'epoch': 0.44}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 3.902777777777778e-05, 'epoch': 0.44}
# {'loss': 0.0013, 'grad_norm': 0.03823595494031906, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.44}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.8972222222222224e-05, 'epoch': 0.44}
# {'loss': 0.0014, 'grad_norm': 0.02277163229882717, 'learning_rate': 3.894444444444444e-05, 'epoch': 0.44}
# {'loss': 0.0017, 'grad_norm': 0.07516634464263916, 'learning_rate': 3.8916666666666666e-05, 'epoch': 0.44}
# {'loss': 0.0016, 'grad_norm': 0.08866998553276062, 'learning_rate': 3.888888888888889e-05, 'epoch': 0.44}
# {'loss': 0.0004, 'grad_norm': 0.0148695083335042, 'learning_rate': 3.8861111111111115e-05, 'epoch': 0.45}
# {'loss': 0.001, 'grad_norm': 0.08202554285526276, 'learning_rate': 3.883333333333333e-05, 'epoch': 0.45}
# {'loss': 0.0011, 'grad_norm': 0.06699702143669128, 'learning_rate': 3.880555555555556e-05, 'epoch': 0.45}
# {'loss': 0.0017, 'grad_norm': 0.18019503355026245, 'learning_rate': 3.877777777777778e-05, 'epoch': 0.45}
# {'loss': 0.001, 'grad_norm': 0.07293690741062164, 'learning_rate': 3.875e-05, 'epoch': 0.45}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.8722222222222225e-05, 'epoch': 0.45}
# {'loss': 0.0011, 'grad_norm': 0.1676173210144043, 'learning_rate': 3.869444444444444e-05, 'epoch': 0.45}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 3.866666666666667e-05, 'epoch': 0.45}
# {'loss': 0.0015, 'grad_norm': 0.08113617449998856, 'learning_rate': 3.863888888888889e-05, 'epoch': 0.45}
# {'loss': 0.0007, 'grad_norm': 0.07531172782182693, 'learning_rate': 3.8611111111111116e-05, 'epoch': 0.46}
# {'loss': 0.0005, 'grad_norm': 0.04475345462560654, 'learning_rate': 3.8583333333333334e-05, 'epoch': 0.46}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 3.855555555555556e-05, 'epoch': 0.46}
# {'loss': 0.0016, 'grad_norm': 0.11691270768642426, 'learning_rate': 3.8527777777777776e-05, 'epoch': 0.46}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 3.85e-05, 'epoch': 0.46}
# {'loss': 0.0016, 'grad_norm': 0.09244947880506516, 'learning_rate': 3.8472222222222225e-05, 'epoch': 0.46}
# {'loss': 0.0023, 'grad_norm': 0.07102634012699127, 'learning_rate': 3.844444444444444e-05, 'epoch': 0.46}
# {'loss': 0.0009, 'grad_norm': 0.04655381292104721, 'learning_rate': 3.841666666666667e-05, 'epoch': 0.46}
# {'loss': 0.0019, 'grad_norm': 0.07895347476005554, 'learning_rate': 3.838888888888889e-05, 'epoch': 0.46}
# {'loss': 0.0013, 'grad_norm': 0.04453619569540024, 'learning_rate': 3.836111111111112e-05, 'epoch': 0.47}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 3.8333333333333334e-05, 'epoch': 0.47}
# {'loss': 0.0024, 'grad_norm': 0.11986570060253143, 'learning_rate': 3.830555555555555e-05, 'epoch': 0.47}
# {'loss': 0.0012, 'grad_norm': 0.07224680483341217, 'learning_rate': 3.827777777777778e-05, 'epoch': 0.47}
# {'loss': 0.0009, 'grad_norm': 0.06042267382144928, 'learning_rate': 3.825e-05, 'epoch': 0.47}
# {'loss': 0.0012, 'grad_norm': 0.07614438980817795, 'learning_rate': 3.8222222222222226e-05, 'epoch': 0.47}
# {'loss': 0.0018, 'grad_norm': 0.04382104054093361, 'learning_rate': 3.8194444444444444e-05, 'epoch': 0.47}
# {'loss': 0.0017, 'grad_norm': 0.262686163187027, 'learning_rate': 3.816666666666667e-05, 'epoch': 0.47}
# {'loss': 0.0011, 'grad_norm': 0.08192441612482071, 'learning_rate': 3.813888888888889e-05, 'epoch': 0.47}
# {'loss': 0.0016, 'grad_norm': 0.07568581402301788, 'learning_rate': 3.811111111111112e-05, 'epoch': 0.48}
# {'loss': 0.001, 'grad_norm': 0.03155767545104027, 'learning_rate': 3.8083333333333335e-05, 'epoch': 0.48}
# {'loss': 0.0009, 'grad_norm': 0.03995091840624809, 'learning_rate': 3.805555555555555e-05, 'epoch': 0.48}
# {'loss': 0.0019, 'grad_norm': 0.11653417348861694, 'learning_rate': 3.802777777777778e-05, 'epoch': 0.48}
# {'loss': 0.0019, 'grad_norm': 0.04985712468624115, 'learning_rate': 3.8e-05, 'epoch': 0.48}
# {'loss': 0.0013, 'grad_norm': 0.09945119917392731, 'learning_rate': 3.797222222222223e-05, 'epoch': 0.48}
# {'loss': 0.001, 'grad_norm': 0.07538573443889618, 'learning_rate': 3.7944444444444444e-05, 'epoch': 0.48}
# {'loss': 0.0014, 'grad_norm': 0.04099046811461449, 'learning_rate': 3.791666666666667e-05, 'epoch': 0.48}
# {'loss': 0.0008, 'grad_norm': 0.044568922370672226, 'learning_rate': 3.7888888888888894e-05, 'epoch': 0.48}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 3.786111111111111e-05, 'epoch': 0.49}
# {'loss': 0.0005, 'grad_norm': 0.04198179394006729, 'learning_rate': 3.7833333333333336e-05, 'epoch': 0.49}
# {'loss': 0.0009, 'grad_norm': 0.06622979044914246, 'learning_rate': 3.7805555555555554e-05, 'epoch': 0.49}
# {'loss': 0.0011, 'grad_norm': 0.01841897889971733, 'learning_rate': 3.777777777777778e-05, 'epoch': 0.49}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.775e-05, 'epoch': 0.49}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 3.772222222222223e-05, 'epoch': 0.49}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 3.769444444444445e-05, 'epoch': 0.49}
# {'loss': 0.0013, 'grad_norm': 0.21403302252292633, 'learning_rate': 3.766666666666667e-05, 'epoch': 0.49}
# {'loss': 0.0009, 'grad_norm': 0.08062561601400375, 'learning_rate': 3.763888888888889e-05, 'epoch': 0.49}
# {'loss': 0.0016, 'grad_norm': 0.05541934445500374, 'learning_rate': 3.761111111111111e-05, 'epoch': 0.5}
# {'loss': 0.0018, 'grad_norm': 0.029500432312488556, 'learning_rate': 3.7583333333333337e-05, 'epoch': 0.5}
# {'loss': 0.0016, 'grad_norm': 0.11964887380599976, 'learning_rate': 3.7555555555555554e-05, 'epoch': 0.5}
# {'loss': 0.0014, 'grad_norm': 0.08282154053449631, 'learning_rate': 3.752777777777778e-05, 'epoch': 0.5}
# {'loss': 0.0008, 'grad_norm': 0.07594871520996094, 'learning_rate': 3.7500000000000003e-05, 'epoch': 0.5}
# {'loss': 0.0014, 'grad_norm': 0.12902916967868805, 'learning_rate': 3.747222222222223e-05, 'epoch': 0.5}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 3.7444444444444446e-05, 'epoch': 0.5}
# {'loss': 0.0017, 'grad_norm': 0.0, 'learning_rate': 3.7416666666666664e-05, 'epoch': 0.5}
# {'loss': 0.0016, 'grad_norm': 0.13286742568016052, 'learning_rate': 3.738888888888889e-05, 'epoch': 0.5}
# {'loss': 0.0015, 'grad_norm': 0.22465424239635468, 'learning_rate': 3.736111111111111e-05, 'epoch': 0.51}
# {'loss': 0.0012, 'grad_norm': 0.08488139510154724, 'learning_rate': 3.733333333333334e-05, 'epoch': 0.51}
# {'loss': 0.001, 'grad_norm': 0.043353717774152756, 'learning_rate': 3.7305555555555555e-05, 'epoch': 0.51}
# {'loss': 0.0005, 'grad_norm': 0.10203228145837784, 'learning_rate': 3.727777777777778e-05, 'epoch': 0.51}
# {'loss': 0.0012, 'grad_norm': 0.07695791870355606, 'learning_rate': 3.7250000000000004e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.07240952551364899, 'learning_rate': 3.722222222222222e-05, 'epoch': 0.51}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.7194444444444447e-05, 'epoch': 0.51}
# {'loss': 0.0008, 'grad_norm': 0.06673380732536316, 'learning_rate': 3.7166666666666664e-05, 'epoch': 0.51}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 3.713888888888889e-05, 'epoch': 0.51}
# {'loss': 0.0013, 'grad_norm': 0.08131293952465057, 'learning_rate': 3.7111111111111113e-05, 'epoch': 0.52}
# {'loss': 0.0012, 'grad_norm': 0.060184724628925323, 'learning_rate': 3.708333333333334e-05, 'epoch': 0.52}
# ...
# {'loss': 0.0003, 'grad_norm': 0.05327786132693291, 'learning_rate': 1.777777777777778e-06, 'epoch': 1.93}
# {'loss': 0.0014, 'grad_norm': 0.06640498340129852, 'learning_rate': 1.7500000000000002e-06, 'epoch': 1.93}
# {'loss': 0.0002, 'grad_norm': 0.056329838931560516, 'learning_rate': 1.7222222222222222e-06, 'epoch': 1.93}
# {'loss': 0.0007, 'grad_norm': 0.14182588458061218, 'learning_rate': 1.6944444444444446e-06, 'epoch': 1.93}
# {'loss': 0.0003, 'grad_norm': 0.13183742761611938, 'learning_rate': 1.6666666666666667e-06, 'epoch': 1.93}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 1.638888888888889e-06, 'epoch': 1.93}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 1.6111111111111111e-06, 'epoch': 1.94}
# {'loss': 0.0007, 'grad_norm': 0.0701216459274292, 'learning_rate': 1.5833333333333336e-06, 'epoch': 1.94}
# {'loss': 0.0002, 'grad_norm': 0.0, 'learning_rate': 1.5555555555555556e-06, 'epoch': 1.94}
# {'loss': 0.0014, 'grad_norm': 0.05308859050273895, 'learning_rate': 1.5277777777777778e-06, 'epoch': 1.94}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 1.5e-06, 'epoch': 1.94}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 1.4722222222222223e-06, 'epoch': 1.94}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 1.4444444444444445e-06, 'epoch': 1.94}
# {'loss': 0.0016, 'grad_norm': 0.1504010409116745, 'learning_rate': 1.4166666666666667e-06, 'epoch': 1.94}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 1.388888888888889e-06, 'epoch': 1.94}
# {'loss': 0.0005, 'grad_norm': 0.10099129378795624, 'learning_rate': 1.3611111111111112e-06, 'epoch': 1.95}
# {'loss': 0.0009, 'grad_norm': 0.10925746709108353, 'learning_rate': 1.3333333333333334e-06, 'epoch': 1.95}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 1.3055555555555556e-06, 'epoch': 1.95}
# {'loss': 0.0008, 'grad_norm': 0.07199469208717346, 'learning_rate': 1.2777777777777779e-06, 'epoch': 1.95}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 1.25e-06, 'epoch': 1.95}
# {'loss': 0.0004, 'grad_norm': 0.05723613128066063, 'learning_rate': 1.2222222222222223e-06, 'epoch': 1.95}
# {'loss': 0.0004, 'grad_norm': 0.10506264120340347, 'learning_rate': 1.1944444444444446e-06, 'epoch': 1.95}
# {'loss': 0.0001, 'grad_norm': 0.023269077762961388, 'learning_rate': 1.1666666666666668e-06, 'epoch': 1.95}
# {'loss': 0.0005, 'grad_norm': 0.05040527507662773, 'learning_rate': 1.138888888888889e-06, 'epoch': 1.95}
# {'loss': 0.0001, 'grad_norm': 0.0, 'learning_rate': 1.1111111111111112e-06, 'epoch': 1.96}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 1.0833333333333335e-06, 'epoch': 1.96}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 1.0555555555555557e-06, 'epoch': 1.96}
# {'loss': 0.0006, 'grad_norm': 0.09364396333694458, 'learning_rate': 1.027777777777778e-06, 'epoch': 1.96}
# {'loss': 0.0008, 'grad_norm': 0.07229796797037125, 'learning_rate': 1.0000000000000002e-06, 'epoch': 1.96}
# {'loss': 0.0012, 'grad_norm': 0.09163890779018402, 'learning_rate': 9.722222222222222e-07, 'epoch': 1.96}
# {'loss': 0.0002, 'grad_norm': 0.0553160235285759, 'learning_rate': 9.444444444444445e-07, 'epoch': 1.96}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 9.166666666666667e-07, 'epoch': 1.96}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 8.88888888888889e-07, 'epoch': 1.96}
# {'loss': 0.0003, 'grad_norm': 0.09876000136137009, 'learning_rate': 8.611111111111111e-07, 'epoch': 1.97}
# {'loss': 0.0004, 'grad_norm': 0.07331855595111847, 'learning_rate': 8.333333333333333e-07, 'epoch': 1.97}
# {'loss': 0.0004, 'grad_norm': 0.05339575558900833, 'learning_rate': 8.055555555555556e-07, 'epoch': 1.97}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 7.777777777777778e-07, 'epoch': 1.97}
# {'loss': 0.0008, 'grad_norm': 0.055298689752817154, 'learning_rate': 7.5e-07, 'epoch': 1.97}
# {'loss': 0.0005, 'grad_norm': 0.05194449424743652, 'learning_rate': 7.222222222222222e-07, 'epoch': 1.97}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 6.944444444444445e-07, 'epoch': 1.97}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 6.666666666666667e-07, 'epoch': 1.97}
# {'loss': 0.0001, 'grad_norm': 0.0, 'learning_rate': 6.388888888888889e-07, 'epoch': 1.97}
# {'loss': 0.0005, 'grad_norm': 0.07064179331064224, 'learning_rate': 6.111111111111112e-07, 'epoch': 1.98}
# {'loss': 0.0001, 'grad_norm': 0.0, 'learning_rate': 5.833333333333334e-07, 'epoch': 1.98}
# {'loss': 0.0007, 'grad_norm': 0.11815683543682098, 'learning_rate': 5.555555555555556e-07, 'epoch': 1.98}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 5.277777777777779e-07, 'epoch': 1.98}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 5.000000000000001e-07, 'epoch': 1.98}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 4.7222222222222226e-07, 'epoch': 1.98}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.444444444444445e-07, 'epoch': 1.98}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 4.1666666666666667e-07, 'epoch': 1.98}
# {'loss': 0.0011, 'grad_norm': 0.06018642708659172, 'learning_rate': 3.888888888888889e-07, 'epoch': 1.98}
# {'loss': 0.0005, 'grad_norm': 0.06596384942531586, 'learning_rate': 3.611111111111111e-07, 'epoch': 1.99}
# {'loss': 0.0003, 'grad_norm': 0.051908306777477264, 'learning_rate': 3.3333333333333335e-07, 'epoch': 1.99}
# {'loss': 0.0007, 'grad_norm': 0.05795947089791298, 'learning_rate': 3.055555555555556e-07, 'epoch': 1.99}
# {'loss': 0.0009, 'grad_norm': 0.07564269006252289, 'learning_rate': 2.777777777777778e-07, 'epoch': 1.99}
# {'loss': 0.0005, 'grad_norm': 0.06225832179188728, 'learning_rate': 2.5000000000000004e-07, 'epoch': 1.99}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 2.2222222222222224e-07, 'epoch': 1.99}
# {'loss': 0.0002, 'grad_norm': 0.05370550602674484, 'learning_rate': 1.9444444444444445e-07, 'epoch': 1.99}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 1.6666666666666668e-07, 'epoch': 1.99}
# {'loss': 0.0012, 'grad_norm': 0.06160281226038933, 'learning_rate': 1.388888888888889e-07, 'epoch': 1.99}
# {'loss': 0.0008, 'grad_norm': 0.050654035061597824, 'learning_rate': 1.1111111111111112e-07, 'epoch': 2.0}
# {'loss': 0.0008, 'grad_norm': 0.1556343287229538, 'learning_rate': 8.333333333333334e-08, 'epoch': 2.0}
# {'loss': 0.0008, 'grad_norm': 0.057858314365148544, 'learning_rate': 5.555555555555556e-08, 'epoch': 2.0}
# {'loss': 0.0003, 'grad_norm': 0.10555624216794968, 'learning_rate': 2.777777777777778e-08, 'epoch': 2.0}
# {'loss': 0.0002, 'grad_norm': 0.06301353871822357, 'learning_rate': 0.0, 'epoch': 2.0}
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'eval_loss': 0.0008401022059842944, 'eval_runtime': 2.7041, 'eval_samples_per_second': 1479.24, 'eval_steps_per_second': 36.981, 'epoch': 2.0}
# {'train_runtime': 805.0811, 'train_samples_per_second': 894.32, 'train_steps_per_second': 22.358, 'train_loss': 0.0010728251771219624, 'epoch': 2.0}
# Processing models:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing batches:   0%|          | 0/25000 [00:00<?, ?it/s]
#   0%|          | 0/18000 [00:00<?, ?it/s]
# {'loss': 0.0033, 'grad_norm': 0.364479660987854, 'learning_rate': 4.997222222222223e-05, 'epoch': 0.0}
# {'loss': 0.0033, 'grad_norm': 0.41817399859428406, 'learning_rate': 4.994444444444445e-05, 'epoch': 0.0}
# {'loss': 0.0026, 'grad_norm': 0.3181237578392029, 'learning_rate': 4.991666666666667e-05, 'epoch': 0.0}
# {'loss': 0.0022, 'grad_norm': 0.5083526968955994, 'learning_rate': 4.9888888888888894e-05, 'epoch': 0.0}
# {'loss': 0.0025, 'grad_norm': 0.08824583888053894, 'learning_rate': 4.986111111111111e-05, 'epoch': 0.01}
# {'loss': 0.0007, 'grad_norm': 0.17542624473571777, 'learning_rate': 4.9833333333333336e-05, 'epoch': 0.01}
# {'loss': 0.0019, 'grad_norm': 0.24332721531391144, 'learning_rate': 4.9805555555555554e-05, 'epoch': 0.01}
# {'loss': 0.0029, 'grad_norm': 0.2048766314983368, 'learning_rate': 4.977777777777778e-05, 'epoch': 0.01}
# {'loss': 0.002, 'grad_norm': 0.25105762481689453, 'learning_rate': 4.975e-05, 'epoch': 0.01}
# {'loss': 0.0014, 'grad_norm': 0.180793896317482, 'learning_rate': 4.972222222222223e-05, 'epoch': 0.01}
# {'loss': 0.001, 'grad_norm': 0.08681149035692215, 'learning_rate': 4.969444444444445e-05, 'epoch': 0.01}
# {'loss': 0.0014, 'grad_norm': 0.27910465002059937, 'learning_rate': 4.966666666666667e-05, 'epoch': 0.01}
# {'loss': 0.0017, 'grad_norm': 0.5513052940368652, 'learning_rate': 4.963888888888889e-05, 'epoch': 0.01}
# {'loss': 0.0018, 'grad_norm': 0.3198869228363037, 'learning_rate': 4.961111111111111e-05, 'epoch': 0.02}
# {'loss': 0.002, 'grad_norm': 0.09677956998348236, 'learning_rate': 4.958333333333334e-05, 'epoch': 0.02}
# {'loss': 0.0015, 'grad_norm': 0.033377159386873245, 'learning_rate': 4.955555555555556e-05, 'epoch': 0.02}
# {'loss': 0.0015, 'grad_norm': 0.04364548623561859, 'learning_rate': 4.952777777777778e-05, 'epoch': 0.02}
# {'loss': 0.0012, 'grad_norm': 0.19644539058208466, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.02}
# {'loss': 0.002, 'grad_norm': 0.15375801920890808, 'learning_rate': 4.947222222222223e-05, 'epoch': 0.02}
# {'loss': 0.001, 'grad_norm': 0.156820148229599, 'learning_rate': 4.9444444444444446e-05, 'epoch': 0.02}
# {'loss': 0.0016, 'grad_norm': 0.060424137860536575, 'learning_rate': 4.9416666666666664e-05, 'epoch': 0.02}
# {'loss': 0.0016, 'grad_norm': 0.12116573750972748, 'learning_rate': 4.938888888888889e-05, 'epoch': 0.02}
# {'loss': 0.0016, 'grad_norm': 0.062132827937603, 'learning_rate': 4.936111111111111e-05, 'epoch': 0.03}
# {'loss': 0.0018, 'grad_norm': 0.09205898642539978, 'learning_rate': 4.933333333333334e-05, 'epoch': 0.03}
# {'loss': 0.0014, 'grad_norm': 0.19259275496006012, 'learning_rate': 4.930555555555556e-05, 'epoch': 0.03}
# {'loss': 0.0024, 'grad_norm': 0.22748592495918274, 'learning_rate': 4.927777777777778e-05, 'epoch': 0.03}
# {'loss': 0.003, 'grad_norm': 0.0792999193072319, 'learning_rate': 4.9250000000000004e-05, 'epoch': 0.03}
# {'loss': 0.0015, 'grad_norm': 0.12575295567512512, 'learning_rate': 4.922222222222222e-05, 'epoch': 0.03}
# {'loss': 0.0008, 'grad_norm': 0.02073352038860321, 'learning_rate': 4.919444444444445e-05, 'epoch': 0.03}
# {'loss': 0.0022, 'grad_norm': 0.13612186908721924, 'learning_rate': 4.9166666666666665e-05, 'epoch': 0.03}
# {'loss': 0.0016, 'grad_norm': 0.13480398058891296, 'learning_rate': 4.913888888888889e-05, 'epoch': 0.03}
# {'loss': 0.0024, 'grad_norm': 0.11445626616477966, 'learning_rate': 4.9111111111111114e-05, 'epoch': 0.04}
# {'loss': 0.0014, 'grad_norm': 0.05859357491135597, 'learning_rate': 4.908333333333334e-05, 'epoch': 0.04}
# {'loss': 0.0013, 'grad_norm': 0.1082535982131958, 'learning_rate': 4.905555555555556e-05, 'epoch': 0.04}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 trainer.args.num_train_epochs = stage['epochs']
#      11 trainer.args.learning_rate = stage['learning_rate']
# ---> 12 trainer.train()
#      13 format_string = format_string_base + str(i) + ".obj"
#      14 generate_meshes(model, obj_dir, result_dir, format_string, device,
#      15     batch_size, resolution=100, context_size=200)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:2164, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2162         hf_hub_utils.enable_progress_bars()
#    2163 else:
# -> 2164     return inner_training_loop(
#    2165         args=args,
#    2166         resume_from_checkpoint=resume_from_checkpoint,
#    2167         trial=trial,
#    2168         ignore_keys_for_eval=ignore_keys_for_eval,
#    2169     )
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:2473, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2471 update_step += 1
#    2472 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2473 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches)
#    2474 for i, inputs in enumerate(batch_samples):
#    2475     step += 1
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:5130, in Trainer.get_batch_samples(self, epoch_iterator, num_batches)
#    5128 for _ in range(num_batches):
#    5129     try:
# -> 5130         batch_samples += [next(epoch_iterator)]
#    5131     except StopIteration:
#    5132         break
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\accelerate\data_loader.py:563, in DataLoaderShard.__iter__(self)
#     561     current_batch = send_to_device(current_batch, self.device, non_blocking=self._non_blocking)
#     562 self._update_state_dict()
# --> 563 next_batch = next(dataloader_iter)
#     564 if batch_index >= self.skip_batches:
#     565     yield current_batch
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\_prog\vm_shared\attention-sdf\src\models\dataset.py:31, in LazySampleDataset.__getitem__(self, index)
#      27 loader, batch_index, sample_index = self._sample_indices_map(index)
#      28 # context shape: [num_samples, 4]
#      29 # input_data shape: [1, 3]
#      30 # label_data shape: 1
# ---> 31 context, input_data, label_data = loader.get_sample(batch_index, sample_index)
#      33 # input_data shape: [1, 3]
#      34 # label_data shape: [1, 1]
#      35 input_data = input_data.reshape(1, 3)
#
# File c:\_prog\vm_shared\attention-sdf\src\data\lazy_sample_loader.py:57, in LazySampleLoader.get_sample(self, batch_index, sample_index)
#      56 def get_sample(self, batch_index, sample_index) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
# ---> 57     context = self.file[f'batch_{batch_index}/context'][:]
#      58     input_data = self.file[f'batch_{batch_index}/input'][sample_index]
#      59     label_data = self.file[f'batch_{batch_index}/labels'][sample_index]
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\h5py\_hl\dataset.py:781, in Dataset.__getitem__(self, args, new_dtype)
#     779 if self._fast_read_ok and (new_dtype is None):
#     780     try:
# --> 781         return self._fast_reader.read(args)
#     782     except TypeError:
#     783         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
import json
from dataclasses import asdict

current_date = datetime.now().strftime("%Y-%m-%d")
model_name = f"{current_date}-model"
config_name = f"{current_date}-config.json"
trainer.save_model(result_dir / model_name)

with open(result_dir / config_name, 'w') as f:
    json.dump(asdict(config), f)
