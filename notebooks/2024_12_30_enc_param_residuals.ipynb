# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# %load_ext autoreload
# %autoreload 2

# %%
from src.models.modules import *
from src.models.loss import L1_epsilon_lambda
from dataclasses import dataclass
import torch

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

@dataclass
class SDFTransformerConfig:
    dim_context: int
    dim_input: int
    num_outputs: int
    dim_output: int
    delta: float = 0.1
    dim_hidden: int = 128
    num_inds: int = 64
    num_heads: int = 8

class SDFTransformer(nn.Module):
    def __init__(self, config: SDFTransformerConfig):
        super(SDFTransformer, self).__init__()
        self.config = config
        self.epsilon = None
        self.lambdaa = None
        self.proj1 = nn.Linear(config.dim_input, config.dim_hidden)
        self.proj2 = nn.Linear(config.dim_context, config.dim_hidden)
        self.cross = MAB(config.dim_hidden, config.dim_hidden, config.dim_hidden, config.num_heads)

        self.sab1 = SAB(config.dim_hidden, config.dim_hidden, config.num_heads)
        self.silu1 = nn.SiLU()
        self.alpha1 = nn.Parameter(torch.tensor(0.5))
        self.sab2 = SAB(config.dim_hidden, config.dim_hidden, config.num_heads)
        self.silu2 = nn.SiLU()
        self.alpha2 = nn.Parameter(torch.tensor(0.5))
        self.sab3 = SAB(config.dim_hidden, config.dim_hidden, config.num_heads)
        self.silu3 = nn.SiLU()
        self.alpha3 = nn.Parameter(torch.tensor(0.5))
        self.sab4 = SAB(config.dim_hidden, config.dim_hidden, config.num_heads)
        self.silu4 = nn.SiLU()
        self.alpha4 = nn.Parameter(torch.tensor(0.5))
        self.final = nn.Sequential(
            PMA(config.dim_hidden, config.num_heads, config.num_outputs),
            nn.SiLU(),
            nn.Linear(config.dim_hidden, config.dim_output),
            nn.Tanh()
        )

    def forward(self, context: torch.Tensor, x: torch.Tensor, labels: torch.Tensor = None):
        x = x.expand(-1, context.shape[1], -1)  # [batch_size, context_size, dim_input]
        x = self.proj1(x)                       # [batch_size, context_size, dim_hidden]
        context = self.proj2(context)           # [batch_size, context_size, dim_hidden]
        y = self.cross(x, context)              # [batch_size, context_size, dim_hidden]

        residual = y
        y = self.alpha1 * self.sab1(y) + (1.0 - self.alpha1) * residual
        y = self.silu1(y)              # [batch_size, context_size, dim_hidden]

        residual = y
        y = self.alpha2 * self.sab2(y) + (1.0 - self.alpha2) * residual
        y = self.silu2(y)              # [batch_size, context_size, dim_hidden]

        residual = y
        y = self.alpha3 * self.sab3(y) + (1.0 - self.alpha3) * residual
        y = self.silu3(y)              # [batch_size, context_size, dim_hidden]

        residual = y
        y = self.alpha4 * self.sab4(y) + (1.0 - self.alpha4) * residual
        y = self.silu4(y)              # [batch_size, context_size, dim_hidden]

        y = self.final(y)              # [batch_size, num_outputs, dim_output]

        loss = None
        if labels is not None:
            loss = L1_epsilon_lambda(y, labels, self.epsilon, self.lambdaa, self.config.delta)
        return {'loss': loss, 'logits': y}

config = SDFTransformerConfig(dim_context=4, dim_input=3, num_outputs=1, dim_output=1)
model = SDFTransformer(config).to(device)
print(device)
# Out:
# cuda

# %%
from src.models.dataset import LazySampleDataset
from pathlib import Path

project_dir = Path(os.path.abspath('')).resolve().parent
procesed_dir = project_dir / 'data' / 'processed'

train_files = list(procesed_dir.rglob('*_train.hdf5'))
val_files = list(procesed_dir.rglob('*_val.hdf5'))

train_dataset = LazySampleDataset(train_files)
val_dataset = LazySampleDataset(val_files)

# %%
from src.data.load_data import get_results_dir
from datetime import datetime

notebook_name = '2024_12_30_enc_param_residuals'
current_date = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
folder_name = f"{notebook_name}-{current_date}"
result_dir = get_results_dir() / folder_name
result_dir.mkdir(parents=True, exist_ok=True)
print(result_dir)
# Out:
# C:\_prog\vm_shared\attention-sdf\results\2024_12_30_enc_param_residuals-2024-12-30-14-04-17

# %%
from transformers import Trainer, TrainingArguments

batch_size = 40
training_args = TrainingArguments(
    output_dir=result_dir / "results",
    eval_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=1,
    logging_dir=result_dir / "logs",
    logging_steps=10,
    weight_decay=0.01,
    save_total_limit=3,
    seed=42
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

curriculum_schedule = [
    {"epochs": 2, "epsilon": 0.02,   "lambda": 0.0,  'learning_rate': 5e-5},
    {"epochs": 2, "epsilon": 0.0075, "lambda": 0.15, 'learning_rate': 4e-5},
    {"epochs": 2, "epsilon": 0.004,  "lambda": 0.3,  'learning_rate': 3e-5},
    {"epochs": 2, "epsilon": 0.002,  "lambda": 0.4,  'learning_rate': 2e-5},
    {"epochs": 2, "epsilon": 0.0,    "lambda": 0.5,  'learning_rate': 1e-5}
]

# %%
from src.visualization.generate_mesh import generate_meshes
from src.data.load_data import get_data_dir

obj_dir = get_data_dir() / 'intermediate'
format_string_base = "{name}-" + current_date + "-curriculum-"

for i, stage in enumerate(curriculum_schedule):
    model.epsilon = stage['epsilon']
    model.lambdaa = stage['lambda']
    trainer.args.num_train_epochs = stage['epochs']
    trainer.args.learning_rate = stage['learning_rate']
    trainer.train()
    format_string = format_string_base + str(i) + ".obj"
    generate_meshes(model, obj_dir, result_dir, format_string, device,
        batch_size, resolution=100, context_size=200)
train_dataset.close()
val_dataset.close()
# Out:
#   0%|          | 0/18000 [00:00<?, ?it/s]
# {'loss': 0.02, 'grad_norm': 0.03441108763217926, 'learning_rate': 4.997222222222223e-05, 'epoch': 0.0}
# {'loss': 0.0043, 'grad_norm': 0.0, 'learning_rate': 4.994444444444445e-05, 'epoch': 0.0}
# {'loss': 0.0045, 'grad_norm': 0.034565072506666183, 'learning_rate': 4.991666666666667e-05, 'epoch': 0.0}
# {'loss': 0.0017, 'grad_norm': 0.0343022495508194, 'learning_rate': 4.9888888888888894e-05, 'epoch': 0.0}
# {'loss': 0.0028, 'grad_norm': 0.03432334214448929, 'learning_rate': 4.986111111111111e-05, 'epoch': 0.01}
# {'loss': 0.0023, 'grad_norm': 0.0, 'learning_rate': 4.9833333333333336e-05, 'epoch': 0.01}
# {'loss': 0.0024, 'grad_norm': 0.0007139004301279783, 'learning_rate': 4.9805555555555554e-05, 'epoch': 0.01}
# {'loss': 0.0049, 'grad_norm': 0.03436659276485443, 'learning_rate': 4.977777777777778e-05, 'epoch': 0.01}
# {'loss': 0.0022, 'grad_norm': 0.034312210977077484, 'learning_rate': 4.975e-05, 'epoch': 0.01}
# {'loss': 0.0033, 'grad_norm': 0.1030256375670433, 'learning_rate': 4.972222222222223e-05, 'epoch': 0.01}
# {'loss': 0.003, 'grad_norm': 0.03440770134329796, 'learning_rate': 4.969444444444445e-05, 'epoch': 0.01}
# {'loss': 0.0031, 'grad_norm': 0.06867875903844833, 'learning_rate': 4.966666666666667e-05, 'epoch': 0.01}
# {'loss': 0.003, 'grad_norm': 0.03431692346930504, 'learning_rate': 4.963888888888889e-05, 'epoch': 0.01}
# {'loss': 0.0028, 'grad_norm': 0.03434619680047035, 'learning_rate': 4.961111111111111e-05, 'epoch': 0.02}
# {'loss': 0.0033, 'grad_norm': 0.000579613377340138, 'learning_rate': 4.958333333333334e-05, 'epoch': 0.02}
# {'loss': 0.0035, 'grad_norm': 0.03436827287077904, 'learning_rate': 4.955555555555556e-05, 'epoch': 0.02}
# {'loss': 0.003, 'grad_norm': 0.034318242222070694, 'learning_rate': 4.952777777777778e-05, 'epoch': 0.02}
# {'loss': 0.0038, 'grad_norm': 0.03436553105711937, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.02}
# {'loss': 0.0031, 'grad_norm': 0.03438285365700722, 'learning_rate': 4.947222222222223e-05, 'epoch': 0.02}
# {'loss': 0.0029, 'grad_norm': 0.03432155400514603, 'learning_rate': 4.9444444444444446e-05, 'epoch': 0.02}
# {'loss': 0.0039, 'grad_norm': 0.0012165189255028963, 'learning_rate': 4.9416666666666664e-05, 'epoch': 0.02}
# {'loss': 0.0024, 'grad_norm': 0.0014033924089744687, 'learning_rate': 4.938888888888889e-05, 'epoch': 0.02}
# {'loss': 0.0035, 'grad_norm': 0.06864933669567108, 'learning_rate': 4.936111111111111e-05, 'epoch': 0.03}
# {'loss': 0.0035, 'grad_norm': 0.06868027150630951, 'learning_rate': 4.933333333333334e-05, 'epoch': 0.03}
# {'loss': 0.0039, 'grad_norm': 0.13733749091625214, 'learning_rate': 4.930555555555556e-05, 'epoch': 0.03}
# {'loss': 0.0047, 'grad_norm': 0.0021519744768738747, 'learning_rate': 4.927777777777778e-05, 'epoch': 0.03}
# {'loss': 0.0041, 'grad_norm': 0.13752232491970062, 'learning_rate': 4.9250000000000004e-05, 'epoch': 0.03}
# {'loss': 0.0031, 'grad_norm': 0.0014203430619090796, 'learning_rate': 4.922222222222222e-05, 'epoch': 0.03}
# {'loss': 0.0036, 'grad_norm': 0.10306350141763687, 'learning_rate': 4.919444444444445e-05, 'epoch': 0.03}
# {'loss': 0.0041, 'grad_norm': 0.0015383146237581968, 'learning_rate': 4.9166666666666665e-05, 'epoch': 0.03}
# {'loss': 0.0037, 'grad_norm': 0.06869933754205704, 'learning_rate': 4.913888888888889e-05, 'epoch': 0.03}
# {'loss': 0.0026, 'grad_norm': 0.0689275935292244, 'learning_rate': 4.9111111111111114e-05, 'epoch': 0.04}
# {'loss': 0.0037, 'grad_norm': 0.20607753098011017, 'learning_rate': 4.908333333333334e-05, 'epoch': 0.04}
# {'loss': 0.0032, 'grad_norm': 0.10306625813245773, 'learning_rate': 4.905555555555556e-05, 'epoch': 0.04}
# {'loss': 0.0029, 'grad_norm': 0.0687873363494873, 'learning_rate': 4.902777777777778e-05, 'epoch': 0.04}
# {'loss': 0.0029, 'grad_norm': 0.03435716778039932, 'learning_rate': 4.9e-05, 'epoch': 0.04}
# {'loss': 0.0036, 'grad_norm': 0.03437677398324013, 'learning_rate': 4.897222222222222e-05, 'epoch': 0.04}
# {'loss': 0.0041, 'grad_norm': 0.06866659224033356, 'learning_rate': 4.894444444444445e-05, 'epoch': 0.04}
# {'loss': 0.0037, 'grad_norm': 0.034417249262332916, 'learning_rate': 4.891666666666667e-05, 'epoch': 0.04}
# {'loss': 0.0041, 'grad_norm': 0.034353647381067276, 'learning_rate': 4.888888888888889e-05, 'epoch': 0.04}
# {'loss': 0.0031, 'grad_norm': 0.03453044965863228, 'learning_rate': 4.8861111111111114e-05, 'epoch': 0.05}
# {'loss': 0.0043, 'grad_norm': 0.10348238050937653, 'learning_rate': 4.883333333333334e-05, 'epoch': 0.05}
# {'loss': 0.0043, 'grad_norm': 0.1723158359527588, 'learning_rate': 4.880555555555556e-05, 'epoch': 0.05}
# {'loss': 0.003, 'grad_norm': 0.03496832773089409, 'learning_rate': 4.8777777777777775e-05, 'epoch': 0.05}
# {'loss': 0.0026, 'grad_norm': 0.03480076044797897, 'learning_rate': 4.875e-05, 'epoch': 0.05}
# {'loss': 0.0025, 'grad_norm': 0.0, 'learning_rate': 4.8722222222222224e-05, 'epoch': 0.05}
# {'loss': 0.0019, 'grad_norm': 0.0, 'learning_rate': 4.869444444444445e-05, 'epoch': 0.05}
# {'loss': 0.0034, 'grad_norm': 0.06919822096824646, 'learning_rate': 4.866666666666667e-05, 'epoch': 0.05}
# {'loss': 0.0018, 'grad_norm': 0.103309266269207, 'learning_rate': 4.863888888888889e-05, 'epoch': 0.05}
# {'loss': 0.0038, 'grad_norm': 0.03467171639204025, 'learning_rate': 4.8611111111111115e-05, 'epoch': 0.06}
# {'loss': 0.0025, 'grad_norm': 0.10388612002134323, 'learning_rate': 4.858333333333333e-05, 'epoch': 0.06}
# {'loss': 0.0024, 'grad_norm': 0.03439415991306305, 'learning_rate': 4.855555555555556e-05, 'epoch': 0.06}
# {'loss': 0.0031, 'grad_norm': 0.06953846663236618, 'learning_rate': 4.8527777777777775e-05, 'epoch': 0.06}
# {'loss': 0.004, 'grad_norm': 0.0072330934926867485, 'learning_rate': 4.85e-05, 'epoch': 0.06}
# {'loss': 0.004, 'grad_norm': 0.07128289341926575, 'learning_rate': 4.8472222222222224e-05, 'epoch': 0.06}
# {'loss': 0.0021, 'grad_norm': 0.00883493386209011, 'learning_rate': 4.844444444444445e-05, 'epoch': 0.06}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.8416666666666673e-05, 'epoch': 0.06}
# {'loss': 0.0031, 'grad_norm': 0.03859461098909378, 'learning_rate': 4.838888888888889e-05, 'epoch': 0.06}
# {'loss': 0.0029, 'grad_norm': 0.03937307372689247, 'learning_rate': 4.8361111111111116e-05, 'epoch': 0.07}
# {'loss': 0.0019, 'grad_norm': 0.1766664683818817, 'learning_rate': 4.8333333333333334e-05, 'epoch': 0.07}
# {'loss': 0.0025, 'grad_norm': 0.06926926970481873, 'learning_rate': 4.830555555555556e-05, 'epoch': 0.07}
# {'loss': 0.0027, 'grad_norm': 0.03487540781497955, 'learning_rate': 4.8277777777777776e-05, 'epoch': 0.07}
# {'loss': 0.003, 'grad_norm': 0.007464451715350151, 'learning_rate': 4.825e-05, 'epoch': 0.07}
# {'loss': 0.0029, 'grad_norm': 0.11153072118759155, 'learning_rate': 4.8222222222222225e-05, 'epoch': 0.07}
# {'loss': 0.0021, 'grad_norm': 0.07967821508646011, 'learning_rate': 4.819444444444445e-05, 'epoch': 0.07}
# {'loss': 0.0028, 'grad_norm': 0.013643895275890827, 'learning_rate': 4.8166666666666674e-05, 'epoch': 0.07}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.813888888888889e-05, 'epoch': 0.07}
# {'loss': 0.0031, 'grad_norm': 0.037444330751895905, 'learning_rate': 4.811111111111111e-05, 'epoch': 0.08}
# {'loss': 0.0019, 'grad_norm': 0.07382670044898987, 'learning_rate': 4.8083333333333334e-05, 'epoch': 0.08}
# {'loss': 0.0029, 'grad_norm': 0.1088506281375885, 'learning_rate': 4.805555555555556e-05, 'epoch': 0.08}
# {'loss': 0.0016, 'grad_norm': 0.07067926973104477, 'learning_rate': 4.8027777777777783e-05, 'epoch': 0.08}
# {'loss': 0.0017, 'grad_norm': 0.03498111665248871, 'learning_rate': 4.8e-05, 'epoch': 0.08}
# {'loss': 0.0019, 'grad_norm': 0.03962289169430733, 'learning_rate': 4.7972222222222226e-05, 'epoch': 0.08}
# {'loss': 0.0014, 'grad_norm': 0.03502463176846504, 'learning_rate': 4.794444444444445e-05, 'epoch': 0.08}
# {'loss': 0.0026, 'grad_norm': 0.21338456869125366, 'learning_rate': 4.791666666666667e-05, 'epoch': 0.08}
# {'loss': 0.0019, 'grad_norm': 0.034944772720336914, 'learning_rate': 4.7888888888888886e-05, 'epoch': 0.08}
# {'loss': 0.0035, 'grad_norm': 0.18064817786216736, 'learning_rate': 4.786111111111111e-05, 'epoch': 0.09}
# {'loss': 0.0023, 'grad_norm': 0.04055773466825485, 'learning_rate': 4.7833333333333335e-05, 'epoch': 0.09}
# {'loss': 0.0017, 'grad_norm': 0.10708200931549072, 'learning_rate': 4.780555555555556e-05, 'epoch': 0.09}
# {'loss': 0.0027, 'grad_norm': 0.17268352210521698, 'learning_rate': 4.7777777777777784e-05, 'epoch': 0.09}
# {'loss': 0.0019, 'grad_norm': 0.1103137731552124, 'learning_rate': 4.775e-05, 'epoch': 0.09}
# {'loss': 0.0026, 'grad_norm': 0.08262576162815094, 'learning_rate': 4.7722222222222226e-05, 'epoch': 0.09}
# {'loss': 0.0021, 'grad_norm': 0.0376594103872776, 'learning_rate': 4.7694444444444444e-05, 'epoch': 0.09}
# {'loss': 0.0017, 'grad_norm': 0.035638369619846344, 'learning_rate': 4.766666666666667e-05, 'epoch': 0.09}
# {'loss': 0.0019, 'grad_norm': 0.036519963294267654, 'learning_rate': 4.7638888888888887e-05, 'epoch': 0.09}
# {'loss': 0.0027, 'grad_norm': 0.036583948880434036, 'learning_rate': 4.761111111111111e-05, 'epoch': 0.1}
# {'loss': 0.0026, 'grad_norm': 0.07134541124105453, 'learning_rate': 4.7583333333333336e-05, 'epoch': 0.1}
# {'loss': 0.0026, 'grad_norm': 0.10886489599943161, 'learning_rate': 4.755555555555556e-05, 'epoch': 0.1}
# {'loss': 0.0014, 'grad_norm': 0.0345279686152935, 'learning_rate': 4.7527777777777785e-05, 'epoch': 0.1}
# {'loss': 0.0017, 'grad_norm': 0.10872486233711243, 'learning_rate': 4.75e-05, 'epoch': 0.1}
# {'loss': 0.0011, 'grad_norm': 0.0710354596376419, 'learning_rate': 4.747222222222222e-05, 'epoch': 0.1}
# {'loss': 0.002, 'grad_norm': 0.00246628955937922, 'learning_rate': 4.7444444444444445e-05, 'epoch': 0.1}
# {'loss': 0.0016, 'grad_norm': 0.03576640039682388, 'learning_rate': 4.741666666666667e-05, 'epoch': 0.1}
# {'loss': 0.0017, 'grad_norm': 0.13899365067481995, 'learning_rate': 4.7388888888888894e-05, 'epoch': 0.1}
# {'loss': 0.0021, 'grad_norm': 0.17653389275074005, 'learning_rate': 4.736111111111111e-05, 'epoch': 0.11}
# {'loss': 0.0025, 'grad_norm': 0.04076118767261505, 'learning_rate': 4.7333333333333336e-05, 'epoch': 0.11}
# {'loss': 0.0017, 'grad_norm': 0.07499310374259949, 'learning_rate': 4.730555555555556e-05, 'epoch': 0.11}
# {'loss': 0.002, 'grad_norm': 0.13822323083877563, 'learning_rate': 4.727777777777778e-05, 'epoch': 0.11}
# {'loss': 0.0025, 'grad_norm': 0.023643633350729942, 'learning_rate': 4.7249999999999997e-05, 'epoch': 0.11}
# {'loss': 0.0018, 'grad_norm': 0.10564198344945908, 'learning_rate': 4.722222222222222e-05, 'epoch': 0.11}
# {'loss': 0.0022, 'grad_norm': 0.01369828823953867, 'learning_rate': 4.7194444444444446e-05, 'epoch': 0.11}
# {'loss': 0.002, 'grad_norm': 0.03687150031328201, 'learning_rate': 4.716666666666667e-05, 'epoch': 0.11}
# {'loss': 0.0031, 'grad_norm': 0.06893832981586456, 'learning_rate': 4.7138888888888895e-05, 'epoch': 0.11}
# {'loss': 0.0011, 'grad_norm': 0.1031482145190239, 'learning_rate': 4.711111111111111e-05, 'epoch': 0.12}
# {'loss': 0.0012, 'grad_norm': 0.01752316765487194, 'learning_rate': 4.708333333333334e-05, 'epoch': 0.12}
# {'loss': 0.002, 'grad_norm': 0.03782051429152489, 'learning_rate': 4.7055555555555555e-05, 'epoch': 0.12}
# {'loss': 0.0019, 'grad_norm': 0.07062021642923355, 'learning_rate': 4.702777777777778e-05, 'epoch': 0.12}
# {'loss': 0.0024, 'grad_norm': 0.007721425965428352, 'learning_rate': 4.7e-05, 'epoch': 0.12}
# {'loss': 0.0018, 'grad_norm': 0.07589999586343765, 'learning_rate': 4.697222222222222e-05, 'epoch': 0.12}
# {'loss': 0.0029, 'grad_norm': 0.07118859142065048, 'learning_rate': 4.6944444444444446e-05, 'epoch': 0.12}
# {'loss': 0.0016, 'grad_norm': 0.03904794901609421, 'learning_rate': 4.691666666666667e-05, 'epoch': 0.12}
# {'loss': 0.0026, 'grad_norm': 0.11414464563131332, 'learning_rate': 4.6888888888888895e-05, 'epoch': 0.12}
# {'loss': 0.0021, 'grad_norm': 0.0415627546608448, 'learning_rate': 4.686111111111111e-05, 'epoch': 0.13}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.683333333333334e-05, 'epoch': 0.13}
# {'loss': 0.0017, 'grad_norm': 0.07058093696832657, 'learning_rate': 4.6805555555555556e-05, 'epoch': 0.13}
# {'loss': 0.0026, 'grad_norm': 0.014599793590605259, 'learning_rate': 4.677777777777778e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.1030718982219696, 'learning_rate': 4.6750000000000005e-05, 'epoch': 0.13}
# {'loss': 0.0014, 'grad_norm': 0.047761086374521255, 'learning_rate': 4.672222222222222e-05, 'epoch': 0.13}
# {'loss': 0.0012, 'grad_norm': 0.07251790910959244, 'learning_rate': 4.669444444444445e-05, 'epoch': 0.13}
# {'loss': 0.002, 'grad_norm': 0.10797315090894699, 'learning_rate': 4.666666666666667e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.03573078662157059, 'learning_rate': 4.6638888888888896e-05, 'epoch': 0.13}
# {'loss': 0.0017, 'grad_norm': 0.042447347193956375, 'learning_rate': 4.6611111111111114e-05, 'epoch': 0.14}
# {'loss': 0.0026, 'grad_norm': 0.03469200059771538, 'learning_rate': 4.658333333333333e-05, 'epoch': 0.14}
# {'loss': 0.0026, 'grad_norm': 0.06726743280887604, 'learning_rate': 4.6555555555555556e-05, 'epoch': 0.14}
# {'loss': 0.0017, 'grad_norm': 0.034532319754362106, 'learning_rate': 4.652777777777778e-05, 'epoch': 0.14}
# {'loss': 0.0035, 'grad_norm': 0.03653082624077797, 'learning_rate': 4.6500000000000005e-05, 'epoch': 0.14}
# {'loss': 0.0012, 'grad_norm': 0.01915271393954754, 'learning_rate': 4.647222222222222e-05, 'epoch': 0.14}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.644444444444445e-05, 'epoch': 0.14}
# {'loss': 0.0019, 'grad_norm': 0.04223226383328438, 'learning_rate': 4.641666666666667e-05, 'epoch': 0.14}
# {'loss': 0.0022, 'grad_norm': 0.07314040511846542, 'learning_rate': 4.638888888888889e-05, 'epoch': 0.14}
# {'loss': 0.002, 'grad_norm': 0.07129960507154465, 'learning_rate': 4.636111111111111e-05, 'epoch': 0.15}
# {'loss': 0.0018, 'grad_norm': 0.03557451069355011, 'learning_rate': 4.633333333333333e-05, 'epoch': 0.15}
# {'loss': 0.0023, 'grad_norm': 0.027184611186385155, 'learning_rate': 4.630555555555556e-05, 'epoch': 0.15}
# {'loss': 0.002, 'grad_norm': 0.037675753235816956, 'learning_rate': 4.627777777777778e-05, 'epoch': 0.15}
# {'loss': 0.0027, 'grad_norm': 0.07049186527729034, 'learning_rate': 4.6250000000000006e-05, 'epoch': 0.15}
# {'loss': 0.0011, 'grad_norm': 0.007359274663031101, 'learning_rate': 4.6222222222222224e-05, 'epoch': 0.15}
# {'loss': 0.0037, 'grad_norm': 0.007840585894882679, 'learning_rate': 4.619444444444445e-05, 'epoch': 0.15}
# {'loss': 0.0023, 'grad_norm': 0.013833991251885891, 'learning_rate': 4.6166666666666666e-05, 'epoch': 0.15}
# {'loss': 0.0016, 'grad_norm': 0.04352375119924545, 'learning_rate': 4.613888888888889e-05, 'epoch': 0.15}
# {'loss': 0.0023, 'grad_norm': 0.10751219838857651, 'learning_rate': 4.6111111111111115e-05, 'epoch': 0.16}
# {'loss': 0.0016, 'grad_norm': 0.14452484250068665, 'learning_rate': 4.608333333333333e-05, 'epoch': 0.16}
# {'loss': 0.0023, 'grad_norm': 0.04456738755106926, 'learning_rate': 4.605555555555556e-05, 'epoch': 0.16}
# {'loss': 0.0011, 'grad_norm': 0.07170214504003525, 'learning_rate': 4.602777777777778e-05, 'epoch': 0.16}
# {'loss': 0.0022, 'grad_norm': 0.04703647643327713, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.16}
# {'loss': 0.0018, 'grad_norm': 0.14575634896755219, 'learning_rate': 4.5972222222222225e-05, 'epoch': 0.16}
# {'loss': 0.0023, 'grad_norm': 0.03453441336750984, 'learning_rate': 4.594444444444444e-05, 'epoch': 0.16}
# {'loss': 0.0013, 'grad_norm': 0.030427712947130203, 'learning_rate': 4.591666666666667e-05, 'epoch': 0.16}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.588888888888889e-05, 'epoch': 0.16}
# {'loss': 0.0029, 'grad_norm': 0.3257250487804413, 'learning_rate': 4.5861111111111116e-05, 'epoch': 0.17}
# {'loss': 0.002, 'grad_norm': 0.04344835877418518, 'learning_rate': 4.5833333333333334e-05, 'epoch': 0.17}
# {'loss': 0.0015, 'grad_norm': 0.0715535432100296, 'learning_rate': 4.580555555555556e-05, 'epoch': 0.17}
# {'loss': 0.0029, 'grad_norm': 0.016339804977178574, 'learning_rate': 4.577777777777778e-05, 'epoch': 0.17}
# {'loss': 0.0012, 'grad_norm': 0.1127195879817009, 'learning_rate': 4.575e-05, 'epoch': 0.17}
# {'loss': 0.0021, 'grad_norm': 0.019260048866271973, 'learning_rate': 4.572222222222222e-05, 'epoch': 0.17}
# {'loss': 0.0017, 'grad_norm': 0.0542757511138916, 'learning_rate': 4.569444444444444e-05, 'epoch': 0.17}
# {'loss': 0.0021, 'grad_norm': 0.04574970528483391, 'learning_rate': 4.566666666666667e-05, 'epoch': 0.17}
# {'loss': 0.002, 'grad_norm': 0.07786179333925247, 'learning_rate': 4.563888888888889e-05, 'epoch': 0.17}
# {'loss': 0.0014, 'grad_norm': 0.040222860872745514, 'learning_rate': 4.561111111111112e-05, 'epoch': 0.18}
# {'loss': 0.0018, 'grad_norm': 0.0, 'learning_rate': 4.5583333333333335e-05, 'epoch': 0.18}
# {'loss': 0.0007, 'grad_norm': 0.03603062033653259, 'learning_rate': 4.555555555555556e-05, 'epoch': 0.18}
# {'loss': 0.0016, 'grad_norm': 0.17761816084384918, 'learning_rate': 4.5527777777777784e-05, 'epoch': 0.18}
# {'loss': 0.0015, 'grad_norm': 0.03558509796857834, 'learning_rate': 4.55e-05, 'epoch': 0.18}
# {'loss': 0.0026, 'grad_norm': 0.07170232385396957, 'learning_rate': 4.5472222222222226e-05, 'epoch': 0.18}
# {'loss': 0.0014, 'grad_norm': 0.04755755886435509, 'learning_rate': 4.5444444444444444e-05, 'epoch': 0.18}
# {'loss': 0.0015, 'grad_norm': 0.035235848277807236, 'learning_rate': 4.541666666666667e-05, 'epoch': 0.18}
# {'loss': 0.0007, 'grad_norm': 0.03460373356938362, 'learning_rate': 4.538888888888889e-05, 'epoch': 0.18}
# {'loss': 0.0029, 'grad_norm': 0.14420151710510254, 'learning_rate': 4.536111111111112e-05, 'epoch': 0.19}
# {'loss': 0.0028, 'grad_norm': 0.07120026648044586, 'learning_rate': 4.5333333333333335e-05, 'epoch': 0.19}
# {'loss': 0.001, 'grad_norm': 0.13928771018981934, 'learning_rate': 4.530555555555556e-05, 'epoch': 0.19}
# {'loss': 0.0032, 'grad_norm': 0.0782945528626442, 'learning_rate': 4.527777777777778e-05, 'epoch': 0.19}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.525e-05, 'epoch': 0.19}
# {'loss': 0.0015, 'grad_norm': 0.04027105122804642, 'learning_rate': 4.522222222222223e-05, 'epoch': 0.19}
# {'loss': 0.0014, 'grad_norm': 0.046798933297395706, 'learning_rate': 4.5194444444444444e-05, 'epoch': 0.19}
# {'loss': 0.0009, 'grad_norm': 0.08470110595226288, 'learning_rate': 4.516666666666667e-05, 'epoch': 0.19}
# {'loss': 0.0017, 'grad_norm': 0.01215975172817707, 'learning_rate': 4.5138888888888894e-05, 'epoch': 0.19}
# {'loss': 0.0022, 'grad_norm': 0.03558887541294098, 'learning_rate': 4.511111111111112e-05, 'epoch': 0.2}
# {'loss': 0.0032, 'grad_norm': 0.03581346943974495, 'learning_rate': 4.5083333333333336e-05, 'epoch': 0.2}
# {'loss': 0.0026, 'grad_norm': 0.06968503445386887, 'learning_rate': 4.5055555555555554e-05, 'epoch': 0.2}
# {'loss': 0.0024, 'grad_norm': 0.07034074515104294, 'learning_rate': 4.502777777777778e-05, 'epoch': 0.2}
# {'loss': 0.0022, 'grad_norm': 0.04785728082060814, 'learning_rate': 4.5e-05, 'epoch': 0.2}
# {'loss': 0.0027, 'grad_norm': 0.14261391758918762, 'learning_rate': 4.497222222222223e-05, 'epoch': 0.2}
# {'loss': 0.0018, 'grad_norm': 0.03451232984662056, 'learning_rate': 4.4944444444444445e-05, 'epoch': 0.2}
# {'loss': 0.0015, 'grad_norm': 0.16384555399417877, 'learning_rate': 4.491666666666667e-05, 'epoch': 0.2}
# {'loss': 0.0009, 'grad_norm': 0.03488558158278465, 'learning_rate': 4.4888888888888894e-05, 'epoch': 0.2}
# {'loss': 0.0016, 'grad_norm': 0.040846120566129684, 'learning_rate': 4.486111111111111e-05, 'epoch': 0.21}
# {'loss': 0.0024, 'grad_norm': 0.10583355277776718, 'learning_rate': 4.483333333333333e-05, 'epoch': 0.21}
# {'loss': 0.0006, 'grad_norm': 0.1535278707742691, 'learning_rate': 4.4805555555555554e-05, 'epoch': 0.21}
# {'loss': 0.002, 'grad_norm': 0.012247800827026367, 'learning_rate': 4.477777777777778e-05, 'epoch': 0.21}
# {'loss': 0.0018, 'grad_norm': 0.034795332700014114, 'learning_rate': 4.4750000000000004e-05, 'epoch': 0.21}
# {'loss': 0.0026, 'grad_norm': 0.10388055443763733, 'learning_rate': 4.472222222222223e-05, 'epoch': 0.21}
# {'loss': 0.0024, 'grad_norm': 0.10858525335788727, 'learning_rate': 4.4694444444444446e-05, 'epoch': 0.21}
# {'loss': 0.002, 'grad_norm': 0.04486722871661186, 'learning_rate': 4.466666666666667e-05, 'epoch': 0.21}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.463888888888889e-05, 'epoch': 0.21}
# {'loss': 0.0019, 'grad_norm': 0.03439393639564514, 'learning_rate': 4.461111111111111e-05, 'epoch': 0.22}
# {'loss': 0.0017, 'grad_norm': 0.0403224416077137, 'learning_rate': 4.458333333333334e-05, 'epoch': 0.22}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.4555555555555555e-05, 'epoch': 0.22}
# {'loss': 0.0009, 'grad_norm': 0.03464753180742264, 'learning_rate': 4.452777777777778e-05, 'epoch': 0.22}
# {'loss': 0.0015, 'grad_norm': 0.11797739565372467, 'learning_rate': 4.4500000000000004e-05, 'epoch': 0.22}
# {'loss': 0.003, 'grad_norm': 0.025962619110941887, 'learning_rate': 4.447222222222223e-05, 'epoch': 0.22}
# {'loss': 0.0018, 'grad_norm': 0.10875698179006577, 'learning_rate': 4.4444444444444447e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.03451979532837868, 'learning_rate': 4.4416666666666664e-05, 'epoch': 0.22}
# {'loss': 0.0017, 'grad_norm': 0.0750853419303894, 'learning_rate': 4.438888888888889e-05, 'epoch': 0.22}
# {'loss': 0.002, 'grad_norm': 0.10389452427625656, 'learning_rate': 4.4361111111111113e-05, 'epoch': 0.23}
# {'loss': 0.0014, 'grad_norm': 0.045882537961006165, 'learning_rate': 4.433333333333334e-05, 'epoch': 0.23}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.4305555555555556e-05, 'epoch': 0.23}
# {'loss': 0.0015, 'grad_norm': 0.03465435653924942, 'learning_rate': 4.427777777777778e-05, 'epoch': 0.23}
# {'loss': 0.0011, 'grad_norm': 0.035142719745635986, 'learning_rate': 4.4250000000000005e-05, 'epoch': 0.23}
# {'loss': 0.0024, 'grad_norm': 0.035818129777908325, 'learning_rate': 4.422222222222222e-05, 'epoch': 0.23}
# {'loss': 0.0016, 'grad_norm': 0.06700430810451508, 'learning_rate': 4.419444444444444e-05, 'epoch': 0.23}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.4166666666666665e-05, 'epoch': 0.23}
# {'loss': 0.002, 'grad_norm': 0.04074719548225403, 'learning_rate': 4.413888888888889e-05, 'epoch': 0.23}
# {'loss': 0.0019, 'grad_norm': 0.041305527091026306, 'learning_rate': 4.4111111111111114e-05, 'epoch': 0.24}
# {'loss': 0.0013, 'grad_norm': 0.01362859457731247, 'learning_rate': 4.408333333333334e-05, 'epoch': 0.24}
# {'loss': 0.002, 'grad_norm': 0.0, 'learning_rate': 4.4055555555555557e-05, 'epoch': 0.24}
# {'loss': 0.0019, 'grad_norm': 0.0721607655286789, 'learning_rate': 4.402777777777778e-05, 'epoch': 0.24}
# {'loss': 0.0022, 'grad_norm': 0.07701390981674194, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.24}
# {'loss': 0.0007, 'grad_norm': 0.03870857506990433, 'learning_rate': 4.3972222222222223e-05, 'epoch': 0.24}
# {'loss': 0.0018, 'grad_norm': 0.10566262155771255, 'learning_rate': 4.394444444444445e-05, 'epoch': 0.24}
# {'loss': 0.0014, 'grad_norm': 0.034727755934000015, 'learning_rate': 4.3916666666666666e-05, 'epoch': 0.24}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.388888888888889e-05, 'epoch': 0.24}
# {'loss': 0.0023, 'grad_norm': 0.1837186962366104, 'learning_rate': 4.3861111111111115e-05, 'epoch': 0.25}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.383333333333334e-05, 'epoch': 0.25}
# {'loss': 0.0018, 'grad_norm': 0.1148703321814537, 'learning_rate': 4.380555555555556e-05, 'epoch': 0.25}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.377777777777778e-05, 'epoch': 0.25}
# {'loss': 0.0012, 'grad_norm': 0.03504078462719917, 'learning_rate': 4.375e-05, 'epoch': 0.25}
# {'loss': 0.0013, 'grad_norm': 0.07007429748773575, 'learning_rate': 4.3722222222222224e-05, 'epoch': 0.25}
# {'loss': 0.0011, 'grad_norm': 0.03433985635638237, 'learning_rate': 4.369444444444445e-05, 'epoch': 0.25}
# {'loss': 0.0019, 'grad_norm': 0.0918193832039833, 'learning_rate': 4.3666666666666666e-05, 'epoch': 0.25}
# {'loss': 0.0016, 'grad_norm': 0.0350194126367569, 'learning_rate': 4.363888888888889e-05, 'epoch': 0.25}
# {'loss': 0.0012, 'grad_norm': 0.04081867262721062, 'learning_rate': 4.3611111111111116e-05, 'epoch': 0.26}
# {'loss': 0.0024, 'grad_norm': 0.034404776990413666, 'learning_rate': 4.358333333333334e-05, 'epoch': 0.26}
# {'loss': 0.0013, 'grad_norm': 0.07136454433202744, 'learning_rate': 4.355555555555556e-05, 'epoch': 0.26}
# {'loss': 0.0028, 'grad_norm': 0.0, 'learning_rate': 4.3527777777777776e-05, 'epoch': 0.26}
# {'loss': 0.0017, 'grad_norm': 0.03473827615380287, 'learning_rate': 4.35e-05, 'epoch': 0.26}
# {'loss': 0.0019, 'grad_norm': 0.06881581246852875, 'learning_rate': 4.3472222222222225e-05, 'epoch': 0.26}
# {'loss': 0.0013, 'grad_norm': 0.0461483970284462, 'learning_rate': 4.344444444444445e-05, 'epoch': 0.26}
# {'loss': 0.0026, 'grad_norm': 0.035022832453250885, 'learning_rate': 4.341666666666667e-05, 'epoch': 0.26}
# {'loss': 0.0025, 'grad_norm': 0.2167181819677353, 'learning_rate': 4.338888888888889e-05, 'epoch': 0.26}
# {'loss': 0.0016, 'grad_norm': 0.07047577947378159, 'learning_rate': 4.3361111111111116e-05, 'epoch': 0.27}
# {'loss': 0.0018, 'grad_norm': 0.0, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.27}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.330555555555556e-05, 'epoch': 0.27}
# {'loss': 0.0007, 'grad_norm': 0.036057230085134506, 'learning_rate': 4.3277777777777776e-05, 'epoch': 0.27}
# {'loss': 0.0021, 'grad_norm': 0.10827213525772095, 'learning_rate': 4.325e-05, 'epoch': 0.27}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.3222222222222226e-05, 'epoch': 0.27}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.319444444444445e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.16338348388671875, 'learning_rate': 4.316666666666667e-05, 'epoch': 0.27}
# {'loss': 0.0013, 'grad_norm': 0.05199918523430824, 'learning_rate': 4.313888888888889e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.03507500886917114, 'learning_rate': 4.311111111111111e-05, 'epoch': 0.28}
# {'loss': 0.0014, 'grad_norm': 0.03433617949485779, 'learning_rate': 4.3083333333333335e-05, 'epoch': 0.28}
# {'loss': 0.0014, 'grad_norm': 0.04141414165496826, 'learning_rate': 4.305555555555556e-05, 'epoch': 0.28}
# {'loss': 0.0008, 'grad_norm': 0.049860164523124695, 'learning_rate': 4.302777777777778e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.03436458855867386, 'learning_rate': 4.3e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.2972222222222226e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.045296430587768555, 'learning_rate': 4.294444444444445e-05, 'epoch': 0.28}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.291666666666667e-05, 'epoch': 0.28}
# {'loss': 0.0011, 'grad_norm': 0.08510425686836243, 'learning_rate': 4.2888888888888886e-05, 'epoch': 0.28}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.286111111111111e-05, 'epoch': 0.29}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.2833333333333335e-05, 'epoch': 0.29}
# {'loss': 0.0015, 'grad_norm': 0.053593121469020844, 'learning_rate': 4.280555555555556e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.0027508221101015806, 'learning_rate': 4.277777777777778e-05, 'epoch': 0.29}
# {'loss': 0.002, 'grad_norm': 0.04122287780046463, 'learning_rate': 4.275e-05, 'epoch': 0.29}
# {'loss': 0.0015, 'grad_norm': 0.04808906093239784, 'learning_rate': 4.272222222222223e-05, 'epoch': 0.29}
# {'loss': 0.0017, 'grad_norm': 0.07220347970724106, 'learning_rate': 4.2694444444444445e-05, 'epoch': 0.29}
# {'loss': 0.0016, 'grad_norm': 0.07407425343990326, 'learning_rate': 4.266666666666667e-05, 'epoch': 0.29}
# {'loss': 0.0018, 'grad_norm': 0.0, 'learning_rate': 4.263888888888889e-05, 'epoch': 0.29}
# {'loss': 0.002, 'grad_norm': 0.0, 'learning_rate': 4.261111111111111e-05, 'epoch': 0.3}
# {'loss': 0.0012, 'grad_norm': 0.07083684206008911, 'learning_rate': 4.2583333333333336e-05, 'epoch': 0.3}
# {'loss': 0.002, 'grad_norm': 0.09438416361808777, 'learning_rate': 4.255555555555556e-05, 'epoch': 0.3}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.252777777777778e-05, 'epoch': 0.3}
# {'loss': 0.0023, 'grad_norm': 0.07428839802742004, 'learning_rate': 4.25e-05, 'epoch': 0.3}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.247222222222223e-05, 'epoch': 0.3}
# {'loss': 0.001, 'grad_norm': 0.10324476659297943, 'learning_rate': 4.2444444444444445e-05, 'epoch': 0.3}
# {'loss': 0.0017, 'grad_norm': 0.02461487427353859, 'learning_rate': 4.241666666666667e-05, 'epoch': 0.3}
# {'loss': 0.0012, 'grad_norm': 0.037339501082897186, 'learning_rate': 4.238888888888889e-05, 'epoch': 0.3}
# {'loss': 0.0022, 'grad_norm': 0.03447943925857544, 'learning_rate': 4.236111111111111e-05, 'epoch': 0.31}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.233333333333334e-05, 'epoch': 0.31}
# {'loss': 0.0006, 'grad_norm': 0.03445984050631523, 'learning_rate': 4.230555555555556e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.227777777777778e-05, 'epoch': 0.31}
# {'loss': 0.0015, 'grad_norm': 0.10838545113801956, 'learning_rate': 4.2250000000000004e-05, 'epoch': 0.31}
# {'loss': 0.0016, 'grad_norm': 0.03438376635313034, 'learning_rate': 4.222222222222222e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.03432731702923775, 'learning_rate': 4.2194444444444446e-05, 'epoch': 0.31}
# {'loss': 0.0023, 'grad_norm': 0.04071537405252457, 'learning_rate': 4.216666666666667e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.06588917225599289, 'learning_rate': 4.213888888888889e-05, 'epoch': 0.31}
# {'loss': 0.001, 'grad_norm': 0.04827594757080078, 'learning_rate': 4.211111111111111e-05, 'epoch': 0.32}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.208333333333334e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 4.205555555555556e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.0360458604991436, 'learning_rate': 4.202777777777778e-05, 'epoch': 0.32}
# {'loss': 0.0011, 'grad_norm': 0.07721984386444092, 'learning_rate': 4.2e-05, 'epoch': 0.32}
# {'loss': 0.0013, 'grad_norm': 0.042925819754600525, 'learning_rate': 4.197222222222222e-05, 'epoch': 0.32}
# {'loss': 0.0016, 'grad_norm': 0.03485020995140076, 'learning_rate': 4.194444444444445e-05, 'epoch': 0.32}
# {'loss': 0.0022, 'grad_norm': 0.034411389380693436, 'learning_rate': 4.191666666666667e-05, 'epoch': 0.32}
# {'loss': 0.0016, 'grad_norm': 0.03445868566632271, 'learning_rate': 4.188888888888889e-05, 'epoch': 0.32}
# {'loss': 0.0019, 'grad_norm': 0.0, 'learning_rate': 4.1861111111111114e-05, 'epoch': 0.33}
# {'loss': 0.0024, 'grad_norm': 0.038716915994882584, 'learning_rate': 4.183333333333334e-05, 'epoch': 0.33}
# {'loss': 0.001, 'grad_norm': 0.03441477566957474, 'learning_rate': 4.1805555555555556e-05, 'epoch': 0.33}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.177777777777778e-05, 'epoch': 0.33}
# {'loss': 0.0018, 'grad_norm': 0.09578963369131088, 'learning_rate': 4.175e-05, 'epoch': 0.33}
# {'loss': 0.0006, 'grad_norm': 0.10486483573913574, 'learning_rate': 4.172222222222222e-05, 'epoch': 0.33}
# {'loss': 0.0014, 'grad_norm': 0.03440176695585251, 'learning_rate': 4.169444444444445e-05, 'epoch': 0.33}
# {'loss': 0.0013, 'grad_norm': 0.03457488864660263, 'learning_rate': 4.166666666666667e-05, 'epoch': 0.33}
# {'loss': 0.0017, 'grad_norm': 0.17582952976226807, 'learning_rate': 4.163888888888889e-05, 'epoch': 0.33}
# {'loss': 0.0012, 'grad_norm': 0.06874431669712067, 'learning_rate': 4.1611111111111114e-05, 'epoch': 0.34}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.158333333333333e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.06905023008584976, 'learning_rate': 4.155555555555556e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.152777777777778e-05, 'epoch': 0.34}
# {'loss': 0.0015, 'grad_norm': 0.03447325900197029, 'learning_rate': 4.15e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.1472222222222224e-05, 'epoch': 0.34}
# {'loss': 0.0017, 'grad_norm': 0.04676970839500427, 'learning_rate': 4.144444444444445e-05, 'epoch': 0.34}
# {'loss': 0.0019, 'grad_norm': 0.2272748053073883, 'learning_rate': 4.141666666666667e-05, 'epoch': 0.34}
# {'loss': 0.0022, 'grad_norm': 0.06878462433815002, 'learning_rate': 4.138888888888889e-05, 'epoch': 0.34}
# {'loss': 0.0023, 'grad_norm': 0.038012415170669556, 'learning_rate': 4.136111111111111e-05, 'epoch': 0.35}
# {'loss': 0.001, 'grad_norm': 0.1424873024225235, 'learning_rate': 4.133333333333333e-05, 'epoch': 0.35}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.130555555555556e-05, 'epoch': 0.35}
# {'loss': 0.002, 'grad_norm': 0.03457428142428398, 'learning_rate': 4.127777777777778e-05, 'epoch': 0.35}
# {'loss': 0.0009, 'grad_norm': 0.07000049203634262, 'learning_rate': 4.125e-05, 'epoch': 0.35}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.1222222222222224e-05, 'epoch': 0.35}
# {'loss': 0.0009, 'grad_norm': 0.08472652733325958, 'learning_rate': 4.119444444444445e-05, 'epoch': 0.35}
# {'loss': 0.001, 'grad_norm': 0.07524202764034271, 'learning_rate': 4.116666666666667e-05, 'epoch': 0.35}
# {'loss': 0.0012, 'grad_norm': 0.003507415996864438, 'learning_rate': 4.113888888888889e-05, 'epoch': 0.35}
# {'loss': 0.0019, 'grad_norm': 0.007314878981560469, 'learning_rate': 4.111111111111111e-05, 'epoch': 0.36}
# {'loss': 0.0017, 'grad_norm': 0.029182709753513336, 'learning_rate': 4.1083333333333334e-05, 'epoch': 0.36}
# {'loss': 0.0013, 'grad_norm': 0.003808253910392523, 'learning_rate': 4.105555555555556e-05, 'epoch': 0.36}
# {'loss': 0.0014, 'grad_norm': 0.0547301210463047, 'learning_rate': 4.102777777777778e-05, 'epoch': 0.36}
# {'loss': 0.0011, 'grad_norm': 0.03877168893814087, 'learning_rate': 4.1e-05, 'epoch': 0.36}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.0972222222222225e-05, 'epoch': 0.36}
# {'loss': 0.0025, 'grad_norm': 0.10810565203428268, 'learning_rate': 4.094444444444445e-05, 'epoch': 0.36}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.091666666666667e-05, 'epoch': 0.36}
# {'loss': 0.0018, 'grad_norm': 0.035274092108011246, 'learning_rate': 4.088888888888889e-05, 'epoch': 0.36}
# {'loss': 0.0011, 'grad_norm': 0.03451842814683914, 'learning_rate': 4.086111111111111e-05, 'epoch': 0.37}
# {'loss': 0.0018, 'grad_norm': 0.07232214510440826, 'learning_rate': 4.0833333333333334e-05, 'epoch': 0.37}
# {'loss': 0.002, 'grad_norm': 0.0035586205776780844, 'learning_rate': 4.080555555555556e-05, 'epoch': 0.37}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 4.0777777777777783e-05, 'epoch': 0.37}
# {'loss': 0.0021, 'grad_norm': 0.05242665112018585, 'learning_rate': 4.075e-05, 'epoch': 0.37}
# {'loss': 0.0019, 'grad_norm': 0.03504183515906334, 'learning_rate': 4.0722222222222226e-05, 'epoch': 0.37}
# {'loss': 0.0009, 'grad_norm': 0.08960530161857605, 'learning_rate': 4.0694444444444444e-05, 'epoch': 0.37}
# {'loss': 0.001, 'grad_norm': 0.04370808228850365, 'learning_rate': 4.066666666666667e-05, 'epoch': 0.37}
# {'loss': 0.0014, 'grad_norm': 0.04193560406565666, 'learning_rate': 4.063888888888889e-05, 'epoch': 0.37}
# {'loss': 0.0012, 'grad_norm': 0.1027340516448021, 'learning_rate': 4.061111111111111e-05, 'epoch': 0.38}
# {'loss': 0.0006, 'grad_norm': 0.05386902019381523, 'learning_rate': 4.0583333333333335e-05, 'epoch': 0.38}
# {'loss': 0.001, 'grad_norm': 0.09214352816343307, 'learning_rate': 4.055555555555556e-05, 'epoch': 0.38}
# {'loss': 0.0016, 'grad_norm': 0.058743856847286224, 'learning_rate': 4.0527777777777784e-05, 'epoch': 0.38}
# {'loss': 0.0009, 'grad_norm': 0.03458206355571747, 'learning_rate': 4.05e-05, 'epoch': 0.38}
# {'loss': 0.001, 'grad_norm': 0.11905445158481598, 'learning_rate': 4.047222222222222e-05, 'epoch': 0.38}
# {'loss': 0.0012, 'grad_norm': 0.039542607963085175, 'learning_rate': 4.0444444444444444e-05, 'epoch': 0.38}
# {'loss': 0.0021, 'grad_norm': 0.049196552485227585, 'learning_rate': 4.041666666666667e-05, 'epoch': 0.38}
# {'loss': 0.0016, 'grad_norm': 0.08888241648674011, 'learning_rate': 4.038888888888889e-05, 'epoch': 0.38}
# {'loss': 0.0022, 'grad_norm': 0.012319248169660568, 'learning_rate': 4.036111111111111e-05, 'epoch': 0.39}
# {'loss': 0.0014, 'grad_norm': 0.0700385794043541, 'learning_rate': 4.0333333333333336e-05, 'epoch': 0.39}
# {'loss': 0.0008, 'grad_norm': 0.03460351750254631, 'learning_rate': 4.030555555555556e-05, 'epoch': 0.39}
# {'loss': 0.0019, 'grad_norm': 0.14005228877067566, 'learning_rate': 4.027777777777778e-05, 'epoch': 0.39}
# {'loss': 0.0015, 'grad_norm': 0.03524812310934067, 'learning_rate': 4.025e-05, 'epoch': 0.39}
# {'loss': 0.0011, 'grad_norm': 0.12801453471183777, 'learning_rate': 4.022222222222222e-05, 'epoch': 0.39}
# {'loss': 0.0019, 'grad_norm': 0.07656241953372955, 'learning_rate': 4.0194444444444445e-05, 'epoch': 0.39}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 4.016666666666667e-05, 'epoch': 0.39}
# {'loss': 0.0009, 'grad_norm': 0.03470472991466522, 'learning_rate': 4.0138888888888894e-05, 'epoch': 0.39}
# {'loss': 0.0013, 'grad_norm': 0.034682776778936386, 'learning_rate': 4.011111111111111e-05, 'epoch': 0.4}
# {'loss': 0.0016, 'grad_norm': 0.051082149147987366, 'learning_rate': 4.0083333333333336e-05, 'epoch': 0.4}
# {'loss': 0.0024, 'grad_norm': 0.03691738471388817, 'learning_rate': 4.0055555555555554e-05, 'epoch': 0.4}
# {'loss': 0.0014, 'grad_norm': 0.03590521216392517, 'learning_rate': 4.002777777777778e-05, 'epoch': 0.4}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 4e-05, 'epoch': 0.4}
# {'loss': 0.0008, 'grad_norm': 0.03460872545838356, 'learning_rate': 3.997222222222222e-05, 'epoch': 0.4}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 3.9944444444444446e-05, 'epoch': 0.4}
# {'loss': 0.0026, 'grad_norm': 0.034684520214796066, 'learning_rate': 3.991666666666667e-05, 'epoch': 0.4}
# {'loss': 0.0022, 'grad_norm': 0.03474491834640503, 'learning_rate': 3.9888888888888895e-05, 'epoch': 0.4}
# {'loss': 0.0016, 'grad_norm': 0.004660202190279961, 'learning_rate': 3.986111111111111e-05, 'epoch': 0.41}
# {'loss': 0.002, 'grad_norm': 0.03480569273233414, 'learning_rate': 3.983333333333333e-05, 'epoch': 0.41}
# {'loss': 0.0015, 'grad_norm': 0.0010385520290583372, 'learning_rate': 3.9805555555555555e-05, 'epoch': 0.41}
# {'loss': 0.0019, 'grad_norm': 0.0, 'learning_rate': 3.977777777777778e-05, 'epoch': 0.41}
# {'loss': 0.0007, 'grad_norm': 0.0741836428642273, 'learning_rate': 3.9750000000000004e-05, 'epoch': 0.41}
# {'loss': 0.0013, 'grad_norm': 0.06907729059457779, 'learning_rate': 3.972222222222222e-05, 'epoch': 0.41}
# {'loss': 0.0008, 'grad_norm': 0.03457235172390938, 'learning_rate': 3.9694444444444446e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.10989296436309814, 'learning_rate': 3.966666666666667e-05, 'epoch': 0.41}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 3.9638888888888895e-05, 'epoch': 0.41}
# {'loss': 0.0013, 'grad_norm': 0.05321812629699707, 'learning_rate': 3.961111111111111e-05, 'epoch': 0.42}
# {'loss': 0.0012, 'grad_norm': 0.035003840923309326, 'learning_rate': 3.958333333333333e-05, 'epoch': 0.42}
# {'loss': 0.0017, 'grad_norm': 0.03459615260362625, 'learning_rate': 3.9555555555555556e-05, 'epoch': 0.42}
# {'loss': 0.0009, 'grad_norm': 0.04841921478509903, 'learning_rate': 3.952777777777778e-05, 'epoch': 0.42}
# {'loss': 0.0009, 'grad_norm': 0.0799139067530632, 'learning_rate': 3.9500000000000005e-05, 'epoch': 0.42}
# {'loss': 0.0008, 'grad_norm': 0.03482596203684807, 'learning_rate': 3.947222222222222e-05, 'epoch': 0.42}
# {'loss': 0.0011, 'grad_norm': 0.08357507735490799, 'learning_rate': 3.944444444444445e-05, 'epoch': 0.42}
# {'loss': 0.0021, 'grad_norm': 0.03600490838289261, 'learning_rate': 3.941666666666667e-05, 'epoch': 0.42}
# {'loss': 0.0008, 'grad_norm': 0.05363095924258232, 'learning_rate': 3.938888888888889e-05, 'epoch': 0.42}
# {'loss': 0.0011, 'grad_norm': 0.15244530141353607, 'learning_rate': 3.9361111111111114e-05, 'epoch': 0.43}
# {'loss': 0.0017, 'grad_norm': 0.03493601083755493, 'learning_rate': 3.933333333333333e-05, 'epoch': 0.43}
# {'loss': 0.0015, 'grad_norm': 0.04243101924657822, 'learning_rate': 3.9305555555555556e-05, 'epoch': 0.43}
# {'loss': 0.0018, 'grad_norm': 0.0350312739610672, 'learning_rate': 3.927777777777778e-05, 'epoch': 0.43}
# {'loss': 0.0039, 'grad_norm': 0.11746826767921448, 'learning_rate': 3.9250000000000005e-05, 'epoch': 0.43}
# {'loss': 0.0017, 'grad_norm': 0.04129699617624283, 'learning_rate': 3.922222222222223e-05, 'epoch': 0.43}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 3.919444444444445e-05, 'epoch': 0.43}
# {'loss': 0.0014, 'grad_norm': 0.08032605797052383, 'learning_rate': 3.9166666666666665e-05, 'epoch': 0.43}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.913888888888889e-05, 'epoch': 0.43}
# {'loss': 0.0021, 'grad_norm': 0.03530949354171753, 'learning_rate': 3.9111111111111115e-05, 'epoch': 0.44}
# {'loss': 0.001, 'grad_norm': 0.10016345977783203, 'learning_rate': 3.908333333333333e-05, 'epoch': 0.44}
# {'loss': 0.0022, 'grad_norm': 0.06546837836503983, 'learning_rate': 3.905555555555556e-05, 'epoch': 0.44}
# {'loss': 0.0017, 'grad_norm': 0.15262308716773987, 'learning_rate': 3.902777777777778e-05, 'epoch': 0.44}
# {'loss': 0.0016, 'grad_norm': 0.03461404889822006, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.44}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.8972222222222224e-05, 'epoch': 0.44}
# {'loss': 0.0015, 'grad_norm': 0.036046769469976425, 'learning_rate': 3.894444444444444e-05, 'epoch': 0.44}
# {'loss': 0.002, 'grad_norm': 0.014995083212852478, 'learning_rate': 3.8916666666666666e-05, 'epoch': 0.44}
# {'loss': 0.0019, 'grad_norm': 0.07607558369636536, 'learning_rate': 3.888888888888889e-05, 'epoch': 0.44}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 3.8861111111111115e-05, 'epoch': 0.45}
# {'loss': 0.0012, 'grad_norm': 0.05885237455368042, 'learning_rate': 3.883333333333333e-05, 'epoch': 0.45}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 3.880555555555556e-05, 'epoch': 0.45}
# {'loss': 0.0017, 'grad_norm': 0.054414574056863785, 'learning_rate': 3.877777777777778e-05, 'epoch': 0.45}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.875e-05, 'epoch': 0.45}
# {'loss': 0.0013, 'grad_norm': 0.0755198746919632, 'learning_rate': 3.8722222222222225e-05, 'epoch': 0.45}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 3.869444444444444e-05, 'epoch': 0.45}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 3.866666666666667e-05, 'epoch': 0.45}
# {'loss': 0.0016, 'grad_norm': 0.03883828967809677, 'learning_rate': 3.863888888888889e-05, 'epoch': 0.45}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 3.8611111111111116e-05, 'epoch': 0.46}
# {'loss': 0.0007, 'grad_norm': 0.03513989970088005, 'learning_rate': 3.8583333333333334e-05, 'epoch': 0.46}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.855555555555556e-05, 'epoch': 0.46}
# {'loss': 0.002, 'grad_norm': 0.09951013326644897, 'learning_rate': 3.8527777777777776e-05, 'epoch': 0.46}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 3.85e-05, 'epoch': 0.46}
# {'loss': 0.002, 'grad_norm': 0.23064890503883362, 'learning_rate': 3.8472222222222225e-05, 'epoch': 0.46}
# {'loss': 0.0028, 'grad_norm': 0.07987578958272934, 'learning_rate': 3.844444444444444e-05, 'epoch': 0.46}
# {'loss': 0.0012, 'grad_norm': 0.03504788875579834, 'learning_rate': 3.841666666666667e-05, 'epoch': 0.46}
# {'loss': 0.0023, 'grad_norm': 0.06937912106513977, 'learning_rate': 3.838888888888889e-05, 'epoch': 0.46}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 3.836111111111112e-05, 'epoch': 0.47}
# {'loss': 0.0016, 'grad_norm': 0.06554023176431656, 'learning_rate': 3.8333333333333334e-05, 'epoch': 0.47}
# {'loss': 0.0027, 'grad_norm': 0.03567548841238022, 'learning_rate': 3.830555555555555e-05, 'epoch': 0.47}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 3.827777777777778e-05, 'epoch': 0.47}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.825e-05, 'epoch': 0.47}
# {'loss': 0.0015, 'grad_norm': 0.03494961932301521, 'learning_rate': 3.8222222222222226e-05, 'epoch': 0.47}
# {'loss': 0.0018, 'grad_norm': 0.0678315982222557, 'learning_rate': 3.8194444444444444e-05, 'epoch': 0.47}
# {'loss': 0.0015, 'grad_norm': 0.040180452167987823, 'learning_rate': 3.816666666666667e-05, 'epoch': 0.47}
# {'loss': 0.0016, 'grad_norm': 0.03584467992186546, 'learning_rate': 3.813888888888889e-05, 'epoch': 0.47}
# {'loss': 0.002, 'grad_norm': 0.07080039381980896, 'learning_rate': 3.811111111111112e-05, 'epoch': 0.48}
# {'loss': 0.0012, 'grad_norm': 0.06952346861362457, 'learning_rate': 3.8083333333333335e-05, 'epoch': 0.48}
# {'loss': 0.0012, 'grad_norm': 0.03458719700574875, 'learning_rate': 3.805555555555555e-05, 'epoch': 0.48}
# {'loss': 0.0017, 'grad_norm': 0.13054560124874115, 'learning_rate': 3.802777777777778e-05, 'epoch': 0.48}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 3.8e-05, 'epoch': 0.48}
# {'loss': 0.0014, 'grad_norm': 0.03477638214826584, 'learning_rate': 3.797222222222223e-05, 'epoch': 0.48}
# {'loss': 0.0014, 'grad_norm': 0.1203518658876419, 'learning_rate': 3.7944444444444444e-05, 'epoch': 0.48}
# {'loss': 0.0017, 'grad_norm': 0.03465849906206131, 'learning_rate': 3.791666666666667e-05, 'epoch': 0.48}
# {'loss': 0.001, 'grad_norm': 0.03610217943787575, 'learning_rate': 3.7888888888888894e-05, 'epoch': 0.48}
# {'loss': 0.0017, 'grad_norm': 0.035347532480955124, 'learning_rate': 3.786111111111111e-05, 'epoch': 0.49}
# {'loss': 0.0007, 'grad_norm': 0.036416031420230865, 'learning_rate': 3.7833333333333336e-05, 'epoch': 0.49}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.7805555555555554e-05, 'epoch': 0.49}
# {'loss': 0.0012, 'grad_norm': 0.03456299751996994, 'learning_rate': 3.777777777777778e-05, 'epoch': 0.49}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 3.775e-05, 'epoch': 0.49}
# {'loss': 0.002, 'grad_norm': 0.0, 'learning_rate': 3.772222222222223e-05, 'epoch': 0.49}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.769444444444445e-05, 'epoch': 0.49}
# {'loss': 0.0015, 'grad_norm': 0.16524551808834076, 'learning_rate': 3.766666666666667e-05, 'epoch': 0.49}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.763888888888889e-05, 'epoch': 0.49}
# {'loss': 0.002, 'grad_norm': 0.1300073266029358, 'learning_rate': 3.761111111111111e-05, 'epoch': 0.5}
# {'loss': 0.0019, 'grad_norm': 0.008393293246626854, 'learning_rate': 3.7583333333333337e-05, 'epoch': 0.5}
# {'loss': 0.0018, 'grad_norm': 0.07028786092996597, 'learning_rate': 3.7555555555555554e-05, 'epoch': 0.5}
# {'loss': 0.0014, 'grad_norm': 0.06410467624664307, 'learning_rate': 3.752777777777778e-05, 'epoch': 0.5}
# {'loss': 0.0008, 'grad_norm': 0.0760951116681099, 'learning_rate': 3.7500000000000003e-05, 'epoch': 0.5}
# {'loss': 0.0015, 'grad_norm': 0.0062668840400874615, 'learning_rate': 3.747222222222223e-05, 'epoch': 0.5}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 3.7444444444444446e-05, 'epoch': 0.5}
# {'loss': 0.0018, 'grad_norm': 0.0352487713098526, 'learning_rate': 3.7416666666666664e-05, 'epoch': 0.5}
# {'loss': 0.0019, 'grad_norm': 0.06896181404590607, 'learning_rate': 3.738888888888889e-05, 'epoch': 0.5}
# {'loss': 0.002, 'grad_norm': 0.11568281054496765, 'learning_rate': 3.736111111111111e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.03864197060465813, 'learning_rate': 3.733333333333334e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 3.7305555555555555e-05, 'epoch': 0.51}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 3.727777777777778e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.06945031881332397, 'learning_rate': 3.7250000000000004e-05, 'epoch': 0.51}
# {'loss': 0.0009, 'grad_norm': 0.023280562832951546, 'learning_rate': 3.722222222222222e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 3.7194444444444447e-05, 'epoch': 0.51}
# {'loss': 0.001, 'grad_norm': 0.0684623047709465, 'learning_rate': 3.7166666666666664e-05, 'epoch': 0.51}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 3.713888888888889e-05, 'epoch': 0.51}
# {'loss': 0.0013, 'grad_norm': 0.04001467674970627, 'learning_rate': 3.7111111111111113e-05, 'epoch': 0.52}
# {'loss': 0.0014, 'grad_norm': 0.1294526606798172, 'learning_rate': 3.708333333333334e-05, 'epoch': 0.52}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.705555555555556e-05, 'epoch': 0.52}
# {'loss': 0.001, 'grad_norm': 0.03775330260396004, 'learning_rate': 3.702777777777778e-05, 'epoch': 0.52}
# ...
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 1.0472222222222222e-05, 'epoch': 1.58}
# {'loss': 0.0006, 'grad_norm': 0.04433821141719818, 'learning_rate': 1.0444444444444445e-05, 'epoch': 1.58}
# {'loss': 0.0007, 'grad_norm': 0.038804177194833755, 'learning_rate': 1.0416666666666668e-05, 'epoch': 1.58}
# {'loss': 0.0001, 'grad_norm': 0.0, 'learning_rate': 1.038888888888889e-05, 'epoch': 1.58}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 1.0361111111111112e-05, 'epoch': 1.59}
# {'loss': 0.0007, 'grad_norm': 0.04047045111656189, 'learning_rate': 1.0333333333333333e-05, 'epoch': 1.59}
# {'loss': 0.0007, 'grad_norm': 0.06222711503505707, 'learning_rate': 1.0305555555555556e-05, 'epoch': 1.59}
# {'loss': 0.0005, 'grad_norm': 0.11555211246013641, 'learning_rate': 1.0277777777777777e-05, 'epoch': 1.59}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 1.025e-05, 'epoch': 1.59}
# {'loss': 0.0015, 'grad_norm': 0.13924813270568848, 'learning_rate': 1.0222222222222223e-05, 'epoch': 1.59}
# {'loss': 0.0014, 'grad_norm': 0.1092819944024086, 'learning_rate': 1.0194444444444446e-05, 'epoch': 1.59}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 1.0166666666666667e-05, 'epoch': 1.59}
# {'loss': 0.0008, 'grad_norm': 0.04004320502281189, 'learning_rate': 1.013888888888889e-05, 'epoch': 1.59}
# {'loss': 0.0019, 'grad_norm': 0.08318423479795456, 'learning_rate': 1.0111111111111111e-05, 'epoch': 1.6}
# {'loss': 0.0001, 'grad_norm': 0.07081661373376846, 'learning_rate': 1.0083333333333334e-05, 'epoch': 1.6}
# {'loss': 0.0004, 'grad_norm': 0.03935783728957176, 'learning_rate': 1.0055555555555555e-05, 'epoch': 1.6}
# {'loss': 0.0005, 'grad_norm': 0.0386790856719017, 'learning_rate': 1.0027777777777778e-05, 'epoch': 1.6}
# {'loss': 0.0009, 'grad_norm': 0.11566943675279617, 'learning_rate': 1e-05, 'epoch': 1.6}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 9.972222222222224e-06, 'epoch': 1.6}
# {'loss': 0.0013, 'grad_norm': 0.0902753546833992, 'learning_rate': 9.944444444444445e-06, 'epoch': 1.6}
# {'loss': 0.0007, 'grad_norm': 0.08253907412290573, 'learning_rate': 9.916666666666668e-06, 'epoch': 1.6}
# {'loss': 0.001, 'grad_norm': 0.11514543741941452, 'learning_rate': 9.888888888888889e-06, 'epoch': 1.6}
# {'loss': 0.0006, 'grad_norm': 0.10211057215929031, 'learning_rate': 9.861111111111112e-06, 'epoch': 1.61}
# {'loss': 0.0008, 'grad_norm': 0.10402397811412811, 'learning_rate': 9.833333333333333e-06, 'epoch': 1.61}
# {'loss': 0.0002, 'grad_norm': 0.038912199437618256, 'learning_rate': 9.805555555555557e-06, 'epoch': 1.61}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 9.777777777777779e-06, 'epoch': 1.61}
# {'loss': 0.0005, 'grad_norm': 0.07781321555376053, 'learning_rate': 9.750000000000002e-06, 'epoch': 1.61}
# {'loss': 0.0009, 'grad_norm': 0.03852877393364906, 'learning_rate': 9.722222222222223e-06, 'epoch': 1.61}
# {'loss': 0.0005, 'grad_norm': 0.08444409817457199, 'learning_rate': 9.694444444444446e-06, 'epoch': 1.61}
# {'loss': 0.0007, 'grad_norm': 0.13904723525047302, 'learning_rate': 9.666666666666667e-06, 'epoch': 1.61}
# {'loss': 0.0011, 'grad_norm': 0.039042286574840546, 'learning_rate': 9.63888888888889e-06, 'epoch': 1.61}
# {'loss': 0.0009, 'grad_norm': 0.15169277787208557, 'learning_rate': 9.61111111111111e-06, 'epoch': 1.62}
# {'loss': 0.0007, 'grad_norm': 0.07682602852582932, 'learning_rate': 9.583333333333334e-06, 'epoch': 1.62}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 9.555555555555556e-06, 'epoch': 1.62}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 9.52777777777778e-06, 'epoch': 1.62}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 9.5e-06, 'epoch': 1.62}
# {'loss': 0.0003, 'grad_norm': 0.07806877046823502, 'learning_rate': 9.472222222222223e-06, 'epoch': 1.62}
# {'loss': 0.0019, 'grad_norm': 0.10334867238998413, 'learning_rate': 9.444444444444445e-06, 'epoch': 1.62}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 9.416666666666667e-06, 'epoch': 1.62}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 9.388888888888889e-06, 'epoch': 1.62}
# {'loss': 0.001, 'grad_norm': 0.03835871070623398, 'learning_rate': 9.361111111111111e-06, 'epoch': 1.63}
# {'loss': 0.0014, 'grad_norm': 0.039703670889139175, 'learning_rate': 9.333333333333334e-06, 'epoch': 1.63}
# {'loss': 0.0005, 'grad_norm': 0.09427862614393234, 'learning_rate': 9.305555555555555e-06, 'epoch': 1.63}
# {'loss': 0.0001, 'grad_norm': 0.039519645273685455, 'learning_rate': 9.277777777777778e-06, 'epoch': 1.63}
# {'loss': 0.0008, 'grad_norm': 0.04230577498674393, 'learning_rate': 9.25e-06, 'epoch': 1.63}
# {'loss': 0.0008, 'grad_norm': 0.07690209150314331, 'learning_rate': 9.222222222222222e-06, 'epoch': 1.63}
# {'loss': 0.0002, 'grad_norm': 0.026839325204491615, 'learning_rate': 9.194444444444445e-06, 'epoch': 1.63}
# {'loss': 0.0007, 'grad_norm': 0.03935227170586586, 'learning_rate': 9.166666666666666e-06, 'epoch': 1.63}
# {'loss': 0.001, 'grad_norm': 0.03970583528280258, 'learning_rate': 9.13888888888889e-06, 'epoch': 1.63}
# {'loss': 0.0026, 'grad_norm': 0.08032289892435074, 'learning_rate': 9.111111111111112e-06, 'epoch': 1.64}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 9.083333333333333e-06, 'epoch': 1.64}
# {'loss': 0.0007, 'grad_norm': 0.041246529668569565, 'learning_rate': 9.055555555555556e-06, 'epoch': 1.64}
# {'loss': 0.0007, 'grad_norm': 0.041136156767606735, 'learning_rate': 9.027777777777777e-06, 'epoch': 1.64}
# {'loss': 0.0011, 'grad_norm': 0.07830040901899338, 'learning_rate': 9e-06, 'epoch': 1.64}
# {'loss': 0.0008, 'grad_norm': 0.16943906247615814, 'learning_rate': 8.972222222222221e-06, 'epoch': 1.64}
# {'loss': 0.0008, 'grad_norm': 0.0, 'learning_rate': 8.944444444444444e-06, 'epoch': 1.64}
# {'loss': 0.0014, 'grad_norm': 0.03985247388482094, 'learning_rate': 8.916666666666667e-06, 'epoch': 1.64}
# {'loss': 0.0006, 'grad_norm': 0.058670077472925186, 'learning_rate': 8.88888888888889e-06, 'epoch': 1.64}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 8.861111111111111e-06, 'epoch': 1.65}
# {'loss': 0.001, 'grad_norm': 0.02997591160237789, 'learning_rate': 8.833333333333334e-06, 'epoch': 1.65}
# {'loss': 0.0007, 'grad_norm': 0.046780429780483246, 'learning_rate': 8.805555555555555e-06, 'epoch': 1.65}
# {'loss': 0.0011, 'grad_norm': 0.0432729497551918, 'learning_rate': 8.777777777777778e-06, 'epoch': 1.65}
# {'loss': 0.0004, 'grad_norm': 0.0149422911927104, 'learning_rate': 8.75e-06, 'epoch': 1.65}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 8.722222222222224e-06, 'epoch': 1.65}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 8.694444444444445e-06, 'epoch': 1.65}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 8.666666666666668e-06, 'epoch': 1.65}
# {'loss': 0.0007, 'grad_norm': 0.10042837262153625, 'learning_rate': 8.638888888888889e-06, 'epoch': 1.65}
# {'loss': 0.0009, 'grad_norm': 0.05167258158326149, 'learning_rate': 8.611111111111112e-06, 'epoch': 1.66}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 8.583333333333333e-06, 'epoch': 1.66}
# {'loss': 0.0009, 'grad_norm': 0.04394612833857536, 'learning_rate': 8.555555555555556e-06, 'epoch': 1.66}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 8.527777777777777e-06, 'epoch': 1.66}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 8.500000000000002e-06, 'epoch': 1.66}
# {'loss': 0.0014, 'grad_norm': 0.1083945706486702, 'learning_rate': 8.472222222222223e-06, 'epoch': 1.66}
# {'loss': 0.001, 'grad_norm': 0.04128578305244446, 'learning_rate': 8.444444444444446e-06, 'epoch': 1.66}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 8.416666666666667e-06, 'epoch': 1.66}
# {'loss': 0.0015, 'grad_norm': 0.09308864176273346, 'learning_rate': 8.38888888888889e-06, 'epoch': 1.66}
# {'loss': 0.0009, 'grad_norm': 0.08222195506095886, 'learning_rate': 8.361111111111111e-06, 'epoch': 1.67}
# {'loss': 0.001, 'grad_norm': 0.040381576865911484, 'learning_rate': 8.333333333333334e-06, 'epoch': 1.67}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 8.305555555555555e-06, 'epoch': 1.67}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 8.27777777777778e-06, 'epoch': 1.67}
# {'loss': 0.0012, 'grad_norm': 0.16088183224201202, 'learning_rate': 8.25e-06, 'epoch': 1.67}
# {'loss': 0.0002, 'grad_norm': 0.03957482427358627, 'learning_rate': 8.222222222222223e-06, 'epoch': 1.67}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 8.194444444444445e-06, 'epoch': 1.67}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 8.166666666666668e-06, 'epoch': 1.67}
# {'loss': 0.0007, 'grad_norm': 0.0779549703001976, 'learning_rate': 8.138888888888889e-06, 'epoch': 1.67}
# {'loss': 0.0007, 'grad_norm': 0.05688417702913284, 'learning_rate': 8.111111111111112e-06, 'epoch': 1.68}
# {'loss': 0.0005, 'grad_norm': 0.04000794142484665, 'learning_rate': 8.083333333333333e-06, 'epoch': 1.68}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 8.055555555555557e-06, 'epoch': 1.68}
# {'loss': 0.0006, 'grad_norm': 0.03974825516343117, 'learning_rate': 8.027777777777778e-06, 'epoch': 1.68}
# {'loss': 0.0014, 'grad_norm': 0.022670714184641838, 'learning_rate': 8.000000000000001e-06, 'epoch': 1.68}
# {'loss': 0.0007, 'grad_norm': 0.10870174318552017, 'learning_rate': 7.972222222222223e-06, 'epoch': 1.68}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 7.944444444444445e-06, 'epoch': 1.68}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 7.916666666666667e-06, 'epoch': 1.68}
# {'loss': 0.0009, 'grad_norm': 0.040293168276548386, 'learning_rate': 7.88888888888889e-06, 'epoch': 1.68}
# {'loss': 0.0007, 'grad_norm': 0.04070837050676346, 'learning_rate': 7.861111111111112e-06, 'epoch': 1.69}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 7.833333333333333e-06, 'epoch': 1.69}
# {'loss': 0.0007, 'grad_norm': 0.07744625955820084, 'learning_rate': 7.805555555555556e-06, 'epoch': 1.69}
# {'loss': 0.0015, 'grad_norm': 0.013761324808001518, 'learning_rate': 7.777777777777777e-06, 'epoch': 1.69}
# {'loss': 0.0004, 'grad_norm': 0.04253542423248291, 'learning_rate': 7.75e-06, 'epoch': 1.69}
# {'loss': 0.0005, 'grad_norm': 0.0, 'learning_rate': 7.722222222222223e-06, 'epoch': 1.69}
# {'loss': 0.0003, 'grad_norm': 0.0, 'learning_rate': 7.694444444444444e-06, 'epoch': 1.69}
# {'loss': 0.0005, 'grad_norm': 0.045141883194446564, 'learning_rate': 7.666666666666667e-06, 'epoch': 1.69}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 12
#      10 trainer.args.num_train_epochs = stage['epochs']
#      11 trainer.args.learning_rate = stage['learning_rate']
# ---> 12 trainer.train()
#      13 format_string = format_string_base + str(i) + ".obj"
#      14 generate_meshes(model, obj_dir, result_dir, format_string, device,
#      15     batch_size, resolution=100, context_size=200)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:2164, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2162         hf_hub_utils.enable_progress_bars()
#    2163 else:
# -> 2164     return inner_training_loop(
#    2165         args=args,
#    2166         resume_from_checkpoint=resume_from_checkpoint,
#    2167         trial=trial,
#    2168         ignore_keys_for_eval=ignore_keys_for_eval,
#    2169     )
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:2473, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2471 update_step += 1
#    2472 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2473 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches)
#    2474 for i, inputs in enumerate(batch_samples):
#    2475     step += 1
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:5130, in Trainer.get_batch_samples(self, epoch_iterator, num_batches)
#    5128 for _ in range(num_batches):
#    5129     try:
# -> 5130         batch_samples += [next(epoch_iterator)]
#    5131     except StopIteration:
#    5132         break
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\accelerate\data_loader.py:563, in DataLoaderShard.__iter__(self)
#     561     current_batch = send_to_device(current_batch, self.device, non_blocking=self._non_blocking)
#     562 self._update_state_dict()
# --> 563 next_batch = next(dataloader_iter)
#     564 if batch_index >= self.skip_batches:
#     565     yield current_batch
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\_prog\vm_shared\attention-sdf\src\models\dataset.py:31, in LazySampleDataset.__getitem__(self, index)
#      27 loader, batch_index, sample_index = self._sample_indices_map(index)
#      28 # context shape: [num_samples, 4]
#      29 # input_data shape: [1, 3]
#      30 # label_data shape: 1
# ---> 31 context, input_data, label_data = loader.get_sample(batch_index, sample_index)
#      33 # input_data shape: [1, 3]
#      34 # label_data shape: [1, 1]
#      35 input_data = input_data.reshape(1, 3)
#
# File c:\_prog\vm_shared\attention-sdf\src\data\lazy_sample_loader.py:57, in LazySampleLoader.get_sample(self, batch_index, sample_index)
#      56 def get_sample(self, batch_index, sample_index) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
# ---> 57     context = self.file[f'batch_{batch_index}/context'][:]
#      58     input_data = self.file[f'batch_{batch_index}/input'][sample_index]
#      59     label_data = self.file[f'batch_{batch_index}/labels'][sample_index]
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\h5py\_hl\group.py:357, in Group.__getitem__(self, name)
#     355         raise ValueError("Invalid HDF5 object reference")
#     356 elif isinstance(name, (bytes, str)):
# --> 357     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358 else:
#     359     raise TypeError("Accessing a group is done with bytes or str, "
#     360                     "not {}".format(type(name)))
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5o.pyx:257, in h5py.h5o.open()
#
# KeyError: 'Unable to synchronously open object (bad object header version number)'

# %%
import json
from dataclasses import asdict

current_date = datetime.now().strftime("%Y-%m-%d")
model_name = f"{current_date}-model"
config_name = f"{current_date}-config.json"
trainer.save_model(result_dir / model_name)

with open(result_dir / config_name, 'w') as f:
    json.dump(asdict(config), f)
