# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# %load_ext autoreload
# %autoreload 2

# %%
from src.models.modules import *
from src.models.loss import L1_epsilon_lambda
from dataclasses import dataclass
import torch

torch.manual_seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

@dataclass
class SDFTransformerConfig:
    dim_context: int
    dim_input: int
    num_outputs: int
    dim_output: int
    delta: float = 0.1
    dim_hidden: int = 128
    num_inds: int = 64
    num_heads: int = 4
    ln: bool = False

class SDFTransformer(nn.Module):
    def __init__(self, config: SDFTransformerConfig):
        super(SDFTransformer, self).__init__()
        self.config = config
        self.epsilon = None
        self.lambdaa = None
        self.proj1 = nn.Linear(config.dim_input, config.dim_hidden)
        self.proj2 = nn.Linear(config.dim_context, config.dim_hidden)
        self.cross = MAB(config.dim_hidden, config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln)
        self.enc = nn.Sequential(
            SAB(config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln),
            nn.SiLU(),
            SAB(config.dim_hidden, config.dim_hidden, config.num_heads, ln=config.ln),
            nn.SiLU(),
            PMA(config.dim_hidden, config.num_heads, config.num_outputs, ln=config.ln),
            nn.SiLU(),
            nn.Linear(config.dim_hidden, config.dim_output),
            nn.Tanh()
        )

    def forward(self, context: torch.Tensor, x: torch.Tensor, labels: torch.Tensor = None):
        x = x.expand(-1, context.shape[1], -1)  # [batch_size, context_size, dim_input]
        x = self.proj1(x)                       # [batch_size, context_size, dim_hidden]
        context = self.proj2(context)           # [batch_size, context_size, dim_hidden]
        y = self.cross(x, context)              # [batch_size, context_size, dim_hidden]
        y = self.enc(y)                         # [batch_size, num_outputs, dim_output]

        loss = None
        if labels is not None:
            loss = L1_epsilon_lambda(y, labels, self.epsilon, self.lambdaa, self.config.delta)
        return {'loss': loss, 'logits': y}

config = SDFTransformerConfig(dim_context=4, dim_input=3, num_outputs=1, dim_output=1)
model = SDFTransformer(config).to(device)
print(device)
# Out:
# cuda

# %%
from src.models.dataset import LazySampleDataset
from pathlib import Path

project_dir = Path(os.path.abspath('')).resolve().parent
procesed_dir = project_dir / 'data' / 'processed'

train_files = list(procesed_dir.rglob('*_train.hdf5'))
val_files = list(procesed_dir.rglob('*_val.hdf5'))

train_dataset = LazySampleDataset(train_files)
val_dataset = LazySampleDataset(val_files)

# %%
from src.data.load_data import get_results_dir
from datetime import datetime

notebook_name = '2024_12_30_enc_mab_less_sab'
current_date = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
folder_name = f"{notebook_name}-{current_date}"
result_dir = get_results_dir() / folder_name
result_dir.mkdir(parents=True, exist_ok=True)
print(result_dir)
# Out:
# C:\_prog\vm_shared\attention-sdf\results\2024_12_30_enc_mab_less_sab-2024-12-30-12-10-34

# %%
from transformers import Trainer, TrainingArguments

batch_size = 40
training_args = TrainingArguments(
    output_dir=result_dir / "results",
    eval_strategy="epoch",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=1,
    logging_dir=result_dir / "logs",
    logging_steps=10,
    weight_decay=0.01,
    save_total_limit=3,
    seed=42
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

curriculum_schedule = [
    {"epochs": 2, "epsilon": 0.02,   "lambda": 0.0,  'learning_rate': 5e-5},
    {"epochs": 2, "epsilon": 0.0075, "lambda": 0.15, 'learning_rate': 4e-5},
    {"epochs": 2, "epsilon": 0.004,  "lambda": 0.3,  'learning_rate': 3e-5},
    {"epochs": 2, "epsilon": 0.002,  "lambda": 0.4,  'learning_rate': 2e-5},
    {"epochs": 2, "epsilon": 0.0,    "lambda": 0.5,  'learning_rate': 1e-5}
]

# %%
from src.visualization.generate_mesh import generate_meshes
from src.data.load_data import get_data_dir

obj_dir = get_data_dir() / 'intermediate'
format_string_base = "{name}-" + current_date + "-curriculum-"

for i, stage in enumerate(curriculum_schedule):
    model.epsilon = stage['epsilon']
    model.lambdaa = stage['lambda']
    trainer.args.num_train_epochs = stage['epochs']
    trainer.args.learning_rate = stage['learning_rate']
    trainer.train()
    format_string = format_string_base + str(i) + ".obj"
    generate_meshes(model, obj_dir, result_dir, format_string, device,
        batch_size, resolution=100, context_size=200)
train_dataset.close()
val_dataset.close()
# Out:
#   0%|          | 0/18000 [00:00<?, ?it/s]
# {'loss': 0.0046, 'grad_norm': 0.0, 'learning_rate': 4.997222222222223e-05, 'epoch': 0.0}
# {'loss': 0.0037, 'grad_norm': 0.0, 'learning_rate': 4.994444444444445e-05, 'epoch': 0.0}
# {'loss': 0.0048, 'grad_norm': 0.012874833308160305, 'learning_rate': 4.991666666666667e-05, 'epoch': 0.0}
# {'loss': 0.0018, 'grad_norm': 0.07508909702301025, 'learning_rate': 4.9888888888888894e-05, 'epoch': 0.0}
# {'loss': 0.0029, 'grad_norm': 0.037999626249074936, 'learning_rate': 4.986111111111111e-05, 'epoch': 0.01}
# {'loss': 0.0022, 'grad_norm': 0.45732662081718445, 'learning_rate': 4.9833333333333336e-05, 'epoch': 0.01}
# {'loss': 0.0024, 'grad_norm': 0.03754843398928642, 'learning_rate': 4.9805555555555554e-05, 'epoch': 0.01}
# {'loss': 0.0049, 'grad_norm': 0.023657361045479774, 'learning_rate': 4.977777777777778e-05, 'epoch': 0.01}
# {'loss': 0.0022, 'grad_norm': 0.03818686306476593, 'learning_rate': 4.975e-05, 'epoch': 0.01}
# {'loss': 0.0033, 'grad_norm': 0.11583506315946579, 'learning_rate': 4.972222222222223e-05, 'epoch': 0.01}
# {'loss': 0.0028, 'grad_norm': 0.15284523367881775, 'learning_rate': 4.969444444444445e-05, 'epoch': 0.01}
# {'loss': 0.0029, 'grad_norm': 0.11862605810165405, 'learning_rate': 4.966666666666667e-05, 'epoch': 0.01}
# {'loss': 0.0028, 'grad_norm': 0.03776296600699425, 'learning_rate': 4.963888888888889e-05, 'epoch': 0.01}
# {'loss': 0.0025, 'grad_norm': 0.010239721275866032, 'learning_rate': 4.961111111111111e-05, 'epoch': 0.02}
# {'loss': 0.0031, 'grad_norm': 0.0407366007566452, 'learning_rate': 4.958333333333334e-05, 'epoch': 0.02}
# {'loss': 0.0033, 'grad_norm': 0.04270511865615845, 'learning_rate': 4.955555555555556e-05, 'epoch': 0.02}
# {'loss': 0.003, 'grad_norm': 0.037953272461891174, 'learning_rate': 4.952777777777778e-05, 'epoch': 0.02}
# {'loss': 0.0034, 'grad_norm': 0.038805995136499405, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.02}
# {'loss': 0.0028, 'grad_norm': 0.010981857776641846, 'learning_rate': 4.947222222222223e-05, 'epoch': 0.02}
# {'loss': 0.0026, 'grad_norm': 0.016270184889435768, 'learning_rate': 4.9444444444444446e-05, 'epoch': 0.02}
# {'loss': 0.0035, 'grad_norm': 0.043846677988767624, 'learning_rate': 4.9416666666666664e-05, 'epoch': 0.02}
# {'loss': 0.0024, 'grad_norm': 0.04191312938928604, 'learning_rate': 4.938888888888889e-05, 'epoch': 0.02}
# {'loss': 0.0034, 'grad_norm': 0.3454299569129944, 'learning_rate': 4.936111111111111e-05, 'epoch': 0.03}
# {'loss': 0.0031, 'grad_norm': 0.023814819753170013, 'learning_rate': 4.933333333333334e-05, 'epoch': 0.03}
# {'loss': 0.0033, 'grad_norm': 0.02183450013399124, 'learning_rate': 4.930555555555556e-05, 'epoch': 0.03}
# {'loss': 0.0039, 'grad_norm': 0.01840117760002613, 'learning_rate': 4.927777777777778e-05, 'epoch': 0.03}
# {'loss': 0.0035, 'grad_norm': 0.12282896041870117, 'learning_rate': 4.9250000000000004e-05, 'epoch': 0.03}
# {'loss': 0.0024, 'grad_norm': 0.04073766991496086, 'learning_rate': 4.922222222222222e-05, 'epoch': 0.03}
# {'loss': 0.003, 'grad_norm': 0.19655673205852509, 'learning_rate': 4.919444444444445e-05, 'epoch': 0.03}
# {'loss': 0.0031, 'grad_norm': 0.04246172308921814, 'learning_rate': 4.9166666666666665e-05, 'epoch': 0.03}
# {'loss': 0.0026, 'grad_norm': 0.04094899073243141, 'learning_rate': 4.913888888888889e-05, 'epoch': 0.03}
# {'loss': 0.0022, 'grad_norm': 0.07786436378955841, 'learning_rate': 4.9111111111111114e-05, 'epoch': 0.04}
# {'loss': 0.0025, 'grad_norm': 0.055811647325754166, 'learning_rate': 4.908333333333334e-05, 'epoch': 0.04}
# {'loss': 0.0023, 'grad_norm': 0.0888977125287056, 'learning_rate': 4.905555555555556e-05, 'epoch': 0.04}
# {'loss': 0.002, 'grad_norm': 0.11979106068611145, 'learning_rate': 4.902777777777778e-05, 'epoch': 0.04}
# {'loss': 0.0017, 'grad_norm': 0.08709105849266052, 'learning_rate': 4.9e-05, 'epoch': 0.04}
# {'loss': 0.0027, 'grad_norm': 0.04292783513665199, 'learning_rate': 4.897222222222222e-05, 'epoch': 0.04}
# {'loss': 0.0026, 'grad_norm': 0.20729711651802063, 'learning_rate': 4.894444444444445e-05, 'epoch': 0.04}
# {'loss': 0.0025, 'grad_norm': 0.04803386330604553, 'learning_rate': 4.891666666666667e-05, 'epoch': 0.04}
# {'loss': 0.0025, 'grad_norm': 0.07980114966630936, 'learning_rate': 4.888888888888889e-05, 'epoch': 0.04}
# {'loss': 0.0023, 'grad_norm': 0.08451977372169495, 'learning_rate': 4.8861111111111114e-05, 'epoch': 0.05}
# {'loss': 0.0029, 'grad_norm': 0.08363296836614609, 'learning_rate': 4.883333333333334e-05, 'epoch': 0.05}
# {'loss': 0.003, 'grad_norm': 0.16734591126441956, 'learning_rate': 4.880555555555556e-05, 'epoch': 0.05}
# {'loss': 0.0024, 'grad_norm': 0.12346808612346649, 'learning_rate': 4.8777777777777775e-05, 'epoch': 0.05}
# {'loss': 0.0019, 'grad_norm': 0.0677865743637085, 'learning_rate': 4.875e-05, 'epoch': 0.05}
# {'loss': 0.0017, 'grad_norm': 0.05310291424393654, 'learning_rate': 4.8722222222222224e-05, 'epoch': 0.05}
# {'loss': 0.001, 'grad_norm': 0.04377949982881546, 'learning_rate': 4.869444444444445e-05, 'epoch': 0.05}
# {'loss': 0.0022, 'grad_norm': 0.09792273491621017, 'learning_rate': 4.866666666666667e-05, 'epoch': 0.05}
# {'loss': 0.0014, 'grad_norm': 0.12142353504896164, 'learning_rate': 4.863888888888889e-05, 'epoch': 0.05}
# {'loss': 0.0021, 'grad_norm': 0.04576355218887329, 'learning_rate': 4.8611111111111115e-05, 'epoch': 0.06}
# {'loss': 0.0019, 'grad_norm': 0.0411749891936779, 'learning_rate': 4.858333333333333e-05, 'epoch': 0.06}
# {'loss': 0.0018, 'grad_norm': 0.0931159108877182, 'learning_rate': 4.855555555555556e-05, 'epoch': 0.06}
# {'loss': 0.0025, 'grad_norm': 0.04320146515965462, 'learning_rate': 4.8527777777777775e-05, 'epoch': 0.06}
# {'loss': 0.0031, 'grad_norm': 0.055482540279626846, 'learning_rate': 4.85e-05, 'epoch': 0.06}
# {'loss': 0.0033, 'grad_norm': 0.08561382442712784, 'learning_rate': 4.8472222222222224e-05, 'epoch': 0.06}
# {'loss': 0.002, 'grad_norm': 0.04714829847216606, 'learning_rate': 4.844444444444445e-05, 'epoch': 0.06}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.8416666666666673e-05, 'epoch': 0.06}
# {'loss': 0.0021, 'grad_norm': 0.1330793797969818, 'learning_rate': 4.838888888888889e-05, 'epoch': 0.06}
# {'loss': 0.0022, 'grad_norm': 0.0907474085688591, 'learning_rate': 4.8361111111111116e-05, 'epoch': 0.07}
# {'loss': 0.0013, 'grad_norm': 0.04068432003259659, 'learning_rate': 4.8333333333333334e-05, 'epoch': 0.07}
# {'loss': 0.0021, 'grad_norm': 0.11813599616289139, 'learning_rate': 4.830555555555556e-05, 'epoch': 0.07}
# {'loss': 0.0024, 'grad_norm': 0.02455323003232479, 'learning_rate': 4.8277777777777776e-05, 'epoch': 0.07}
# {'loss': 0.0027, 'grad_norm': 0.06597454100847244, 'learning_rate': 4.825e-05, 'epoch': 0.07}
# {'loss': 0.0024, 'grad_norm': 0.08825764060020447, 'learning_rate': 4.8222222222222225e-05, 'epoch': 0.07}
# {'loss': 0.0019, 'grad_norm': 0.028765983879566193, 'learning_rate': 4.819444444444445e-05, 'epoch': 0.07}
# {'loss': 0.0024, 'grad_norm': 0.04459753632545471, 'learning_rate': 4.8166666666666674e-05, 'epoch': 0.07}
# {'loss': 0.0012, 'grad_norm': 0.04664827138185501, 'learning_rate': 4.813888888888889e-05, 'epoch': 0.07}
# {'loss': 0.0027, 'grad_norm': 0.06890961527824402, 'learning_rate': 4.811111111111111e-05, 'epoch': 0.08}
# {'loss': 0.0021, 'grad_norm': 0.08526591211557388, 'learning_rate': 4.8083333333333334e-05, 'epoch': 0.08}
# {'loss': 0.0029, 'grad_norm': 0.1717272400856018, 'learning_rate': 4.805555555555556e-05, 'epoch': 0.08}
# {'loss': 0.0017, 'grad_norm': 0.039080437272787094, 'learning_rate': 4.8027777777777783e-05, 'epoch': 0.08}
# {'loss': 0.0017, 'grad_norm': 0.0778021439909935, 'learning_rate': 4.8e-05, 'epoch': 0.08}
# {'loss': 0.0019, 'grad_norm': 0.08474027365446091, 'learning_rate': 4.7972222222222226e-05, 'epoch': 0.08}
# {'loss': 0.0014, 'grad_norm': 0.05172029510140419, 'learning_rate': 4.794444444444445e-05, 'epoch': 0.08}
# {'loss': 0.0022, 'grad_norm': 0.22046607732772827, 'learning_rate': 4.791666666666667e-05, 'epoch': 0.08}
# {'loss': 0.0018, 'grad_norm': 0.042284246534109116, 'learning_rate': 4.7888888888888886e-05, 'epoch': 0.08}
# {'loss': 0.003, 'grad_norm': 0.02543971873819828, 'learning_rate': 4.786111111111111e-05, 'epoch': 0.09}
# {'loss': 0.002, 'grad_norm': 0.04928995296359062, 'learning_rate': 4.7833333333333335e-05, 'epoch': 0.09}
# {'loss': 0.0017, 'grad_norm': 0.12729351222515106, 'learning_rate': 4.780555555555556e-05, 'epoch': 0.09}
# {'loss': 0.0026, 'grad_norm': 0.07785483449697495, 'learning_rate': 4.7777777777777784e-05, 'epoch': 0.09}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 4.775e-05, 'epoch': 0.09}
# {'loss': 0.0026, 'grad_norm': 0.17436103522777557, 'learning_rate': 4.7722222222222226e-05, 'epoch': 0.09}
# {'loss': 0.002, 'grad_norm': 0.04869796708226204, 'learning_rate': 4.7694444444444444e-05, 'epoch': 0.09}
# {'loss': 0.0017, 'grad_norm': 0.01672240160405636, 'learning_rate': 4.766666666666667e-05, 'epoch': 0.09}
# {'loss': 0.0019, 'grad_norm': 0.16828860342502594, 'learning_rate': 4.7638888888888887e-05, 'epoch': 0.09}
# {'loss': 0.0025, 'grad_norm': 0.04566233232617378, 'learning_rate': 4.761111111111111e-05, 'epoch': 0.1}
# {'loss': 0.0024, 'grad_norm': 0.02899135649204254, 'learning_rate': 4.7583333333333336e-05, 'epoch': 0.1}
# {'loss': 0.0024, 'grad_norm': 0.06361635029315948, 'learning_rate': 4.755555555555556e-05, 'epoch': 0.1}
# {'loss': 0.0012, 'grad_norm': 0.07759877294301987, 'learning_rate': 4.7527777777777785e-05, 'epoch': 0.1}
# {'loss': 0.0017, 'grad_norm': 0.04338333383202553, 'learning_rate': 4.75e-05, 'epoch': 0.1}
# {'loss': 0.001, 'grad_norm': 0.05078303441405296, 'learning_rate': 4.747222222222222e-05, 'epoch': 0.1}
# {'loss': 0.0017, 'grad_norm': 0.007403770461678505, 'learning_rate': 4.7444444444444445e-05, 'epoch': 0.1}
# {'loss': 0.0014, 'grad_norm': 0.2011820375919342, 'learning_rate': 4.741666666666667e-05, 'epoch': 0.1}
# {'loss': 0.0016, 'grad_norm': 0.03771458938717842, 'learning_rate': 4.7388888888888894e-05, 'epoch': 0.1}
# {'loss': 0.002, 'grad_norm': 0.25274139642715454, 'learning_rate': 4.736111111111111e-05, 'epoch': 0.11}
# {'loss': 0.0026, 'grad_norm': 0.04449184238910675, 'learning_rate': 4.7333333333333336e-05, 'epoch': 0.11}
# {'loss': 0.0019, 'grad_norm': 0.08915390074253082, 'learning_rate': 4.730555555555556e-05, 'epoch': 0.11}
# {'loss': 0.0019, 'grad_norm': 0.047843072563409805, 'learning_rate': 4.727777777777778e-05, 'epoch': 0.11}
# {'loss': 0.0023, 'grad_norm': 0.05506308376789093, 'learning_rate': 4.7249999999999997e-05, 'epoch': 0.11}
# {'loss': 0.0019, 'grad_norm': 0.12307324260473251, 'learning_rate': 4.722222222222222e-05, 'epoch': 0.11}
# {'loss': 0.0021, 'grad_norm': 0.0851581022143364, 'learning_rate': 4.7194444444444446e-05, 'epoch': 0.11}
# {'loss': 0.002, 'grad_norm': 0.045290134847164154, 'learning_rate': 4.716666666666667e-05, 'epoch': 0.11}
# {'loss': 0.003, 'grad_norm': 0.040845274925231934, 'learning_rate': 4.7138888888888895e-05, 'epoch': 0.11}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.711111111111111e-05, 'epoch': 0.12}
# {'loss': 0.0011, 'grad_norm': 0.05003923177719116, 'learning_rate': 4.708333333333334e-05, 'epoch': 0.12}
# {'loss': 0.0019, 'grad_norm': 0.04865901917219162, 'learning_rate': 4.7055555555555555e-05, 'epoch': 0.12}
# {'loss': 0.0018, 'grad_norm': 0.16866375505924225, 'learning_rate': 4.702777777777778e-05, 'epoch': 0.12}
# {'loss': 0.0022, 'grad_norm': 0.0938505306839943, 'learning_rate': 4.7e-05, 'epoch': 0.12}
# {'loss': 0.0018, 'grad_norm': 0.03454219922423363, 'learning_rate': 4.697222222222222e-05, 'epoch': 0.12}
# {'loss': 0.0028, 'grad_norm': 0.05491175130009651, 'learning_rate': 4.6944444444444446e-05, 'epoch': 0.12}
# {'loss': 0.0015, 'grad_norm': 0.0869622528553009, 'learning_rate': 4.691666666666667e-05, 'epoch': 0.12}
# {'loss': 0.0025, 'grad_norm': 0.25444793701171875, 'learning_rate': 4.6888888888888895e-05, 'epoch': 0.12}
# {'loss': 0.0018, 'grad_norm': 0.05036540329456329, 'learning_rate': 4.686111111111111e-05, 'epoch': 0.13}
# {'loss': 0.0013, 'grad_norm': 0.08339270204305649, 'learning_rate': 4.683333333333334e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.0697704404592514, 'learning_rate': 4.6805555555555556e-05, 'epoch': 0.13}
# {'loss': 0.0024, 'grad_norm': 0.03346357122063637, 'learning_rate': 4.677777777777778e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.6750000000000005e-05, 'epoch': 0.13}
# {'loss': 0.0014, 'grad_norm': 0.04808272793889046, 'learning_rate': 4.672222222222222e-05, 'epoch': 0.13}
# {'loss': 0.001, 'grad_norm': 0.04985141381621361, 'learning_rate': 4.669444444444445e-05, 'epoch': 0.13}
# {'loss': 0.002, 'grad_norm': 0.16206280887126923, 'learning_rate': 4.666666666666667e-05, 'epoch': 0.13}
# {'loss': 0.0015, 'grad_norm': 0.0312274731695652, 'learning_rate': 4.6638888888888896e-05, 'epoch': 0.13}
# {'loss': 0.0016, 'grad_norm': 0.044736433774232864, 'learning_rate': 4.6611111111111114e-05, 'epoch': 0.14}
# {'loss': 0.0026, 'grad_norm': 0.03967253863811493, 'learning_rate': 4.658333333333333e-05, 'epoch': 0.14}
# {'loss': 0.0025, 'grad_norm': 0.05793159455060959, 'learning_rate': 4.6555555555555556e-05, 'epoch': 0.14}
# {'loss': 0.0017, 'grad_norm': 0.0868169516324997, 'learning_rate': 4.652777777777778e-05, 'epoch': 0.14}
# {'loss': 0.0033, 'grad_norm': 0.04442141577601433, 'learning_rate': 4.6500000000000005e-05, 'epoch': 0.14}
# {'loss': 0.0011, 'grad_norm': 0.03791926056146622, 'learning_rate': 4.647222222222222e-05, 'epoch': 0.14}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.644444444444445e-05, 'epoch': 0.14}
# {'loss': 0.0018, 'grad_norm': 0.06077360361814499, 'learning_rate': 4.641666666666667e-05, 'epoch': 0.14}
# {'loss': 0.002, 'grad_norm': 0.156024768948555, 'learning_rate': 4.638888888888889e-05, 'epoch': 0.14}
# {'loss': 0.0019, 'grad_norm': 0.046985745429992676, 'learning_rate': 4.636111111111111e-05, 'epoch': 0.15}
# {'loss': 0.0017, 'grad_norm': 0.13016818463802338, 'learning_rate': 4.633333333333333e-05, 'epoch': 0.15}
# {'loss': 0.002, 'grad_norm': 0.04057003930211067, 'learning_rate': 4.630555555555556e-05, 'epoch': 0.15}
# {'loss': 0.0019, 'grad_norm': 0.04516233876347542, 'learning_rate': 4.627777777777778e-05, 'epoch': 0.15}
# {'loss': 0.0025, 'grad_norm': 0.08551488816738129, 'learning_rate': 4.6250000000000006e-05, 'epoch': 0.15}
# {'loss': 0.0008, 'grad_norm': 0.08153549581766129, 'learning_rate': 4.6222222222222224e-05, 'epoch': 0.15}
# {'loss': 0.0035, 'grad_norm': 0.0343908816576004, 'learning_rate': 4.619444444444445e-05, 'epoch': 0.15}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.6166666666666666e-05, 'epoch': 0.15}
# {'loss': 0.0014, 'grad_norm': 0.04550142213702202, 'learning_rate': 4.613888888888889e-05, 'epoch': 0.15}
# {'loss': 0.002, 'grad_norm': 0.10079826414585114, 'learning_rate': 4.6111111111111115e-05, 'epoch': 0.16}
# {'loss': 0.0016, 'grad_norm': 0.39337772130966187, 'learning_rate': 4.608333333333333e-05, 'epoch': 0.16}
# {'loss': 0.0023, 'grad_norm': 0.056548576802015305, 'learning_rate': 4.605555555555556e-05, 'epoch': 0.16}
# {'loss': 0.001, 'grad_norm': 0.17142370343208313, 'learning_rate': 4.602777777777778e-05, 'epoch': 0.16}
# {'loss': 0.0022, 'grad_norm': 0.09876811504364014, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.16}
# {'loss': 0.0018, 'grad_norm': 0.08398269861936569, 'learning_rate': 4.5972222222222225e-05, 'epoch': 0.16}
# {'loss': 0.0022, 'grad_norm': 0.09183266013860703, 'learning_rate': 4.594444444444444e-05, 'epoch': 0.16}
# {'loss': 0.0013, 'grad_norm': 0.09031883627176285, 'learning_rate': 4.591666666666667e-05, 'epoch': 0.16}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.588888888888889e-05, 'epoch': 0.16}
# {'loss': 0.0027, 'grad_norm': 0.16526800394058228, 'learning_rate': 4.5861111111111116e-05, 'epoch': 0.17}
# {'loss': 0.0019, 'grad_norm': 0.04412636160850525, 'learning_rate': 4.5833333333333334e-05, 'epoch': 0.17}
# {'loss': 0.0015, 'grad_norm': 0.12602826952934265, 'learning_rate': 4.580555555555556e-05, 'epoch': 0.17}
# {'loss': 0.0027, 'grad_norm': 0.04136775806546211, 'learning_rate': 4.577777777777778e-05, 'epoch': 0.17}
# {'loss': 0.0015, 'grad_norm': 0.13540761172771454, 'learning_rate': 4.575e-05, 'epoch': 0.17}
# {'loss': 0.002, 'grad_norm': 0.0451531708240509, 'learning_rate': 4.572222222222222e-05, 'epoch': 0.17}
# {'loss': 0.0017, 'grad_norm': 0.07544638216495514, 'learning_rate': 4.569444444444444e-05, 'epoch': 0.17}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.566666666666667e-05, 'epoch': 0.17}
# {'loss': 0.0018, 'grad_norm': 0.10193813592195511, 'learning_rate': 4.563888888888889e-05, 'epoch': 0.17}
# {'loss': 0.0013, 'grad_norm': 0.06305017322301865, 'learning_rate': 4.561111111111112e-05, 'epoch': 0.18}
# {'loss': 0.0016, 'grad_norm': 0.05276605859398842, 'learning_rate': 4.5583333333333335e-05, 'epoch': 0.18}
# {'loss': 0.0007, 'grad_norm': 0.04623772203922272, 'learning_rate': 4.555555555555556e-05, 'epoch': 0.18}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.5527777777777784e-05, 'epoch': 0.18}
# {'loss': 0.0014, 'grad_norm': 0.04739390313625336, 'learning_rate': 4.55e-05, 'epoch': 0.18}
# {'loss': 0.0024, 'grad_norm': 0.0957808792591095, 'learning_rate': 4.5472222222222226e-05, 'epoch': 0.18}
# {'loss': 0.0013, 'grad_norm': 0.09092510491609573, 'learning_rate': 4.5444444444444444e-05, 'epoch': 0.18}
# {'loss': 0.0014, 'grad_norm': 0.12647074460983276, 'learning_rate': 4.541666666666667e-05, 'epoch': 0.18}
# {'loss': 0.0007, 'grad_norm': 0.04784683138132095, 'learning_rate': 4.538888888888889e-05, 'epoch': 0.18}
# {'loss': 0.0024, 'grad_norm': 0.015777764841914177, 'learning_rate': 4.536111111111112e-05, 'epoch': 0.19}
# {'loss': 0.0025, 'grad_norm': 0.12247724831104279, 'learning_rate': 4.5333333333333335e-05, 'epoch': 0.19}
# {'loss': 0.0008, 'grad_norm': 0.14198558032512665, 'learning_rate': 4.530555555555556e-05, 'epoch': 0.19}
# {'loss': 0.003, 'grad_norm': 0.10687557607889175, 'learning_rate': 4.527777777777778e-05, 'epoch': 0.19}
# {'loss': 0.0019, 'grad_norm': 0.0, 'learning_rate': 4.525e-05, 'epoch': 0.19}
# {'loss': 0.0013, 'grad_norm': 0.09257568418979645, 'learning_rate': 4.522222222222223e-05, 'epoch': 0.19}
# {'loss': 0.0015, 'grad_norm': 0.2114313840866089, 'learning_rate': 4.5194444444444444e-05, 'epoch': 0.19}
# {'loss': 0.0008, 'grad_norm': 0.02182730659842491, 'learning_rate': 4.516666666666667e-05, 'epoch': 0.19}
# {'loss': 0.0016, 'grad_norm': 0.12479213625192642, 'learning_rate': 4.5138888888888894e-05, 'epoch': 0.19}
# {'loss': 0.0021, 'grad_norm': 0.039793651551008224, 'learning_rate': 4.511111111111112e-05, 'epoch': 0.2}
# {'loss': 0.003, 'grad_norm': 0.058756180107593536, 'learning_rate': 4.5083333333333336e-05, 'epoch': 0.2}
# {'loss': 0.0027, 'grad_norm': 0.08684410154819489, 'learning_rate': 4.5055555555555554e-05, 'epoch': 0.2}
# {'loss': 0.0021, 'grad_norm': 0.057212360203266144, 'learning_rate': 4.502777777777778e-05, 'epoch': 0.2}
# {'loss': 0.0021, 'grad_norm': 0.06885302811861038, 'learning_rate': 4.5e-05, 'epoch': 0.2}
# {'loss': 0.0028, 'grad_norm': 0.043626513332128525, 'learning_rate': 4.497222222222223e-05, 'epoch': 0.2}
# {'loss': 0.0018, 'grad_norm': 0.04920900985598564, 'learning_rate': 4.4944444444444445e-05, 'epoch': 0.2}
# {'loss': 0.0013, 'grad_norm': 0.08908695727586746, 'learning_rate': 4.491666666666667e-05, 'epoch': 0.2}
# {'loss': 0.0009, 'grad_norm': 0.042212456464767456, 'learning_rate': 4.4888888888888894e-05, 'epoch': 0.2}
# {'loss': 0.0012, 'grad_norm': 0.0528106689453125, 'learning_rate': 4.486111111111111e-05, 'epoch': 0.21}
# {'loss': 0.0021, 'grad_norm': 0.09631174802780151, 'learning_rate': 4.483333333333333e-05, 'epoch': 0.21}
# {'loss': 0.0006, 'grad_norm': 0.05378640070557594, 'learning_rate': 4.4805555555555554e-05, 'epoch': 0.21}
# {'loss': 0.002, 'grad_norm': 0.06542681902647018, 'learning_rate': 4.477777777777778e-05, 'epoch': 0.21}
# {'loss': 0.0017, 'grad_norm': 0.10111606121063232, 'learning_rate': 4.4750000000000004e-05, 'epoch': 0.21}
# {'loss': 0.0021, 'grad_norm': 0.06895923614501953, 'learning_rate': 4.472222222222223e-05, 'epoch': 0.21}
# {'loss': 0.0019, 'grad_norm': 0.05885821580886841, 'learning_rate': 4.4694444444444446e-05, 'epoch': 0.21}
# {'loss': 0.0018, 'grad_norm': 0.05969052389264107, 'learning_rate': 4.466666666666667e-05, 'epoch': 0.21}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.463888888888889e-05, 'epoch': 0.21}
# {'loss': 0.0017, 'grad_norm': 0.2553161084651947, 'learning_rate': 4.461111111111111e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.05062435567378998, 'learning_rate': 4.458333333333334e-05, 'epoch': 0.22}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.4555555555555555e-05, 'epoch': 0.22}
# {'loss': 0.0007, 'grad_norm': 0.08792199194431305, 'learning_rate': 4.452777777777778e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.13383325934410095, 'learning_rate': 4.4500000000000004e-05, 'epoch': 0.22}
# {'loss': 0.0028, 'grad_norm': 0.05884157866239548, 'learning_rate': 4.447222222222223e-05, 'epoch': 0.22}
# {'loss': 0.0018, 'grad_norm': 0.2253136783838272, 'learning_rate': 4.4444444444444447e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.16162259876728058, 'learning_rate': 4.4416666666666664e-05, 'epoch': 0.22}
# {'loss': 0.0016, 'grad_norm': 0.09100479632616043, 'learning_rate': 4.438888888888889e-05, 'epoch': 0.22}
# {'loss': 0.0017, 'grad_norm': 0.06016434356570244, 'learning_rate': 4.4361111111111113e-05, 'epoch': 0.23}
# {'loss': 0.0013, 'grad_norm': 0.0595206618309021, 'learning_rate': 4.433333333333334e-05, 'epoch': 0.23}
# {'loss': 0.0007, 'grad_norm': 0.06375473737716675, 'learning_rate': 4.4305555555555556e-05, 'epoch': 0.23}
# {'loss': 0.0016, 'grad_norm': 0.01855495758354664, 'learning_rate': 4.427777777777778e-05, 'epoch': 0.23}
# {'loss': 0.0011, 'grad_norm': 0.047394197434186935, 'learning_rate': 4.4250000000000005e-05, 'epoch': 0.23}
# {'loss': 0.0022, 'grad_norm': 0.04905235022306442, 'learning_rate': 4.422222222222222e-05, 'epoch': 0.23}
# {'loss': 0.0017, 'grad_norm': 0.1319192349910736, 'learning_rate': 4.419444444444444e-05, 'epoch': 0.23}
# {'loss': 0.002, 'grad_norm': 0.04546503722667694, 'learning_rate': 4.4166666666666665e-05, 'epoch': 0.23}
# {'loss': 0.0019, 'grad_norm': 0.08359447121620178, 'learning_rate': 4.413888888888889e-05, 'epoch': 0.23}
# {'loss': 0.0019, 'grad_norm': 0.048676274716854095, 'learning_rate': 4.4111111111111114e-05, 'epoch': 0.24}
# {'loss': 0.0012, 'grad_norm': 0.1068916767835617, 'learning_rate': 4.408333333333334e-05, 'epoch': 0.24}
# {'loss': 0.0017, 'grad_norm': 0.046845078468322754, 'learning_rate': 4.4055555555555557e-05, 'epoch': 0.24}
# {'loss': 0.0019, 'grad_norm': 0.11826872825622559, 'learning_rate': 4.402777777777778e-05, 'epoch': 0.24}
# {'loss': 0.002, 'grad_norm': 0.10562068969011307, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.24}
# {'loss': 0.0008, 'grad_norm': 0.06638019531965256, 'learning_rate': 4.3972222222222223e-05, 'epoch': 0.24}
# {'loss': 0.0013, 'grad_norm': 0.02812756970524788, 'learning_rate': 4.394444444444445e-05, 'epoch': 0.24}
# {'loss': 0.0012, 'grad_norm': 0.05045194923877716, 'learning_rate': 4.3916666666666666e-05, 'epoch': 0.24}
# {'loss': 0.0012, 'grad_norm': 0.06637567281723022, 'learning_rate': 4.388888888888889e-05, 'epoch': 0.24}
# {'loss': 0.0019, 'grad_norm': 0.1133052334189415, 'learning_rate': 4.3861111111111115e-05, 'epoch': 0.25}
# {'loss': 0.0014, 'grad_norm': 0.260912150144577, 'learning_rate': 4.383333333333334e-05, 'epoch': 0.25}
# {'loss': 0.0016, 'grad_norm': 0.05158710852265358, 'learning_rate': 4.380555555555556e-05, 'epoch': 0.25}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 4.377777777777778e-05, 'epoch': 0.25}
# {'loss': 0.0012, 'grad_norm': 0.04719589650630951, 'learning_rate': 4.375e-05, 'epoch': 0.25}
# {'loss': 0.0012, 'grad_norm': 0.08738793432712555, 'learning_rate': 4.3722222222222224e-05, 'epoch': 0.25}
# {'loss': 0.001, 'grad_norm': 0.04167716205120087, 'learning_rate': 4.369444444444445e-05, 'epoch': 0.25}
# {'loss': 0.0017, 'grad_norm': 0.16427907347679138, 'learning_rate': 4.3666666666666666e-05, 'epoch': 0.25}
# {'loss': 0.0016, 'grad_norm': 0.03268570825457573, 'learning_rate': 4.363888888888889e-05, 'epoch': 0.25}
# {'loss': 0.0012, 'grad_norm': 0.0691411942243576, 'learning_rate': 4.3611111111111116e-05, 'epoch': 0.26}
# {'loss': 0.0021, 'grad_norm': 0.08586279302835464, 'learning_rate': 4.358333333333334e-05, 'epoch': 0.26}
# {'loss': 0.0013, 'grad_norm': 0.045763060450553894, 'learning_rate': 4.355555555555556e-05, 'epoch': 0.26}
# {'loss': 0.0022, 'grad_norm': 0.0845598503947258, 'learning_rate': 4.3527777777777776e-05, 'epoch': 0.26}
# {'loss': 0.0017, 'grad_norm': 0.18494091928005219, 'learning_rate': 4.35e-05, 'epoch': 0.26}
# {'loss': 0.0017, 'grad_norm': 0.1315678060054779, 'learning_rate': 4.3472222222222225e-05, 'epoch': 0.26}
# {'loss': 0.0011, 'grad_norm': 0.04526582360267639, 'learning_rate': 4.344444444444445e-05, 'epoch': 0.26}
# {'loss': 0.0023, 'grad_norm': 0.04929826408624649, 'learning_rate': 4.341666666666667e-05, 'epoch': 0.26}
# {'loss': 0.0019, 'grad_norm': 0.13169391453266144, 'learning_rate': 4.338888888888889e-05, 'epoch': 0.26}
# {'loss': 0.0013, 'grad_norm': 0.09297119081020355, 'learning_rate': 4.3361111111111116e-05, 'epoch': 0.27}
# {'loss': 0.0013, 'grad_norm': 0.08215638250112534, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.27}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.330555555555556e-05, 'epoch': 0.27}
# {'loss': 0.0008, 'grad_norm': 0.05844709277153015, 'learning_rate': 4.3277777777777776e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.1089976504445076, 'learning_rate': 4.325e-05, 'epoch': 0.27}
# {'loss': 0.0015, 'grad_norm': 0.0, 'learning_rate': 4.3222222222222226e-05, 'epoch': 0.27}
# {'loss': 0.0021, 'grad_norm': 0.0, 'learning_rate': 4.319444444444445e-05, 'epoch': 0.27}
# {'loss': 0.0014, 'grad_norm': 0.23909981548786163, 'learning_rate': 4.316666666666667e-05, 'epoch': 0.27}
# {'loss': 0.0011, 'grad_norm': 0.09496662020683289, 'learning_rate': 4.313888888888889e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.05213361606001854, 'learning_rate': 4.311111111111111e-05, 'epoch': 0.28}
# {'loss': 0.0014, 'grad_norm': 0.06756047904491425, 'learning_rate': 4.3083333333333335e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.0441131666302681, 'learning_rate': 4.305555555555556e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.07684419304132462, 'learning_rate': 4.302777777777778e-05, 'epoch': 0.28}
# {'loss': 0.0011, 'grad_norm': 0.1623515635728836, 'learning_rate': 4.3e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.04796477034687996, 'learning_rate': 4.2972222222222226e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.14505542814731598, 'learning_rate': 4.294444444444445e-05, 'epoch': 0.28}
# {'loss': 0.0009, 'grad_norm': 0.21238921582698822, 'learning_rate': 4.291666666666667e-05, 'epoch': 0.28}
# {'loss': 0.0014, 'grad_norm': 0.05469560623168945, 'learning_rate': 4.2888888888888886e-05, 'epoch': 0.28}
# {'loss': 0.0009, 'grad_norm': 0.11032300442457199, 'learning_rate': 4.286111111111111e-05, 'epoch': 0.29}
# {'loss': 0.0007, 'grad_norm': 0.05826818570494652, 'learning_rate': 4.2833333333333335e-05, 'epoch': 0.29}
# {'loss': 0.0015, 'grad_norm': 0.04842212051153183, 'learning_rate': 4.280555555555556e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.01933354139328003, 'learning_rate': 4.277777777777778e-05, 'epoch': 0.29}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.275e-05, 'epoch': 0.29}
# {'loss': 0.0016, 'grad_norm': 0.09666545689105988, 'learning_rate': 4.272222222222223e-05, 'epoch': 0.29}
# {'loss': 0.0014, 'grad_norm': 0.2059059888124466, 'learning_rate': 4.2694444444444445e-05, 'epoch': 0.29}
# {'loss': 0.0012, 'grad_norm': 0.12975294888019562, 'learning_rate': 4.266666666666667e-05, 'epoch': 0.29}
# {'loss': 0.0016, 'grad_norm': 0.04939786344766617, 'learning_rate': 4.263888888888889e-05, 'epoch': 0.29}
# {'loss': 0.002, 'grad_norm': 0.06395343691110611, 'learning_rate': 4.261111111111111e-05, 'epoch': 0.3}
# {'loss': 0.0014, 'grad_norm': 0.04369400441646576, 'learning_rate': 4.2583333333333336e-05, 'epoch': 0.3}
# {'loss': 0.0016, 'grad_norm': 0.06147010251879692, 'learning_rate': 4.255555555555556e-05, 'epoch': 0.3}
# {'loss': 0.0012, 'grad_norm': 0.12559464573860168, 'learning_rate': 4.252777777777778e-05, 'epoch': 0.3}
# {'loss': 0.002, 'grad_norm': 0.07884451001882553, 'learning_rate': 4.25e-05, 'epoch': 0.3}
# {'loss': 0.001, 'grad_norm': 0.1286984533071518, 'learning_rate': 4.247222222222223e-05, 'epoch': 0.3}
# {'loss': 0.0015, 'grad_norm': 0.049426790326833725, 'learning_rate': 4.2444444444444445e-05, 'epoch': 0.3}
# {'loss': 0.0015, 'grad_norm': 0.058797936886548996, 'learning_rate': 4.241666666666667e-05, 'epoch': 0.3}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.238888888888889e-05, 'epoch': 0.3}
# {'loss': 0.0018, 'grad_norm': 0.0, 'learning_rate': 4.236111111111111e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.053076617419719696, 'learning_rate': 4.233333333333334e-05, 'epoch': 0.31}
# {'loss': 0.0007, 'grad_norm': 0.10680673271417618, 'learning_rate': 4.230555555555556e-05, 'epoch': 0.31}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 4.227777777777778e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.046092405915260315, 'learning_rate': 4.2250000000000004e-05, 'epoch': 0.31}
# {'loss': 0.0013, 'grad_norm': 0.09478809684515, 'learning_rate': 4.222222222222222e-05, 'epoch': 0.31}
# {'loss': 0.001, 'grad_norm': 0.09750758111476898, 'learning_rate': 4.2194444444444446e-05, 'epoch': 0.31}
# {'loss': 0.0019, 'grad_norm': 0.0, 'learning_rate': 4.216666666666667e-05, 'epoch': 0.31}
# {'loss': 0.0012, 'grad_norm': 0.06656728684902191, 'learning_rate': 4.213888888888889e-05, 'epoch': 0.31}
# {'loss': 0.0009, 'grad_norm': 0.1212320551276207, 'learning_rate': 4.211111111111111e-05, 'epoch': 0.32}
# {'loss': 0.0011, 'grad_norm': 0.2116589993238449, 'learning_rate': 4.208333333333334e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.11147025227546692, 'learning_rate': 4.205555555555556e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.13007676601409912, 'learning_rate': 4.202777777777778e-05, 'epoch': 0.32}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.2e-05, 'epoch': 0.32}
# {'loss': 0.0011, 'grad_norm': 0.05822724103927612, 'learning_rate': 4.197222222222222e-05, 'epoch': 0.32}
# {'loss': 0.0014, 'grad_norm': 0.0451028048992157, 'learning_rate': 4.194444444444445e-05, 'epoch': 0.32}
# {'loss': 0.0019, 'grad_norm': 0.08255035430192947, 'learning_rate': 4.191666666666667e-05, 'epoch': 0.32}
# {'loss': 0.0016, 'grad_norm': 0.029021959751844406, 'learning_rate': 4.188888888888889e-05, 'epoch': 0.32}
# {'loss': 0.0018, 'grad_norm': 0.07081551104784012, 'learning_rate': 4.1861111111111114e-05, 'epoch': 0.33}
# {'loss': 0.0027, 'grad_norm': 0.09116411209106445, 'learning_rate': 4.183333333333334e-05, 'epoch': 0.33}
# {'loss': 0.001, 'grad_norm': 0.0641031414270401, 'learning_rate': 4.1805555555555556e-05, 'epoch': 0.33}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 4.177777777777778e-05, 'epoch': 0.33}
# {'loss': 0.002, 'grad_norm': 0.056803494691848755, 'learning_rate': 4.175e-05, 'epoch': 0.33}
# {'loss': 0.0007, 'grad_norm': 0.1386033147573471, 'learning_rate': 4.172222222222222e-05, 'epoch': 0.33}
# {'loss': 0.0013, 'grad_norm': 0.04423708841204643, 'learning_rate': 4.169444444444445e-05, 'epoch': 0.33}
# {'loss': 0.0013, 'grad_norm': 0.04555240646004677, 'learning_rate': 4.166666666666667e-05, 'epoch': 0.33}
# {'loss': 0.0014, 'grad_norm': 0.06766004115343094, 'learning_rate': 4.163888888888889e-05, 'epoch': 0.33}
# {'loss': 0.0009, 'grad_norm': 0.07458792626857758, 'learning_rate': 4.1611111111111114e-05, 'epoch': 0.34}
# {'loss': 0.0006, 'grad_norm': 0.1397000104188919, 'learning_rate': 4.158333333333333e-05, 'epoch': 0.34}
# {'loss': 0.001, 'grad_norm': 0.09653545171022415, 'learning_rate': 4.155555555555556e-05, 'epoch': 0.34}
# {'loss': 0.0013, 'grad_norm': 0.08252368122339249, 'learning_rate': 4.152777777777778e-05, 'epoch': 0.34}
# {'loss': 0.0011, 'grad_norm': 0.021437468007206917, 'learning_rate': 4.15e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.0433485321700573, 'learning_rate': 4.1472222222222224e-05, 'epoch': 0.34}
# {'loss': 0.0015, 'grad_norm': 0.35906463861465454, 'learning_rate': 4.144444444444445e-05, 'epoch': 0.34}
# {'loss': 0.0015, 'grad_norm': 0.13042858242988586, 'learning_rate': 4.141666666666667e-05, 'epoch': 0.34}
# {'loss': 0.002, 'grad_norm': 0.1314607858657837, 'learning_rate': 4.138888888888889e-05, 'epoch': 0.34}
# {'loss': 0.0021, 'grad_norm': 0.058504700660705566, 'learning_rate': 4.136111111111111e-05, 'epoch': 0.35}
# {'loss': 0.0007, 'grad_norm': 0.3557031750679016, 'learning_rate': 4.133333333333333e-05, 'epoch': 0.35}
# {'loss': 0.0009, 'grad_norm': 0.0705948919057846, 'learning_rate': 4.130555555555556e-05, 'epoch': 0.35}
# {'loss': 0.0019, 'grad_norm': 0.09211411327123642, 'learning_rate': 4.127777777777778e-05, 'epoch': 0.35}
# {'loss': 0.0009, 'grad_norm': 0.06883646547794342, 'learning_rate': 4.125e-05, 'epoch': 0.35}
# {'loss': 0.0007, 'grad_norm': 0.11429402232170105, 'learning_rate': 4.1222222222222224e-05, 'epoch': 0.35}
# {'loss': 0.0009, 'grad_norm': 0.030054625123739243, 'learning_rate': 4.119444444444445e-05, 'epoch': 0.35}
# {'loss': 0.0008, 'grad_norm': 0.04923360422253609, 'learning_rate': 4.116666666666667e-05, 'epoch': 0.35}
# {'loss': 0.0011, 'grad_norm': 0.06668583303689957, 'learning_rate': 4.113888888888889e-05, 'epoch': 0.35}
# {'loss': 0.0015, 'grad_norm': 0.02503739856183529, 'learning_rate': 4.111111111111111e-05, 'epoch': 0.36}
# {'loss': 0.0012, 'grad_norm': 0.05073754861950874, 'learning_rate': 4.1083333333333334e-05, 'epoch': 0.36}
# {'loss': 0.0009, 'grad_norm': 0.3099769651889801, 'learning_rate': 4.105555555555556e-05, 'epoch': 0.36}
# {'loss': 0.0012, 'grad_norm': 0.06296423077583313, 'learning_rate': 4.102777777777778e-05, 'epoch': 0.36}
# {'loss': 0.0011, 'grad_norm': 0.14808571338653564, 'learning_rate': 4.1e-05, 'epoch': 0.36}
# {'loss': 0.0009, 'grad_norm': 0.0, 'learning_rate': 4.0972222222222225e-05, 'epoch': 0.36}
# {'loss': 0.0026, 'grad_norm': 0.09369092434644699, 'learning_rate': 4.094444444444445e-05, 'epoch': 0.36}
# {'loss': 0.0013, 'grad_norm': 0.13167785108089447, 'learning_rate': 4.091666666666667e-05, 'epoch': 0.36}
# {'loss': 0.0014, 'grad_norm': 0.05230463296175003, 'learning_rate': 4.088888888888889e-05, 'epoch': 0.36}
# {'loss': 0.001, 'grad_norm': 0.12764157354831696, 'learning_rate': 4.086111111111111e-05, 'epoch': 0.37}
# {'loss': 0.0018, 'grad_norm': 0.09273439645767212, 'learning_rate': 4.0833333333333334e-05, 'epoch': 0.37}
# {'loss': 0.0017, 'grad_norm': 0.030567875131964684, 'learning_rate': 4.080555555555556e-05, 'epoch': 0.37}
# {'loss': 0.0015, 'grad_norm': 0.05310271307826042, 'learning_rate': 4.0777777777777783e-05, 'epoch': 0.37}
# {'loss': 0.0022, 'grad_norm': 0.09590427577495575, 'learning_rate': 4.075e-05, 'epoch': 0.37}
# {'loss': 0.0019, 'grad_norm': 0.0918663963675499, 'learning_rate': 4.0722222222222226e-05, 'epoch': 0.37}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 4.0694444444444444e-05, 'epoch': 0.37}
# {'loss': 0.0008, 'grad_norm': 0.05306096747517586, 'learning_rate': 4.066666666666667e-05, 'epoch': 0.37}
# {'loss': 0.0011, 'grad_norm': 0.11296836286783218, 'learning_rate': 4.063888888888889e-05, 'epoch': 0.37}
# {'loss': 0.0013, 'grad_norm': 0.05514311045408249, 'learning_rate': 4.061111111111111e-05, 'epoch': 0.38}
# {'loss': 0.001, 'grad_norm': 0.13666357100009918, 'learning_rate': 4.0583333333333335e-05, 'epoch': 0.38}
# {'loss': 0.0011, 'grad_norm': 0.12010811269283295, 'learning_rate': 4.055555555555556e-05, 'epoch': 0.38}
# {'loss': 0.0013, 'grad_norm': 0.17201317846775055, 'learning_rate': 4.0527777777777784e-05, 'epoch': 0.38}
# {'loss': 0.001, 'grad_norm': 0.26202255487442017, 'learning_rate': 4.05e-05, 'epoch': 0.38}
# {'loss': 0.0013, 'grad_norm': 0.24711713194847107, 'learning_rate': 4.047222222222222e-05, 'epoch': 0.38}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 4.0444444444444444e-05, 'epoch': 0.38}
# {'loss': 0.0017, 'grad_norm': 0.09866387397050858, 'learning_rate': 4.041666666666667e-05, 'epoch': 0.38}
# {'loss': 0.0012, 'grad_norm': 0.1987244337797165, 'learning_rate': 4.038888888888889e-05, 'epoch': 0.38}
# {'loss': 0.002, 'grad_norm': 0.09914866834878922, 'learning_rate': 4.036111111111111e-05, 'epoch': 0.39}
# {'loss': 0.0017, 'grad_norm': 0.04003288596868515, 'learning_rate': 4.0333333333333336e-05, 'epoch': 0.39}
# {'loss': 0.0008, 'grad_norm': 0.02523067779839039, 'learning_rate': 4.030555555555556e-05, 'epoch': 0.39}
# {'loss': 0.0016, 'grad_norm': 0.07187820971012115, 'learning_rate': 4.027777777777778e-05, 'epoch': 0.39}
# {'loss': 0.0012, 'grad_norm': 0.04628831148147583, 'learning_rate': 4.025e-05, 'epoch': 0.39}
# {'loss': 0.0011, 'grad_norm': 0.1511535346508026, 'learning_rate': 4.022222222222222e-05, 'epoch': 0.39}
# {'loss': 0.0016, 'grad_norm': 0.19664543867111206, 'learning_rate': 4.0194444444444445e-05, 'epoch': 0.39}
# {'loss': 0.0007, 'grad_norm': 0.10673273354768753, 'learning_rate': 4.016666666666667e-05, 'epoch': 0.39}
# {'loss': 0.0007, 'grad_norm': 0.14592844247817993, 'learning_rate': 4.0138888888888894e-05, 'epoch': 0.39}
# {'loss': 0.0014, 'grad_norm': 0.029259061440825462, 'learning_rate': 4.011111111111111e-05, 'epoch': 0.4}
# {'loss': 0.0015, 'grad_norm': 0.10611630231142044, 'learning_rate': 4.0083333333333336e-05, 'epoch': 0.4}
# {'loss': 0.0024, 'grad_norm': 0.0952451154589653, 'learning_rate': 4.0055555555555554e-05, 'epoch': 0.4}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 4.002777777777778e-05, 'epoch': 0.4}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 4e-05, 'epoch': 0.4}
# {'loss': 0.0008, 'grad_norm': 0.08841481804847717, 'learning_rate': 3.997222222222222e-05, 'epoch': 0.4}
# {'loss': 0.0013, 'grad_norm': 0.06961818039417267, 'learning_rate': 3.9944444444444446e-05, 'epoch': 0.4}
# {'loss': 0.0028, 'grad_norm': 0.265936940908432, 'learning_rate': 3.991666666666667e-05, 'epoch': 0.4}
# {'loss': 0.0019, 'grad_norm': 0.051073648035526276, 'learning_rate': 3.9888888888888895e-05, 'epoch': 0.4}
# {'loss': 0.0016, 'grad_norm': 0.0555289052426815, 'learning_rate': 3.986111111111111e-05, 'epoch': 0.41}
# {'loss': 0.0019, 'grad_norm': 0.05065252259373665, 'learning_rate': 3.983333333333333e-05, 'epoch': 0.41}
# {'loss': 0.0014, 'grad_norm': 0.04907728359103203, 'learning_rate': 3.9805555555555555e-05, 'epoch': 0.41}
# {'loss': 0.0016, 'grad_norm': 0.041287802159786224, 'learning_rate': 3.977777777777778e-05, 'epoch': 0.41}
# {'loss': 0.0007, 'grad_norm': 0.07603517919778824, 'learning_rate': 3.9750000000000004e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.11206374317407608, 'learning_rate': 3.972222222222222e-05, 'epoch': 0.41}
# {'loss': 0.0007, 'grad_norm': 0.057019155472517014, 'learning_rate': 3.9694444444444446e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.10759434849023819, 'learning_rate': 3.966666666666667e-05, 'epoch': 0.41}
# {'loss': 0.0012, 'grad_norm': 0.1304750293493271, 'learning_rate': 3.9638888888888895e-05, 'epoch': 0.41}
# {'loss': 0.001, 'grad_norm': 0.06573870778083801, 'learning_rate': 3.961111111111111e-05, 'epoch': 0.42}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 3.958333333333333e-05, 'epoch': 0.42}
# {'loss': 0.0016, 'grad_norm': 0.09740418940782547, 'learning_rate': 3.9555555555555556e-05, 'epoch': 0.42}
# {'loss': 0.001, 'grad_norm': 0.10285619646310806, 'learning_rate': 3.952777777777778e-05, 'epoch': 0.42}
# {'loss': 0.0009, 'grad_norm': 0.09558101743459702, 'learning_rate': 3.9500000000000005e-05, 'epoch': 0.42}
# {'loss': 0.0008, 'grad_norm': 0.12588509917259216, 'learning_rate': 3.947222222222222e-05, 'epoch': 0.42}
# {'loss': 0.0012, 'grad_norm': 0.1393975019454956, 'learning_rate': 3.944444444444445e-05, 'epoch': 0.42}
# {'loss': 0.0021, 'grad_norm': 0.26355209946632385, 'learning_rate': 3.941666666666667e-05, 'epoch': 0.42}
# {'loss': 0.0009, 'grad_norm': 0.08939676731824875, 'learning_rate': 3.938888888888889e-05, 'epoch': 0.42}
# {'loss': 0.0012, 'grad_norm': 0.045643482357263565, 'learning_rate': 3.9361111111111114e-05, 'epoch': 0.43}
# {'loss': 0.0016, 'grad_norm': 0.04575198143720627, 'learning_rate': 3.933333333333333e-05, 'epoch': 0.43}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.9305555555555556e-05, 'epoch': 0.43}
# {'loss': 0.0016, 'grad_norm': 0.21239504218101501, 'learning_rate': 3.927777777777778e-05, 'epoch': 0.43}
# {'loss': 0.0034, 'grad_norm': 0.20804263651371002, 'learning_rate': 3.9250000000000005e-05, 'epoch': 0.43}
# {'loss': 0.0012, 'grad_norm': 0.037726592272520065, 'learning_rate': 3.922222222222223e-05, 'epoch': 0.43}
# {'loss': 0.0006, 'grad_norm': 0.0, 'learning_rate': 3.919444444444445e-05, 'epoch': 0.43}
# {'loss': 0.0013, 'grad_norm': 0.05927473306655884, 'learning_rate': 3.9166666666666665e-05, 'epoch': 0.43}
# {'loss': 0.0009, 'grad_norm': 0.06271495670080185, 'learning_rate': 3.913888888888889e-05, 'epoch': 0.43}
# {'loss': 0.0018, 'grad_norm': 0.057641517370939255, 'learning_rate': 3.9111111111111115e-05, 'epoch': 0.44}
# {'loss': 0.0011, 'grad_norm': 0.10280416905879974, 'learning_rate': 3.908333333333333e-05, 'epoch': 0.44}
# {'loss': 0.0018, 'grad_norm': 0.136168971657753, 'learning_rate': 3.905555555555556e-05, 'epoch': 0.44}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 3.902777777777778e-05, 'epoch': 0.44}
# {'loss': 0.0013, 'grad_norm': 0.0421733595430851, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.44}
# {'loss': 0.0012, 'grad_norm': 0.04854008927941322, 'learning_rate': 3.8972222222222224e-05, 'epoch': 0.44}
# {'loss': 0.0015, 'grad_norm': 0.092536561191082, 'learning_rate': 3.894444444444444e-05, 'epoch': 0.44}
# {'loss': 0.0017, 'grad_norm': 0.033367548137903214, 'learning_rate': 3.8916666666666666e-05, 'epoch': 0.44}
# {'loss': 0.0016, 'grad_norm': 0.0802781879901886, 'learning_rate': 3.888888888888889e-05, 'epoch': 0.44}
# {'loss': 0.0005, 'grad_norm': 0.04577172175049782, 'learning_rate': 3.8861111111111115e-05, 'epoch': 0.45}
# {'loss': 0.001, 'grad_norm': 0.1242866963148117, 'learning_rate': 3.883333333333333e-05, 'epoch': 0.45}
# {'loss': 0.0013, 'grad_norm': 0.0890703797340393, 'learning_rate': 3.880555555555556e-05, 'epoch': 0.45}
# {'loss': 0.0015, 'grad_norm': 0.10034941881895065, 'learning_rate': 3.877777777777778e-05, 'epoch': 0.45}
# {'loss': 0.0011, 'grad_norm': 0.10552797466516495, 'learning_rate': 3.875e-05, 'epoch': 0.45}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.8722222222222225e-05, 'epoch': 0.45}
# {'loss': 0.001, 'grad_norm': 0.05020498111844063, 'learning_rate': 3.869444444444444e-05, 'epoch': 0.45}
# {'loss': 0.0006, 'grad_norm': 0.05171295255422592, 'learning_rate': 3.866666666666667e-05, 'epoch': 0.45}
# {'loss': 0.0017, 'grad_norm': 0.051787834614515305, 'learning_rate': 3.863888888888889e-05, 'epoch': 0.45}
# {'loss': 0.0008, 'grad_norm': 0.16846248507499695, 'learning_rate': 3.8611111111111116e-05, 'epoch': 0.46}
# {'loss': 0.0005, 'grad_norm': 0.08899043500423431, 'learning_rate': 3.8583333333333334e-05, 'epoch': 0.46}
# {'loss': 0.0012, 'grad_norm': 0.0934726819396019, 'learning_rate': 3.855555555555556e-05, 'epoch': 0.46}
# {'loss': 0.0017, 'grad_norm': 0.09840576350688934, 'learning_rate': 3.8527777777777776e-05, 'epoch': 0.46}
# {'loss': 0.0015, 'grad_norm': 0.07622819393873215, 'learning_rate': 3.85e-05, 'epoch': 0.46}
# {'loss': 0.0018, 'grad_norm': 0.2647761404514313, 'learning_rate': 3.8472222222222225e-05, 'epoch': 0.46}
# {'loss': 0.0023, 'grad_norm': 0.06676329672336578, 'learning_rate': 3.844444444444444e-05, 'epoch': 0.46}
# {'loss': 0.001, 'grad_norm': 0.08705919235944748, 'learning_rate': 3.841666666666667e-05, 'epoch': 0.46}
# {'loss': 0.0017, 'grad_norm': 0.08858223259449005, 'learning_rate': 3.838888888888889e-05, 'epoch': 0.46}
# {'loss': 0.0012, 'grad_norm': 0.0, 'learning_rate': 3.836111111111112e-05, 'epoch': 0.47}
# {'loss': 0.0013, 'grad_norm': 0.05893630534410477, 'learning_rate': 3.8333333333333334e-05, 'epoch': 0.47}
# {'loss': 0.0024, 'grad_norm': 0.1494591385126114, 'learning_rate': 3.830555555555555e-05, 'epoch': 0.47}
# {'loss': 0.0009, 'grad_norm': 0.04967660829424858, 'learning_rate': 3.827777777777778e-05, 'epoch': 0.47}
# {'loss': 0.0007, 'grad_norm': 0.07759260386228561, 'learning_rate': 3.825e-05, 'epoch': 0.47}
# {'loss': 0.0011, 'grad_norm': 0.13799816370010376, 'learning_rate': 3.8222222222222226e-05, 'epoch': 0.47}
# {'loss': 0.0019, 'grad_norm': 0.11639843881130219, 'learning_rate': 3.8194444444444444e-05, 'epoch': 0.47}
# {'loss': 0.0015, 'grad_norm': 0.08997450023889542, 'learning_rate': 3.816666666666667e-05, 'epoch': 0.47}
# {'loss': 0.0011, 'grad_norm': 0.057234425097703934, 'learning_rate': 3.813888888888889e-05, 'epoch': 0.47}
# {'loss': 0.0016, 'grad_norm': 0.03065446764230728, 'learning_rate': 3.811111111111112e-05, 'epoch': 0.48}
# {'loss': 0.001, 'grad_norm': 0.15178219974040985, 'learning_rate': 3.8083333333333335e-05, 'epoch': 0.48}
# {'loss': 0.001, 'grad_norm': 0.0969616249203682, 'learning_rate': 3.805555555555555e-05, 'epoch': 0.48}
# {'loss': 0.002, 'grad_norm': 0.12799832224845886, 'learning_rate': 3.802777777777778e-05, 'epoch': 0.48}
# {'loss': 0.0021, 'grad_norm': 0.057259783148765564, 'learning_rate': 3.8e-05, 'epoch': 0.48}
# {'loss': 0.0015, 'grad_norm': 0.27334973216056824, 'learning_rate': 3.797222222222223e-05, 'epoch': 0.48}
# {'loss': 0.0012, 'grad_norm': 0.08279275894165039, 'learning_rate': 3.7944444444444444e-05, 'epoch': 0.48}
# {'loss': 0.0014, 'grad_norm': 0.04540099948644638, 'learning_rate': 3.791666666666667e-05, 'epoch': 0.48}
# {'loss': 0.0007, 'grad_norm': 0.06652622669935226, 'learning_rate': 3.7888888888888894e-05, 'epoch': 0.48}
# {'loss': 0.0018, 'grad_norm': 0.054152727127075195, 'learning_rate': 3.786111111111111e-05, 'epoch': 0.49}
# {'loss': 0.0007, 'grad_norm': 0.0925939679145813, 'learning_rate': 3.7833333333333336e-05, 'epoch': 0.49}
# {'loss': 0.001, 'grad_norm': 0.0, 'learning_rate': 3.7805555555555554e-05, 'epoch': 0.49}
# {'loss': 0.001, 'grad_norm': 0.04407045245170593, 'learning_rate': 3.777777777777778e-05, 'epoch': 0.49}
# {'loss': 0.0011, 'grad_norm': 0.0, 'learning_rate': 3.775e-05, 'epoch': 0.49}
# {'loss': 0.0018, 'grad_norm': 0.10740859061479568, 'learning_rate': 3.772222222222223e-05, 'epoch': 0.49}
# {'loss': 0.0004, 'grad_norm': 0.0, 'learning_rate': 3.769444444444445e-05, 'epoch': 0.49}
# {'loss': 0.0011, 'grad_norm': 0.12481720000505447, 'learning_rate': 3.766666666666667e-05, 'epoch': 0.49}
# {'loss': 0.001, 'grad_norm': 0.11993378400802612, 'learning_rate': 3.763888888888889e-05, 'epoch': 0.49}
# {'loss': 0.0017, 'grad_norm': 0.0575447604060173, 'learning_rate': 3.761111111111111e-05, 'epoch': 0.5}
# {'loss': 0.0019, 'grad_norm': 0.0516013577580452, 'learning_rate': 3.7583333333333337e-05, 'epoch': 0.5}
# {'loss': 0.0016, 'grad_norm': 0.10033159703016281, 'learning_rate': 3.7555555555555554e-05, 'epoch': 0.5}
# {'loss': 0.0012, 'grad_norm': 0.10197513550519943, 'learning_rate': 3.752777777777778e-05, 'epoch': 0.5}
# {'loss': 0.0009, 'grad_norm': 0.12120725959539413, 'learning_rate': 3.7500000000000003e-05, 'epoch': 0.5}
# {'loss': 0.0014, 'grad_norm': 0.0736454576253891, 'learning_rate': 3.747222222222223e-05, 'epoch': 0.5}
# {'loss': 0.0017, 'grad_norm': 0.05389407277107239, 'learning_rate': 3.7444444444444446e-05, 'epoch': 0.5}
# {'loss': 0.0016, 'grad_norm': 0.0, 'learning_rate': 3.7416666666666664e-05, 'epoch': 0.5}
# {'loss': 0.0017, 'grad_norm': 0.08320213109254837, 'learning_rate': 3.738888888888889e-05, 'epoch': 0.5}
# {'loss': 0.0017, 'grad_norm': 0.1539202183485031, 'learning_rate': 3.736111111111111e-05, 'epoch': 0.51}
# {'loss': 0.0013, 'grad_norm': 0.0, 'learning_rate': 3.733333333333334e-05, 'epoch': 0.51}
# {'loss': 0.0008, 'grad_norm': 0.061680395156145096, 'learning_rate': 3.7305555555555555e-05, 'epoch': 0.51}
# {'loss': 0.0004, 'grad_norm': 0.17340809106826782, 'learning_rate': 3.727777777777778e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.2308628410100937, 'learning_rate': 3.7250000000000004e-05, 'epoch': 0.51}
# {'loss': 0.0011, 'grad_norm': 0.050611477345228195, 'learning_rate': 3.722222222222222e-05, 'epoch': 0.51}
# {'loss': 0.0012, 'grad_norm': 0.058336030691862106, 'learning_rate': 3.7194444444444447e-05, 'epoch': 0.51}
# {'loss': 0.001, 'grad_norm': 0.047905195504426956, 'learning_rate': 3.7166666666666664e-05, 'epoch': 0.51}
# ...
# {'loss': 0.0015, 'grad_norm': 0.04418549686670303, 'learning_rate': 4.383333333333334e-05, 'epoch': 0.25}
# {'loss': 0.0019, 'grad_norm': 0.07826853543519974, 'learning_rate': 4.380555555555556e-05, 'epoch': 0.25}
# {'loss': 0.0006, 'grad_norm': 0.08890625089406967, 'learning_rate': 4.377777777777778e-05, 'epoch': 0.25}
# {'loss': 0.0015, 'grad_norm': 0.10469301789999008, 'learning_rate': 4.375e-05, 'epoch': 0.25}
# {'loss': 0.0015, 'grad_norm': 0.2189815789461136, 'learning_rate': 4.3722222222222224e-05, 'epoch': 0.25}
# {'loss': 0.0009, 'grad_norm': 0.07849729061126709, 'learning_rate': 4.369444444444445e-05, 'epoch': 0.25}
# {'loss': 0.0018, 'grad_norm': 0.153504878282547, 'learning_rate': 4.3666666666666666e-05, 'epoch': 0.25}
# {'loss': 0.0015, 'grad_norm': 0.07628185302019119, 'learning_rate': 4.363888888888889e-05, 'epoch': 0.25}
# {'loss': 0.0013, 'grad_norm': 0.1565830111503601, 'learning_rate': 4.3611111111111116e-05, 'epoch': 0.26}
# {'loss': 0.0024, 'grad_norm': 0.2128007709980011, 'learning_rate': 4.358333333333334e-05, 'epoch': 0.26}
# {'loss': 0.0017, 'grad_norm': 0.10375265777111053, 'learning_rate': 4.355555555555556e-05, 'epoch': 0.26}
# {'loss': 0.0031, 'grad_norm': 0.2007492482662201, 'learning_rate': 4.3527777777777776e-05, 'epoch': 0.26}
# {'loss': 0.0017, 'grad_norm': 0.1459827870130539, 'learning_rate': 4.35e-05, 'epoch': 0.26}
# {'loss': 0.0015, 'grad_norm': 0.4167449474334717, 'learning_rate': 4.3472222222222225e-05, 'epoch': 0.26}
# {'loss': 0.0009, 'grad_norm': 0.4091431796550751, 'learning_rate': 4.344444444444445e-05, 'epoch': 0.26}
# {'loss': 0.0031, 'grad_norm': 0.185323566198349, 'learning_rate': 4.341666666666667e-05, 'epoch': 0.26}
# {'loss': 0.0016, 'grad_norm': 0.05189589783549309, 'learning_rate': 4.338888888888889e-05, 'epoch': 0.26}
# {'loss': 0.0018, 'grad_norm': 0.2996574938297272, 'learning_rate': 4.3361111111111116e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.36266976594924927, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.27}
# {'loss': 0.0014, 'grad_norm': 0.20223182439804077, 'learning_rate': 4.330555555555556e-05, 'epoch': 0.27}
# {'loss': 0.0009, 'grad_norm': 0.11534745991230011, 'learning_rate': 4.3277777777777776e-05, 'epoch': 0.27}
# {'loss': 0.0014, 'grad_norm': 0.16459453105926514, 'learning_rate': 4.325e-05, 'epoch': 0.27}
# {'loss': 0.0016, 'grad_norm': 0.056729428470134735, 'learning_rate': 4.3222222222222226e-05, 'epoch': 0.27}
# {'loss': 0.0023, 'grad_norm': 0.04552624002099037, 'learning_rate': 4.319444444444445e-05, 'epoch': 0.27}
# {'loss': 0.0015, 'grad_norm': 0.2789590060710907, 'learning_rate': 4.316666666666667e-05, 'epoch': 0.27}
# {'loss': 0.0014, 'grad_norm': 0.1646992564201355, 'learning_rate': 4.313888888888889e-05, 'epoch': 0.27}
# {'loss': 0.0021, 'grad_norm': 0.1359860748052597, 'learning_rate': 4.311111111111111e-05, 'epoch': 0.28}
# {'loss': 0.0016, 'grad_norm': 0.09660615026950836, 'learning_rate': 4.3083333333333335e-05, 'epoch': 0.28}
# {'loss': 0.0015, 'grad_norm': 0.1599612832069397, 'learning_rate': 4.305555555555556e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.1989532709121704, 'learning_rate': 4.302777777777778e-05, 'epoch': 0.28}
# {'loss': 0.0008, 'grad_norm': 0.14991524815559387, 'learning_rate': 4.3e-05, 'epoch': 0.28}
# {'loss': 0.0012, 'grad_norm': 0.3133679926395416, 'learning_rate': 4.2972222222222226e-05, 'epoch': 0.28}
# {'loss': 0.0009, 'grad_norm': 0.12614867091178894, 'learning_rate': 4.294444444444445e-05, 'epoch': 0.28}
# {'loss': 0.0008, 'grad_norm': 0.05689464882016182, 'learning_rate': 4.291666666666667e-05, 'epoch': 0.28}
# {'loss': 0.0011, 'grad_norm': 0.13959160447120667, 'learning_rate': 4.2888888888888886e-05, 'epoch': 0.28}
# {'loss': 0.001, 'grad_norm': 0.12963555753231049, 'learning_rate': 4.286111111111111e-05, 'epoch': 0.29}
# {'loss': 0.001, 'grad_norm': 0.05211590975522995, 'learning_rate': 4.2833333333333335e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.1459079384803772, 'learning_rate': 4.280555555555556e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.09802160412073135, 'learning_rate': 4.277777777777778e-05, 'epoch': 0.29}
# {'loss': 0.0014, 'grad_norm': 0.0, 'learning_rate': 4.275e-05, 'epoch': 0.29}
# {'loss': 0.0013, 'grad_norm': 0.023886650800704956, 'learning_rate': 4.272222222222223e-05, 'epoch': 0.29}
# {'loss': 0.0016, 'grad_norm': 0.32621753215789795, 'learning_rate': 4.2694444444444445e-05, 'epoch': 0.29}
# {'loss': 0.0012, 'grad_norm': 0.1674317866563797, 'learning_rate': 4.266666666666667e-05, 'epoch': 0.29}
# {'loss': 0.0016, 'grad_norm': 0.10424593091011047, 'learning_rate': 4.263888888888889e-05, 'epoch': 0.29}
# {'loss': 0.0016, 'grad_norm': 0.037457436323165894, 'learning_rate': 4.261111111111111e-05, 'epoch': 0.3}
# {'loss': 0.0014, 'grad_norm': 0.15061317384243011, 'learning_rate': 4.2583333333333336e-05, 'epoch': 0.3}
# {'loss': 0.0021, 'grad_norm': 0.10533742606639862, 'learning_rate': 4.255555555555556e-05, 'epoch': 0.3}
# {'loss': 0.0016, 'grad_norm': 0.2875955402851105, 'learning_rate': 4.252777777777778e-05, 'epoch': 0.3}
# {'loss': 0.0023, 'grad_norm': 0.3619763255119324, 'learning_rate': 4.25e-05, 'epoch': 0.3}
# {'loss': 0.0009, 'grad_norm': 0.15804673731327057, 'learning_rate': 4.247222222222223e-05, 'epoch': 0.3}
# {'loss': 0.0009, 'grad_norm': 0.4723903238773346, 'learning_rate': 4.2444444444444445e-05, 'epoch': 0.3}
# {'loss': 0.0016, 'grad_norm': 0.14523105323314667, 'learning_rate': 4.241666666666667e-05, 'epoch': 0.3}
# {'loss': 0.0014, 'grad_norm': 0.05721380189061165, 'learning_rate': 4.238888888888889e-05, 'epoch': 0.3}
# {'loss': 0.0021, 'grad_norm': 0.158644437789917, 'learning_rate': 4.236111111111111e-05, 'epoch': 0.31}
# {'loss': 0.0014, 'grad_norm': 0.1700977385044098, 'learning_rate': 4.233333333333334e-05, 'epoch': 0.31}
# {'loss': 0.0011, 'grad_norm': 0.18496741354465485, 'learning_rate': 4.230555555555556e-05, 'epoch': 0.31}
# {'loss': 0.001, 'grad_norm': 0.05862107127904892, 'learning_rate': 4.227777777777778e-05, 'epoch': 0.31}
# {'loss': 0.0011, 'grad_norm': 0.17279700934886932, 'learning_rate': 4.2250000000000004e-05, 'epoch': 0.31}
# {'loss': 0.0016, 'grad_norm': 0.12131578475236893, 'learning_rate': 4.222222222222222e-05, 'epoch': 0.31}
# {'loss': 0.0011, 'grad_norm': 0.048444442451000214, 'learning_rate': 4.2194444444444446e-05, 'epoch': 0.31}
# {'loss': 0.0026, 'grad_norm': 0.0, 'learning_rate': 4.216666666666667e-05, 'epoch': 0.31}
# {'loss': 0.0016, 'grad_norm': 0.06053262576460838, 'learning_rate': 4.213888888888889e-05, 'epoch': 0.31}
# {'loss': 0.001, 'grad_norm': 0.21262283623218536, 'learning_rate': 4.211111111111111e-05, 'epoch': 0.32}
# {'loss': 0.0009, 'grad_norm': 0.05822243541479111, 'learning_rate': 4.208333333333334e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.0, 'learning_rate': 4.205555555555556e-05, 'epoch': 0.32}
# {'loss': 0.0005, 'grad_norm': 0.09487482905387878, 'learning_rate': 4.202777777777778e-05, 'epoch': 0.32}
# {'loss': 0.0007, 'grad_norm': 0.08963590115308762, 'learning_rate': 4.2e-05, 'epoch': 0.32}
# {'loss': 0.001, 'grad_norm': 0.08447527140378952, 'learning_rate': 4.197222222222222e-05, 'epoch': 0.32}
# {'loss': 0.0016, 'grad_norm': 0.38095030188560486, 'learning_rate': 4.194444444444445e-05, 'epoch': 0.32}
# {'loss': 0.0021, 'grad_norm': 0.27751651406288147, 'learning_rate': 4.191666666666667e-05, 'epoch': 0.32}
# {'loss': 0.0023, 'grad_norm': 0.042973972856998444, 'learning_rate': 4.188888888888889e-05, 'epoch': 0.32}
# {'loss': 0.002, 'grad_norm': 0.09877236932516098, 'learning_rate': 4.1861111111111114e-05, 'epoch': 0.33}
# {'loss': 0.0029, 'grad_norm': 0.1545563042163849, 'learning_rate': 4.183333333333334e-05, 'epoch': 0.33}
# {'loss': 0.0012, 'grad_norm': 0.11149810999631882, 'learning_rate': 4.1805555555555556e-05, 'epoch': 0.33}
# {'loss': 0.0011, 'grad_norm': 0.13081206381320953, 'learning_rate': 4.177777777777778e-05, 'epoch': 0.33}
# {'loss': 0.0021, 'grad_norm': 0.058513276278972626, 'learning_rate': 4.175e-05, 'epoch': 0.33}
# {'loss': 0.0008, 'grad_norm': 0.2741144001483917, 'learning_rate': 4.172222222222222e-05, 'epoch': 0.33}
# {'loss': 0.0018, 'grad_norm': 0.0, 'learning_rate': 4.169444444444445e-05, 'epoch': 0.33}
# {'loss': 0.0015, 'grad_norm': 0.24014288187026978, 'learning_rate': 4.166666666666667e-05, 'epoch': 0.33}
# {'loss': 0.0014, 'grad_norm': 0.16378647089004517, 'learning_rate': 4.163888888888889e-05, 'epoch': 0.33}
# {'loss': 0.0014, 'grad_norm': 0.3388414680957794, 'learning_rate': 4.1611111111111114e-05, 'epoch': 0.34}
# {'loss': 0.001, 'grad_norm': 0.5490214824676514, 'learning_rate': 4.158333333333333e-05, 'epoch': 0.34}
# {'loss': 0.0007, 'grad_norm': 0.14546814560890198, 'learning_rate': 4.155555555555556e-05, 'epoch': 0.34}
# {'loss': 0.0017, 'grad_norm': 0.056191716343164444, 'learning_rate': 4.152777777777778e-05, 'epoch': 0.34}
# {'loss': 0.0013, 'grad_norm': 0.06801006942987442, 'learning_rate': 4.15e-05, 'epoch': 0.34}
# {'loss': 0.0016, 'grad_norm': 0.6710407137870789, 'learning_rate': 4.1472222222222224e-05, 'epoch': 0.34}
# {'loss': 0.0019, 'grad_norm': 0.08289648592472076, 'learning_rate': 4.144444444444445e-05, 'epoch': 0.34}
# {'loss': 0.0014, 'grad_norm': 0.10927913337945938, 'learning_rate': 4.141666666666667e-05, 'epoch': 0.34}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 trainer.args.num_train_epochs = stage['epochs']
#      11 trainer.args.learning_rate = stage['learning_rate']
# ---> 12 trainer.train()
#      13 format_string = format_string_base + str(i) + ".obj"
#      14 generate_meshes(model, obj_dir, result_dir, format_string, device,
#      15     batch_size, resolution=100, context_size=200)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:2164, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2162         hf_hub_utils.enable_progress_bars()
#    2163 else:
# -> 2164     return inner_training_loop(
#    2165         args=args,
#    2166         resume_from_checkpoint=resume_from_checkpoint,
#    2167         trial=trial,
#    2168         ignore_keys_for_eval=ignore_keys_for_eval,
#    2169     )
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:2524, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2517 context = (
#    2518     functools.partial(self.accelerator.no_sync, model=model)
#    2519     if i != len(batch_samples) - 1
#    2520     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2521     else contextlib.nullcontext
#    2522 )
#    2523 with context():
# -> 2524     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2526 if (
#    2527     args.logging_nan_inf_filter
#    2528     and not is_torch_xla_available()
#    2529     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2530 ):
#    2531     # if loss is nan or inf simply add the average of previous logged losses
#    2532     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:3654, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3651     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3653 with self.compute_loss_context_manager():
# -> 3654     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3656 del inputs
#    3657 if (
#    3658     self.args.torch_empty_cache_steps is not None
#    3659     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3660 ):
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\transformers\trainer.py:3708, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3706         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3707     inputs = {**inputs, **loss_kwargs}
# -> 3708 outputs = model(**inputs)
#    3709 # Save past state if it exists
#    3710 # TODO: this needs to be fixed and made cleaner later.
#    3711 if self.args.past_index >= 0:
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[2], line 45, in SDFTransformer.forward(self, context, x, labels)
#      43 x = self.proj1(x)                       # [batch_size, context_size, dim_hidden]
#      44 context = self.proj2(context)           # [batch_size, context_size, dim_hidden]
# ---> 45 y = self.cross(x, context)              # [batch_size, context_size, dim_hidden]
#      46 y = self.enc(y)                         # [batch_size, num_outputs, dim_output]
#      48 loss = None
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\_prog\vm_shared\attention-sdf\src\models\modules.py:38, in MAB.forward(self, Q, K)
#      36 O = torch.cat((Q_ + A.bmm(V_)).split(Q.size(0), 0), 2)
#      37 O = O if getattr(self, 'ln0', None) is None else self.ln0(O)
# ---> 38 O = O + F.relu(self.fc_o(O))
#      39 O = O if getattr(self, 'ln1', None) is None else self.ln1(O)
#      40 return O
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\_prog\vm_shared\attention-sdf\venv\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import json
from dataclasses import asdict

current_date = datetime.now().strftime("%Y-%m-%d")
model_name = f"{current_date}-model"
config_name = f"{current_date}-config.json"
trainer.save_model(result_dir / model_name)

with open(result_dir / config_name, 'w') as f:
    json.dump(asdict(config), f)
